# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary
from sklearn.model_selection import train_test_split
import shutil

'''Load data'''
temp_Qd = np.load('Data_processed/Qd_100.npy',allow_pickle=True).item()
temp_life = np.load('Data_processed/cycle_life.npy',allow_pickle=True).item()
all_capacity = np.load('Data_processed/all_capacity.npy',allow_pickle=True).item()
temp_Qd_all = []
temp_life_all = []
all_capacity_all = []

for key in temp_Qd.keys():
    temp_life_all.append(temp_life[key])
    all_capacity_all.append(all_capacity[key])
    temp_Qd_list = []
    for item in temp_Qd[key]:
        temp_Qd_list.append(item)
    temp_Qd_arr = np.asarray(temp_Qd_list)
    temp_Qd_all.append(temp_Qd_arr)
all_Qd_arr = np.asarray(temp_Qd_all)
cycle_life_arr = np.asarray(temp_life_all)    


'''Divide the dataset as the original paper stated'''
test_ind = np.hstack((np.arange(0,(41+43),2),83))
train_ind = np.arange(1,(41+43-1),2)
secondary_test_ind = np.arange(124-40,124)

all_keys = list(temp_Qd.keys())
train_keys = [all_keys[inx] for inx in train_ind]
test_keys = [all_keys[inx] for inx in test_ind]
secondary_test_keys = [all_keys[inx] for inx in secondary_test_ind]

cycle_life_arr=np.asarray(cycle_life_arr).reshape(-1,1)
max_label=np.max(cycle_life_arr)
cycle_life_arr=cycle_life_arr/max_label


train_Qds = np.asarray(all_Qd_arr)[train_ind]
train_cycle_lifes = np.asarray(cycle_life_arr)[train_ind]

test_Qd_a = np.asarray(all_Qd_arr)[test_ind]
test_cycle_life_a = np.asarray(cycle_life_arr)[test_ind]

test_Qd_b = np.asarray(all_Qd_arr)[secondary_test_ind]
test_cycle_life_b = np.asarray(cycle_life_arr)[secondary_test_ind]

train_Qd, _, train_cycle_life, _ = train_test_split(train_Qds, train_cycle_lifes, test_size=0.36, random_state=3)

# %%
# pip install einops

# %%
import torch
import torch.nn as nn
from einops import rearrange

def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')
def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)

import math
class CBAM(nn.Module):
    def __init__(self,in_channel,reduction=16,kernel_size=7):
        super(CBAM, self).__init__()
        #通道注意力机制
        self.max_pool=nn.AdaptiveMaxPool2d(output_size=1)
        self.avg_pool=nn.AdaptiveAvgPool2d(output_size=1)
        self.mlp=nn.Sequential(
            nn.Linear(in_features=in_channel,out_features=in_channel//reduction,bias=False),
            nn.ReLU(),
            nn.Linear(in_features=in_channel//reduction,out_features=in_channel,bias=False)
        )
        self.sigmoid=nn.Sigmoid()
        #空间注意力机制
        self.conv=nn.Conv2d(in_channels=2,out_channels=1,kernel_size=kernel_size ,stride=1,padding=kernel_size//2,bias=False)

    def forward(self,x):
        #通道注意力机制
        maxout=self.max_pool(x)
        maxout=self.mlp(maxout.view(maxout.size(0),-1))
        avgout=self.avg_pool(x)
        avgout=self.mlp(avgout.view(avgout.size(0),-1))
        channel_out=self.sigmoid(maxout+avgout)
        channel_out=channel_out.view(x.size(0),x.size(1),1,1)
        channel_out=channel_out*x
        #空间注意力机制
        max_out,_=torch.max(channel_out,dim=1,keepdim=True)
        mean_out=torch.mean(channel_out,dim=1,keepdim=True)
        out=torch.cat((max_out,mean_out),dim=1)
        out=self.sigmoid(self.conv(out))
        out=out*channel_out
        return out
    
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=1),
            nn.Dropout(p=0.2),
            nn.Conv2d(8, 16, kernel_size=(2, 3)),
            nn.BatchNorm2d(16),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
            nn.Conv2d(16, 32, kernel_size=(2, 3)),
            nn.BatchNorm2d(32),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
        )
        self.ebam = CBAM(64)
        self.layer2 =nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=(2, 2)),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
            
            nn.Conv2d(64, 128, kernel_size=(1, 2)),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
            
            nn.Conv2d(128,256,kernel_size=(1,2)),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
            
            nn.Conv2d(256, 256, kernel_size=(1, 2)),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.2),
            # nn.Conv2d(256, 512, kernel_size=(1, 2)),
            # nn.BatchNorm2d(512),
            # nn.LeakyReLU(inplace=True),
            # nn.Dropout(p=0.2),  
            
            # nn.Conv2d(512, 512, kernel_size=(1, 2)),
            # nn.BatchNorm2d(512),
            # nn.LeakyReLU(inplace=True),
            # nn.Dropout(p=0.2),  
        )
        
        # self.lstm = nn.LSTM(544, 544,num_layers=2, bidirectional=True, batch_first=True)
        # self.fc1 = nn.Linear(1088, 32)  # 修正为与LSTM输出相匹配
        self.lstm = nn.LSTM(32,32 ,num_layers=2, bidirectional=True, batch_first=True)
        self.fc1 = nn.Linear(33600, 1)  # 修正为与LSTM输出相匹配
        # self.fc2 = nn.Linear(32, 1)
        self.dropout = nn.Dropout(p=0.2)  # 添加Dropout层

    def forward(self, x):
        try:
            #让模型先经过layers1，在分开去做ebam和layer2
            x = self.layers1(x)
            # print(x.shape)
            x = to_3d(x)  # 转换为3D
            x, _ = self.lstm(x)  # LSTM处理
            # print(x.shape)
            # x = x[:, -1, :]  # 取最后一个时序输出作为特征
            # print(x.shape)
            x = to_4d(x,8,19)  # 转换为4D
            ebam_output = self.ebam(x)
            layer2_output = self.layer2(x)
            cropped_ebam_output = ebam_output[:, :, :7, :15]

            x = torch.cat((layer2_output, cropped_ebam_output), dim=1)
            return torch.sigmoid(self.fc1(x.view(x.size(0), -1)))  # 将x展平，确保输入到fc1的维度正确

        except RuntimeError as e:
            print(f"运行时错误：{e}")
            return None
        except Exception as e:
            print(f"发生意外错误：{e}")
            raise  # 重新抛出异常，以便进一步处理

# %%
net = Net()     # define the network
print(net)      # net architecture
# summary(net,(1,100,1000))
# Out:
# Net(
#   (layers1): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Conv2d(8, 16, kernel_size=(2, 3), stride=(1, 1))
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Conv2d(16, 32, kernel_size=(2, 3), stride=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#     (12): Dropout(p=0.2, inplace=False)
#   )
#   (ebam): CBAM(
#     (max_pool): AdaptiveMaxPool2d(output_size=1)
#     (avg_pool): AdaptiveAvgPool2d(output_size=1)
#     (mlp): Sequential(
#       (0): Linear(in_features=64, out_features=4, bias=False)
#       (1): ReLU()
#       (2): Linear(in_features=4, out_features=64, bias=False)
#     )
#     (sigmoid): Sigmoid()
#     (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(2, 2), stride=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): Dropout(p=0.2, inplace=False)
#     (4): Conv2d(64, 128, kernel_size=(1, 2), stride=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.01, inplace=True)
#     (7): Dropout(p=0.2, inplace=False)
#     (8): Conv2d(128, 256, kernel_size=(1, 2), stride=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.01, inplace=True)
#     (11): Dropout(p=0.2, inplace=False)
#     (12): Conv2d(256, 256, kernel_size=(1, 2), stride=(1, 1))
#     (13): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.01, inplace=True)
#     (15): Dropout(p=0.2, inplace=False)
#   )
#   (lstm): LSTM(32, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=33600, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
import pandas as pd
import torch.optim as optim
'''Data loader for Pytorch'''
input_train = torch.FloatTensor(train_Qd)
input_train = torch.unsqueeze(input_train, 1)
train_labels = torch.FloatTensor(train_cycle_life)

input_val = torch.FloatTensor(train_Qds)
input_val = torch.unsqueeze(input_val, 1)
val_labels = torch.FloatTensor(train_cycle_lifes)

input_test_a = torch.FloatTensor(test_Qd_a)
input_test_a = torch.unsqueeze(input_test_a, 1)
test_labels_a = torch.FloatTensor(test_cycle_life_a)

input_test_b = torch.FloatTensor(test_Qd_b)
input_test_b = torch.unsqueeze(input_test_b, 1)
test_labels_b = torch.FloatTensor(test_cycle_life_b)



seed = 17
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed)    # reproducible    




# optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)
optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)

loss_func = torch.nn.MSELoss() 

# # 动态调整学习率
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: 0.8 ** (epoch // 40))

# # 将学习率调度器修改为指数下降
# initial_lr = 0.0001  # 初始学习率
# decay_rate = 0.96  # 每个epoch衰减的比例
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: decay_rate ** epoch)

# 假设你已经定义了模型和优化器
# 当验证损失不下降时，减少学习率
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.8, patience=5)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# 创建历史记录DataFrame
history = pd.DataFrame(columns=['index', 'train_loss', 'val_loss'])
val_losses = []
max_models_to_keep = 10
saved_models=[]
import os

for t in range(800):
    net.train()
    train_prediction = net(input_train)
    train_loss = loss_func(train_prediction, train_labels)
   
    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    # 保存模型
    model_path = 'Target_model/net_parameters'+str(t)+'.pkl'
    torch.save({
        'epoch': t,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()}, model_path)

    net.eval()
    with torch.no_grad():
        val_prediction = net(input_val)
        val_loss = loss_func(val_prediction, val_labels)
    print('Step = %d' % t, 'train_loss:', train_loss.data.numpy(), 'val_loss:', val_loss.data.numpy())
    val_losses.append(val_loss.item())
    
    # 添加当前模型及其验证损失
    saved_models.append((val_loss.item(), model_path))

    # 保持模型数量不超过max_models_to_keep
    if len(saved_models) > max_models_to_keep:
        # 找到验证损失最大的一组模型并删除
        saved_models.sort(key=lambda x: x[0])  # 排序，根据损失
        os.remove(saved_models.pop()[1])  # 删除损失最大的模型
    # 加入训练历史记录
    # 创建新的一行数据
    new_entry = pd.DataFrame({'index': [t], 'train_loss': [train_loss.item()], 'val_loss': [val_loss.item()]})
    
    # 使用concat进行数据合并
    history = pd.concat([history, new_entry], ignore_index=True)

'''find the best model'''
best_index = val_losses.index(np.min(val_losses))
print(f'Best model at index: {best_index}')

'''copy the best model from model file to the model_test file'''
shutil.copyfile(f'Target_model/net_parameters{best_index}.pkl', 'Best_target_model/net_parameters.pkl')

'''Reload the best model''' 
model = Net()
checkpoint = torch.load('Best_target_model/net_parameters.pkl')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Step = 0 train_loss: 0.054745536 val_loss: 0.05579372
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_7104\1978983123.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   history = pd.concat([history, new_entry], ignore_index=True)
# Step = 1 train_loss: 0.038704988 val_loss: 0.052716214
# Step = 2 train_loss: 0.041905 val_loss: 0.051287383
# Step = 3 train_loss: 0.03834322 val_loss: 0.051267274
# Step = 4 train_loss: 0.034067433 val_loss: 0.05096138
# Step = 5 train_loss: 0.029759718 val_loss: 0.050075907
# Step = 6 train_loss: 0.033701368 val_loss: 0.04827732
# Step = 7 train_loss: 0.028405346 val_loss: 0.046042744
# Step = 8 train_loss: 0.02747323 val_loss: 0.044815395
# Step = 9 train_loss: 0.029933909 val_loss: 0.04291943
# Step = 10 train_loss: 0.030524561 val_loss: 0.041315507
# Step = 11 train_loss: 0.044004027 val_loss: 0.03862193
# Step = 12 train_loss: 0.036017463 val_loss: 0.036402788
# Step = 13 train_loss: 0.026981842 val_loss: 0.035670992
# Step = 14 train_loss: 0.032930236 val_loss: 0.036247622
# Step = 15 train_loss: 0.03073878 val_loss: 0.037223436
# Step = 16 train_loss: 0.050117113 val_loss: 0.035942286
# Step = 17 train_loss: 0.043077372 val_loss: 0.033191096
# Step = 18 train_loss: 0.029998135 val_loss: 0.031096287
# Step = 19 train_loss: 0.03200724 val_loss: 0.029094594
# Step = 20 train_loss: 0.034965582 val_loss: 0.027668767
# Step = 21 train_loss: 0.04119031 val_loss: 0.027185999
# Step = 22 train_loss: 0.037744857 val_loss: 0.02725755
# Step = 23 train_loss: 0.032295033 val_loss: 0.028218642
# Step = 24 train_loss: 0.034058347 val_loss: 0.028929494
# Step = 25 train_loss: 0.0374364 val_loss: 0.028576551
# Step = 26 train_loss: 0.035932574 val_loss: 0.02762907
# Step = 27 train_loss: 0.036979757 val_loss: 0.026208794
# Step = 28 train_loss: 0.028045734 val_loss: 0.024623709
# Step = 29 train_loss: 0.02640146 val_loss: 0.022996414
# Step = 30 train_loss: 0.03514369 val_loss: 0.021939466
# Step = 31 train_loss: 0.028973203 val_loss: 0.021435538
# Step = 32 train_loss: 0.029479742 val_loss: 0.021200988
# Step = 33 train_loss: 0.03539371 val_loss: 0.020951841
# Step = 34 train_loss: 0.029647563 val_loss: 0.020941567
# Step = 35 train_loss: 0.027448365 val_loss: 0.020968253
# Step = 36 train_loss: 0.033772193 val_loss: 0.020846894
# Step = 37 train_loss: 0.032160744 val_loss: 0.02077973
# Step = 38 train_loss: 0.02448656 val_loss: 0.02072374
# Step = 39 train_loss: 0.030581715 val_loss: 0.02062109
# Step = 40 train_loss: 0.042976253 val_loss: 0.020451393
# Step = 41 train_loss: 0.03985103 val_loss: 0.0203053
# Step = 42 train_loss: 0.02621044 val_loss: 0.020416753
# Step = 43 train_loss: 0.026782336 val_loss: 0.02038142
# Step = 44 train_loss: 0.028033253 val_loss: 0.020361938
# Step = 45 train_loss: 0.032108635 val_loss: 0.02039538
# Step = 46 train_loss: 0.03803643 val_loss: 0.02049316
# Step = 47 train_loss: 0.029406894 val_loss: 0.020400878
# Step = 48 train_loss: 0.027155193 val_loss: 0.02025731
# Step = 49 train_loss: 0.039014824 val_loss: 0.020175777
# Step = 50 train_loss: 0.030974763 val_loss: 0.020153943
# Step = 51 train_loss: 0.021925302 val_loss: 0.020189837
# Step = 52 train_loss: 0.04031465 val_loss: 0.020380799
# Step = 53 train_loss: 0.027817208 val_loss: 0.020598277
# Step = 54 train_loss: 0.024155019 val_loss: 0.020908618
# Step = 55 train_loss: 0.032739792 val_loss: 0.021490213
# Step = 56 train_loss: 0.021246277 val_loss: 0.022083567
# Step = 57 train_loss: 0.026397092 val_loss: 0.022850137
# Step = 58 train_loss: 0.041065447 val_loss: 0.023605414
# Step = 59 train_loss: 0.028977381 val_loss: 0.024356838
# Step = 60 train_loss: 0.030937495 val_loss: 0.02499342
# Step = 61 train_loss: 0.024078619 val_loss: 0.025616184
# Step = 62 train_loss: 0.030751692 val_loss: 0.02619443
# Step = 63 train_loss: 0.034174405 val_loss: 0.026647525
# Step = 64 train_loss: 0.02583404 val_loss: 0.026981214
# Step = 65 train_loss: 0.029156564 val_loss: 0.027046809
# Step = 66 train_loss: 0.029599575 val_loss: 0.0264385
# Step = 67 train_loss: 0.03366404 val_loss: 0.025660692
# Step = 68 train_loss: 0.041911963 val_loss: 0.025189111
# Step = 69 train_loss: 0.028360596 val_loss: 0.024941044
# Step = 70 train_loss: 0.031803235 val_loss: 0.02478528
# Step = 71 train_loss: 0.028767688 val_loss: 0.024631204
# Step = 72 train_loss: 0.036919992 val_loss: 0.024724541
# Step = 73 train_loss: 0.03374699 val_loss: 0.024907755
# Step = 74 train_loss: 0.025071906 val_loss: 0.025138548
# Step = 75 train_loss: 0.03170318 val_loss: 0.025351435
# Step = 76 train_loss: 0.02973337 val_loss: 0.02532211
# Step = 77 train_loss: 0.03316654 val_loss: 0.025862776
# Step = 78 train_loss: 0.034706026 val_loss: 0.026393874
# Step = 79 train_loss: 0.036891475 val_loss: 0.026622035
# Step = 80 train_loss: 0.035346813 val_loss: 0.026826775
# Step = 81 train_loss: 0.030563744 val_loss: 0.027427051
# Step = 82 train_loss: 0.027433503 val_loss: 0.02823712
# Step = 83 train_loss: 0.023782562 val_loss: 0.028742325
# Step = 84 train_loss: 0.025513815 val_loss: 0.029228142
# Step = 85 train_loss: 0.03613723 val_loss: 0.029662745
# Step = 86 train_loss: 0.021957798 val_loss: 0.029838135
# Step = 87 train_loss: 0.027346445 val_loss: 0.030049698
# Step = 88 train_loss: 0.03635076 val_loss: 0.03035468
# Step = 89 train_loss: 0.030854208 val_loss: 0.030864872
# Step = 90 train_loss: 0.03725819 val_loss: 0.03135667
# Step = 91 train_loss: 0.040854175 val_loss: 0.031605586
# Step = 92 train_loss: 0.027325243 val_loss: 0.031699162
# Step = 93 train_loss: 0.031376123 val_loss: 0.03186744
# Step = 94 train_loss: 0.03436974 val_loss: 0.032072827
# Step = 95 train_loss: 0.026137134 val_loss: 0.032232184
# Step = 96 train_loss: 0.027977956 val_loss: 0.03240139
# Step = 97 train_loss: 0.027635816 val_loss: 0.032569304
# Step = 98 train_loss: 0.028892837 val_loss: 0.03262418
# Step = 99 train_loss: 0.033581957 val_loss: 0.032700233
# Step = 100 train_loss: 0.033186782 val_loss: 0.032698743
# Step = 101 train_loss: 0.029798282 val_loss: 0.032699883
# Step = 102 train_loss: 0.03184191 val_loss: 0.032599058
# Step = 103 train_loss: 0.028270453 val_loss: 0.032624315
# Step = 104 train_loss: 0.028258085 val_loss: 0.032481346
# Step = 105 train_loss: 0.025025545 val_loss: 0.03243205
# Step = 106 train_loss: 0.029654793 val_loss: 0.03239905
# Step = 107 train_loss: 0.02784004 val_loss: 0.032329906
# Step = 108 train_loss: 0.040268756 val_loss: 0.032427587
# Step = 109 train_loss: 0.03028233 val_loss: 0.032227404
# Step = 110 train_loss: 0.03805289 val_loss: 0.03213566
# Step = 111 train_loss: 0.0375528 val_loss: 0.03212508
# Step = 112 train_loss: 0.023526646 val_loss: 0.031891093
# Step = 113 train_loss: 0.03622921 val_loss: 0.03167798
# Step = 114 train_loss: 0.035441738 val_loss: 0.031418424
# Step = 115 train_loss: 0.026461802 val_loss: 0.03130337
# Step = 116 train_loss: 0.04016165 val_loss: 0.031112488
# Step = 117 train_loss: 0.02534008 val_loss: 0.030967308
# Step = 118 train_loss: 0.017585129 val_loss: 0.030763917
# Step = 119 train_loss: 0.034977034 val_loss: 0.030687917
# Step = 120 train_loss: 0.013339074 val_loss: 0.030716926
# Step = 121 train_loss: 0.032828897 val_loss: 0.030734213
# Step = 122 train_loss: 0.03128725 val_loss: 0.030762754
# Step = 123 train_loss: 0.028950714 val_loss: 0.030659286
# Step = 124 train_loss: 0.036573112 val_loss: 0.030882705
# Step = 125 train_loss: 0.035556797 val_loss: 0.031120999
# Step = 126 train_loss: 0.028828222 val_loss: 0.030851882
# Step = 127 train_loss: 0.030054348 val_loss: 0.030665968
# Step = 128 train_loss: 0.02418475 val_loss: 0.030520873
# Step = 129 train_loss: 0.02911761 val_loss: 0.030077033
# Step = 130 train_loss: 0.027097281 val_loss: 0.02949143
# Step = 131 train_loss: 0.02762697 val_loss: 0.02889566
# Step = 132 train_loss: 0.028598811 val_loss: 0.027995814
# Step = 133 train_loss: 0.031304147 val_loss: 0.027201016
# Step = 134 train_loss: 0.018444134 val_loss: 0.02583471
# Step = 135 train_loss: 0.023486314 val_loss: 0.025076872
# Step = 136 train_loss: 0.033352558 val_loss: 0.024263471
# Step = 137 train_loss: 0.03223838 val_loss: 0.023281194
# Step = 138 train_loss: 0.022632925 val_loss: 0.02234191
# Step = 139 train_loss: 0.027019966 val_loss: 0.022056285
# Step = 140 train_loss: 0.036421835 val_loss: 0.021539811
# Step = 141 train_loss: 0.03737318 val_loss: 0.021464169
# Step = 142 train_loss: 0.037339672 val_loss: 0.02120521
# Step = 143 train_loss: 0.029501002 val_loss: 0.02099471
# Step = 144 train_loss: 0.029908953 val_loss: 0.020316416
# Step = 145 train_loss: 0.021520115 val_loss: 0.019884277
# Step = 146 train_loss: 0.037603512 val_loss: 0.019812832
# Step = 147 train_loss: 0.018819699 val_loss: 0.019747024
# Step = 148 train_loss: 0.025051512 val_loss: 0.020045765
# Step = 149 train_loss: 0.030941395 val_loss: 0.020606726
# Step = 150 train_loss: 0.02444897 val_loss: 0.02103495
# Step = 151 train_loss: 0.03201879 val_loss: 0.02142987
# Step = 152 train_loss: 0.02497984 val_loss: 0.02175087
# Step = 153 train_loss: 0.024312885 val_loss: 0.02057948
# Step = 154 train_loss: 0.02679543 val_loss: 0.019819818
# Step = 155 train_loss: 0.023555128 val_loss: 0.018837126
# Step = 156 train_loss: 0.025772123 val_loss: 0.017707093
# Step = 157 train_loss: 0.023355145 val_loss: 0.01697964
# Step = 158 train_loss: 0.026194606 val_loss: 0.016722547
# Step = 159 train_loss: 0.029156933 val_loss: 0.016764054
# Step = 160 train_loss: 0.030184258 val_loss: 0.017444395
# Step = 161 train_loss: 0.02162784 val_loss: 0.018489808
# Step = 162 train_loss: 0.03027339 val_loss: 0.02120433
# Step = 163 train_loss: 0.03655277 val_loss: 0.025957
# Step = 164 train_loss: 0.03405943 val_loss: 0.030332774
# Step = 165 train_loss: 0.027284702 val_loss: 0.03336054
# Step = 166 train_loss: 0.040910706 val_loss: 0.036622345
# Step = 167 train_loss: 0.032145265 val_loss: 0.04034443
# Step = 168 train_loss: 0.031211931 val_loss: 0.04387291
# Step = 169 train_loss: 0.027688261 val_loss: 0.048275705
# Step = 170 train_loss: 0.0455542 val_loss: 0.053092666
# Step = 171 train_loss: 0.02179085 val_loss: 0.05634915
# Step = 172 train_loss: 0.029118588 val_loss: 0.05897316
# Step = 173 train_loss: 0.035538103 val_loss: 0.061661676
# Step = 174 train_loss: 0.028991103 val_loss: 0.062481396
# Step = 175 train_loss: 0.028326603 val_loss: 0.06252749
# Step = 176 train_loss: 0.029386865 val_loss: 0.06177636
# Step = 177 train_loss: 0.028553175 val_loss: 0.06095341
# Step = 178 train_loss: 0.03806702 val_loss: 0.06056835
# Step = 179 train_loss: 0.030560076 val_loss: 0.06087778
# Step = 180 train_loss: 0.028476102 val_loss: 0.06261938
# Step = 181 train_loss: 0.022334788 val_loss: 0.065562844
# Step = 182 train_loss: 0.033235192 val_loss: 0.06801164
# Step = 183 train_loss: 0.0254332 val_loss: 0.06977726
# Step = 184 train_loss: 0.027767135 val_loss: 0.07173409
# Step = 185 train_loss: 0.03417096 val_loss: 0.07495986
# Step = 186 train_loss: 0.022179596 val_loss: 0.07017325
# Step = 187 train_loss: 0.03146312 val_loss: 0.062370718
# Step = 188 train_loss: 0.023517195 val_loss: 0.06631179
# Step = 189 train_loss: 0.028774874 val_loss: 0.043336075
# Step = 190 train_loss: 0.030384919 val_loss: 0.06440931
# Step = 191 train_loss: 0.024871103 val_loss: 0.23898269
# Step = 192 train_loss: 0.024389522 val_loss: 0.31190008
# Step = 193 train_loss: 0.024927933 val_loss: 0.37498966
# Step = 194 train_loss: 0.025680939 val_loss: 0.47826487
# Step = 195 train_loss: 0.02398573 val_loss: 0.491888
# Step = 196 train_loss: 0.024284028 val_loss: 0.49655285
# Step = 197 train_loss: 0.01832083 val_loss: 0.49790782
# Step = 198 train_loss: 0.0212957 val_loss: 0.49678755
# Step = 199 train_loss: 0.02134057 val_loss: 0.4962626
# Step = 200 train_loss: 0.039743107 val_loss: 0.49161482
# Step = 201 train_loss: 0.03151891 val_loss: 0.49374706
# Step = 202 train_loss: 0.040839493 val_loss: 0.4955557
# Step = 203 train_loss: 0.03145138 val_loss: 0.49586552
# Step = 204 train_loss: 0.02954023 val_loss: 0.4934746
# Step = 205 train_loss: 0.031335723 val_loss: 0.48721945
# Step = 206 train_loss: 0.024573673 val_loss: 0.47651142
# Step = 207 train_loss: 0.02916218 val_loss: 0.46237367
# Step = 208 train_loss: 0.03318778 val_loss: 0.4508641
# Step = 209 train_loss: 0.030462673 val_loss: 0.4418242
# Step = 210 train_loss: 0.027227214 val_loss: 0.4328148
# Step = 211 train_loss: 0.02596402 val_loss: 0.42025086
# Step = 212 train_loss: 0.025417645 val_loss: 0.40454045
# Step = 213 train_loss: 0.03240226 val_loss: 0.3882636
# Step = 214 train_loss: 0.032626834 val_loss: 0.36267635
# Step = 215 train_loss: 0.028235707 val_loss: 0.33513138
# Step = 216 train_loss: 0.017517518 val_loss: 0.30721465
# Step = 217 train_loss: 0.034693502 val_loss: 0.29526955
# Step = 218 train_loss: 0.03553202 val_loss: 0.2957319
# Step = 219 train_loss: 0.020799099 val_loss: 0.31556925
# Step = 220 train_loss: 0.030869773 val_loss: 0.32383448
# Step = 221 train_loss: 0.031856395 val_loss: 0.34938958
# Step = 222 train_loss: 0.02918319 val_loss: 0.39031202
# Step = 223 train_loss: 0.022144727 val_loss: 0.44129106
# Step = 224 train_loss: 0.02439503 val_loss: 0.45569193
# Step = 225 train_loss: 0.027328935 val_loss: 0.4967444
# Step = 226 train_loss: 0.08017589 val_loss: 0.3792515
# Step = 227 train_loss: 0.028905153 val_loss: 0.3037668
# Step = 228 train_loss: 0.021389574 val_loss: 0.23490499
# Step = 229 train_loss: 0.029127251 val_loss: 0.01658313
# Step = 230 train_loss: 0.03775962 val_loss: 0.013891271
# Step = 231 train_loss: 0.031862583 val_loss: 0.013548165
# Step = 232 train_loss: 0.029412288 val_loss: 0.012781301
# Step = 233 train_loss: 0.023724856 val_loss: 0.012587379
# Step = 234 train_loss: 0.021981886 val_loss: 0.012644084
# Step = 235 train_loss: 0.034013353 val_loss: 0.012793479
# Step = 236 train_loss: 0.03219518 val_loss: 0.01374956
# Step = 237 train_loss: 0.023466181 val_loss: 0.014227986
# Step = 238 train_loss: 0.029080437 val_loss: 0.013021122
# Step = 239 train_loss: 0.023766914 val_loss: 0.011624021
# Step = 240 train_loss: 0.016512297 val_loss: 0.012176438
# Step = 241 train_loss: 0.028530568 val_loss: 0.017940238
# Step = 242 train_loss: 0.023753315 val_loss: 0.031099636
# Step = 243 train_loss: 0.022748608 val_loss: 0.054495767
# Step = 244 train_loss: 0.028830905 val_loss: 0.114773914
# Step = 245 train_loss: 0.035205923 val_loss: 0.18475562
# Step = 246 train_loss: 0.026539935 val_loss: 0.33945724
# Step = 247 train_loss: 0.03092001 val_loss: 0.4132711
# Step = 248 train_loss: 0.021335244 val_loss: 0.48944065
# Step = 249 train_loss: 0.018154817 val_loss: 0.5067046
# Step = 250 train_loss: 0.03251512 val_loss: 0.5055842
# Step = 251 train_loss: 0.0166879 val_loss: 0.5050064
# Step = 252 train_loss: 0.023713801 val_loss: 0.50497043
# Step = 253 train_loss: 0.025478762 val_loss: 0.5048266
# Step = 254 train_loss: 0.032128382 val_loss: 0.5051374
# Step = 255 train_loss: 0.03883302 val_loss: 0.5049927
# Step = 256 train_loss: 0.019593764 val_loss: 0.5045441
# Step = 257 train_loss: 0.019744482 val_loss: 0.50365376
# Step = 258 train_loss: 0.029480942 val_loss: 0.5017432
# Step = 259 train_loss: 0.02769954 val_loss: 0.4984372
# Step = 260 train_loss: 0.020891448 val_loss: 0.49141404
# Step = 261 train_loss: 0.023306826 val_loss: 0.47956103
# Step = 262 train_loss: 0.029323872 val_loss: 0.46422866
# Step = 263 train_loss: 0.020411223 val_loss: 0.44277516
# Step = 264 train_loss: 0.02617222 val_loss: 0.4079721
# Step = 265 train_loss: 0.026140353 val_loss: 0.35984275
# Step = 266 train_loss: 0.027644765 val_loss: 0.3080833
# Step = 267 train_loss: 0.030412216 val_loss: 0.25648227
# Step = 268 train_loss: 0.018771993 val_loss: 0.20586972
# Step = 269 train_loss: 0.02562785 val_loss: 0.1551455
# Step = 270 train_loss: 0.02143569 val_loss: 0.10376713
# Step = 271 train_loss: 0.02302299 val_loss: 0.06111965
# Step = 272 train_loss: 0.021654803 val_loss: 0.037044317
# Step = 273 train_loss: 0.016564004 val_loss: 0.02166206
# Step = 274 train_loss: 0.03549535 val_loss: 0.013999929
# Step = 275 train_loss: 0.02907726 val_loss: 0.012336355
# Step = 276 train_loss: 0.022870202 val_loss: 0.01462122
# Step = 277 train_loss: 0.018400956 val_loss: 0.01913467
# Step = 278 train_loss: 0.03161261 val_loss: 0.023885215
# Step = 279 train_loss: 0.019602457 val_loss: 0.027471486
# Step = 280 train_loss: 0.019874247 val_loss: 0.031338792
# Step = 281 train_loss: 0.023115622 val_loss: 0.034997065
# Step = 282 train_loss: 0.025868965 val_loss: 0.03779264
# Step = 283 train_loss: 0.023681432 val_loss: 0.04102291
# Step = 284 train_loss: 0.028220702 val_loss: 0.044448838
# Step = 285 train_loss: 0.02770389 val_loss: 0.04717401
# Step = 286 train_loss: 0.032063592 val_loss: 0.049882434
# Step = 287 train_loss: 0.020370973 val_loss: 0.052156746
# Step = 288 train_loss: 0.01724739 val_loss: 0.053750608
# Step = 289 train_loss: 0.023035884 val_loss: 0.05499587
# Step = 290 train_loss: 0.014585303 val_loss: 0.056518596
# Step = 291 train_loss: 0.032948606 val_loss: 0.057459824
# Step = 292 train_loss: 0.029326882 val_loss: 0.058337137
# Step = 293 train_loss: 0.016761867 val_loss: 0.058921594
# Step = 294 train_loss: 0.021826569 val_loss: 0.0596017
# Step = 295 train_loss: 0.019981695 val_loss: 0.06043105
# Step = 296 train_loss: 0.024596797 val_loss: 0.061223023
# Step = 297 train_loss: 0.029456021 val_loss: 0.062254377
# Step = 298 train_loss: 0.021563977 val_loss: 0.063415594
# Step = 299 train_loss: 0.020162344 val_loss: 0.0641022
# Step = 300 train_loss: 0.028977849 val_loss: 0.06494084
# Step = 301 train_loss: 0.016302522 val_loss: 0.06569522
# Step = 302 train_loss: 0.025795083 val_loss: 0.0663637
# Step = 303 train_loss: 0.028663374 val_loss: 0.06674249
# Step = 304 train_loss: 0.0309958 val_loss: 0.06699399
# Step = 305 train_loss: 0.024427302 val_loss: 0.067147985
# Step = 306 train_loss: 0.028648905 val_loss: 0.0676018
# Step = 307 train_loss: 0.026334455 val_loss: 0.06747049
# Step = 308 train_loss: 0.02191788 val_loss: 0.067695335
# Step = 309 train_loss: 0.026359793 val_loss: 0.06765562
# Step = 310 train_loss: 0.023592371 val_loss: 0.06770718
# Step = 311 train_loss: 0.023105042 val_loss: 0.06783707
# Step = 312 train_loss: 0.01716438 val_loss: 0.06796541
# Step = 313 train_loss: 0.016781796 val_loss: 0.068184346
# Step = 314 train_loss: 0.033274252 val_loss: 0.06838265
# Step = 315 train_loss: 0.02308617 val_loss: 0.06823993
# Step = 316 train_loss: 0.02444422 val_loss: 0.06815579
# Step = 317 train_loss: 0.030926367 val_loss: 0.067521416
# Step = 318 train_loss: 0.021203132 val_loss: 0.067029595
# Step = 319 train_loss: 0.020678133 val_loss: 0.06706071
# Step = 320 train_loss: 0.017276965 val_loss: 0.06691841
# Step = 321 train_loss: 0.037587233 val_loss: 0.06613173
# Step = 322 train_loss: 0.02760274 val_loss: 0.065567695
# Step = 323 train_loss: 0.02269247 val_loss: 0.065426506
# Step = 324 train_loss: 0.016942617 val_loss: 0.065138444
# Step = 325 train_loss: 0.029392771 val_loss: 0.06459209
# Step = 326 train_loss: 0.025378503 val_loss: 0.06442126
# Step = 327 train_loss: 0.02948945 val_loss: 0.06435891
# Step = 328 train_loss: 0.032748315 val_loss: 0.064718805
# Step = 329 train_loss: 0.026725251 val_loss: 0.065426685
# Step = 330 train_loss: 0.026860613 val_loss: 0.065627284
# Step = 331 train_loss: 0.016383447 val_loss: 0.06647592
# Step = 332 train_loss: 0.023164187 val_loss: 0.06679388
# Step = 333 train_loss: 0.038372226 val_loss: 0.06780958
# Step = 334 train_loss: 0.03428826 val_loss: 0.069576584
# Step = 335 train_loss: 0.027957221 val_loss: 0.07057774
# Step = 336 train_loss: 0.029136095 val_loss: 0.071045205
# Step = 337 train_loss: 0.029747972 val_loss: 0.072100654
# Step = 338 train_loss: 0.018355832 val_loss: 0.07296521
# Step = 339 train_loss: 0.03146794 val_loss: 0.074166626
# Step = 340 train_loss: 0.018886361 val_loss: 0.07494144
# Step = 341 train_loss: 0.019703291 val_loss: 0.07568809
# Step = 342 train_loss: 0.012881884 val_loss: 0.075673215
# Step = 343 train_loss: 0.025893172 val_loss: 0.07442852
# Step = 344 train_loss: 0.021678496 val_loss: 0.07207053
# Step = 345 train_loss: 0.028732356 val_loss: 0.06841713
# Step = 346 train_loss: 0.020648696 val_loss: 0.06421777
# Step = 347 train_loss: 0.021774344 val_loss: 0.06027939
# Step = 348 train_loss: 0.021059286 val_loss: 0.056162458
# Step = 349 train_loss: 0.029966077 val_loss: 0.05305163
# Step = 350 train_loss: 0.033529676 val_loss: 0.05132036
# Step = 351 train_loss: 0.021243896 val_loss: 0.051117003
# Step = 352 train_loss: 0.023304416 val_loss: 0.052348625
# Step = 353 train_loss: 0.022831637 val_loss: 0.054889645
# Step = 354 train_loss: 0.02940301 val_loss: 0.058864135
# Step = 355 train_loss: 0.02514524 val_loss: 0.06290798
# Step = 356 train_loss: 0.028327767 val_loss: 0.06637606
# Step = 357 train_loss: 0.027047146 val_loss: 0.06816948
# Step = 358 train_loss: 0.027068065 val_loss: 0.06804812
# Step = 359 train_loss: 0.030482905 val_loss: 0.067298114
# Step = 360 train_loss: 0.031099422 val_loss: 0.06556267
# Step = 361 train_loss: 0.031049537 val_loss: 0.06333305
# Step = 362 train_loss: 0.027591784 val_loss: 0.061602917
# Step = 363 train_loss: 0.038352117 val_loss: 0.061981916
# Step = 364 train_loss: 0.031716734 val_loss: 0.06188025
# Step = 365 train_loss: 0.01975694 val_loss: 0.06284198
# Step = 366 train_loss: 0.016429026 val_loss: 0.06397985
# Step = 367 train_loss: 0.0205575 val_loss: 0.06589416
# Step = 368 train_loss: 0.018829228 val_loss: 0.06779955
# Step = 369 train_loss: 0.026216995 val_loss: 0.06917843
# Step = 370 train_loss: 0.0198459 val_loss: 0.070036806
# Step = 371 train_loss: 0.023947498 val_loss: 0.06929638
# Step = 372 train_loss: 0.024713563 val_loss: 0.06844772
# Step = 373 train_loss: 0.02243509 val_loss: 0.068374924
# Step = 374 train_loss: 0.030913506 val_loss: 0.06816023
# Step = 375 train_loss: 0.0224303 val_loss: 0.07012299
# Step = 376 train_loss: 0.024539629 val_loss: 0.07169036
# Step = 377 train_loss: 0.017043803 val_loss: 0.073738374
# Step = 378 train_loss: 0.036865275 val_loss: 0.07685546
# Step = 379 train_loss: 0.023523327 val_loss: 0.078333445
# Step = 380 train_loss: 0.016287958 val_loss: 0.078011625
# Step = 381 train_loss: 0.02203883 val_loss: 0.07765897
# Step = 382 train_loss: 0.020005753 val_loss: 0.07542722
# Step = 383 train_loss: 0.024841096 val_loss: 0.07459531
# Step = 384 train_loss: 0.019418143 val_loss: 0.07545121
# Step = 385 train_loss: 0.0229103 val_loss: 0.07683959
# Step = 386 train_loss: 0.03352503 val_loss: 0.07837832
# Step = 387 train_loss: 0.025958588 val_loss: 0.08033616
# Step = 388 train_loss: 0.022176078 val_loss: 0.08108667
# Step = 389 train_loss: 0.021510985 val_loss: 0.08188233
# Step = 390 train_loss: 0.02127577 val_loss: 0.08254121
# Step = 391 train_loss: 0.01761164 val_loss: 0.08223225
# Step = 392 train_loss: 0.023460232 val_loss: 0.08117375
# Step = 393 train_loss: 0.027043687 val_loss: 0.08086804
# Step = 394 train_loss: 0.029696815 val_loss: 0.083387524
# Step = 395 train_loss: 0.01966292 val_loss: 0.08626229
# Step = 396 train_loss: 0.023362081 val_loss: 0.08875893
# Step = 397 train_loss: 0.028393934 val_loss: 0.089890614
# Step = 398 train_loss: 0.022886224 val_loss: 0.089426614
# Step = 399 train_loss: 0.029278329 val_loss: 0.08857791
# Step = 400 train_loss: 0.027809003 val_loss: 0.087889075
# Step = 401 train_loss: 0.017889183 val_loss: 0.087274306
# Step = 402 train_loss: 0.018551301 val_loss: 0.08730008
# Step = 403 train_loss: 0.027379094 val_loss: 0.0896552
# Step = 404 train_loss: 0.023867454 val_loss: 0.09233995
# Step = 405 train_loss: 0.026206644 val_loss: 0.0944329
# Step = 406 train_loss: 0.01806694 val_loss: 0.09562078
# Step = 407 train_loss: 0.019635182 val_loss: 0.096292816
# Step = 408 train_loss: 0.020097954 val_loss: 0.095731586
# Step = 409 train_loss: 0.02090927 val_loss: 0.09457211
# Step = 410 train_loss: 0.023619715 val_loss: 0.09381049
# Step = 411 train_loss: 0.017561235 val_loss: 0.09351471
# Step = 412 train_loss: 0.024068616 val_loss: 0.094612226
# Step = 413 train_loss: 0.014884417 val_loss: 0.09605743
# Step = 414 train_loss: 0.020370595 val_loss: 0.09814397
# Step = 415 train_loss: 0.023417188 val_loss: 0.09969059
# Step = 416 train_loss: 0.022518417 val_loss: 0.10041646
# Step = 417 train_loss: 0.02464795 val_loss: 0.10049588
# Step = 418 train_loss: 0.023257513 val_loss: 0.10003213
# Step = 419 train_loss: 0.02482458 val_loss: 0.09890676
# Step = 420 train_loss: 0.022329587 val_loss: 0.098510616
# Step = 421 train_loss: 0.01687449 val_loss: 0.09814689
# Step = 422 train_loss: 0.019410305 val_loss: 0.09865007
# Step = 423 train_loss: 0.013848969 val_loss: 0.09903366
# Step = 424 train_loss: 0.02769837 val_loss: 0.099630766
# Step = 425 train_loss: 0.014020548 val_loss: 0.099382006
# Step = 426 train_loss: 0.014201043 val_loss: 0.099113666
# Step = 427 train_loss: 0.017015673 val_loss: 0.09815591
# Step = 428 train_loss: 0.022113081 val_loss: 0.09701464
# Step = 429 train_loss: 0.015257748 val_loss: 0.0964052
# Step = 430 train_loss: 0.012003405 val_loss: 0.09565128
# Step = 431 train_loss: 0.0090606995 val_loss: 0.09497339
# Step = 432 train_loss: 0.01501449 val_loss: 0.09452087
# Step = 433 train_loss: 0.015331318 val_loss: 0.094407775
# Step = 434 train_loss: 0.011423338 val_loss: 0.09351794
# Step = 435 train_loss: 0.021661678 val_loss: 0.09280925
# Step = 436 train_loss: 0.02119665 val_loss: 0.09057057
# Step = 437 train_loss: 0.026591223 val_loss: 0.08686461
# Step = 438 train_loss: 0.028041247 val_loss: 0.082413845
# Step = 439 train_loss: 0.022267658 val_loss: 0.079852
# Step = 440 train_loss: 0.02482627 val_loss: 0.07922485
# Step = 441 train_loss: 0.025916694 val_loss: 0.081255734
# Step = 442 train_loss: 0.0073561114 val_loss: 0.08276522
# Step = 443 train_loss: 0.012945956 val_loss: 0.08443381
# Step = 444 train_loss: 0.017487478 val_loss: 0.085771576
# Step = 445 train_loss: 0.021656562 val_loss: 0.0861759
# Step = 446 train_loss: 0.020285925 val_loss: 0.085589595
# Step = 447 train_loss: 0.027776245 val_loss: 0.084208764
# Step = 448 train_loss: 0.031102372 val_loss: 0.082793616
# Step = 449 train_loss: 0.029553981 val_loss: 0.08247006
# Step = 450 train_loss: 0.021214964 val_loss: 0.082428426
# Step = 451 train_loss: 0.02987924 val_loss: 0.08248778
# Step = 452 train_loss: 0.022655083 val_loss: 0.082381204
# Step = 453 train_loss: 0.023258328 val_loss: 0.08184992
# Step = 454 train_loss: 0.019426236 val_loss: 0.0814843
# Step = 455 train_loss: 0.01977124 val_loss: 0.08055357
# Step = 456 train_loss: 0.020731231 val_loss: 0.07971299
# Step = 457 train_loss: 0.02528725 val_loss: 0.0789962
# Step = 458 train_loss: 0.023493577 val_loss: 0.07853888
# Step = 459 train_loss: 0.019284347 val_loss: 0.07796363
# Step = 460 train_loss: 0.019679694 val_loss: 0.07727245
# Step = 461 train_loss: 0.030804805 val_loss: 0.07655093
# Step = 462 train_loss: 0.03042394 val_loss: 0.076042876
# Step = 463 train_loss: 0.026171397 val_loss: 0.07521996
# Step = 464 train_loss: 0.01584221 val_loss: 0.07420865
# Step = 465 train_loss: 0.021142602 val_loss: 0.07346442
# Step = 466 train_loss: 0.031072458 val_loss: 0.073102824
# Step = 467 train_loss: 0.026388735 val_loss: 0.07264506
# Step = 468 train_loss: 0.03341396 val_loss: 0.071685486
# Step = 469 train_loss: 0.018045682 val_loss: 0.07010906
# Step = 470 train_loss: 0.021573301 val_loss: 0.06858787
# Step = 471 train_loss: 0.017106107 val_loss: 0.066479824
# Step = 472 train_loss: 0.017346187 val_loss: 0.064234674
# Step = 473 train_loss: 0.024397042 val_loss: 0.061486587
# Step = 474 train_loss: 0.023503982 val_loss: 0.058856342
# Step = 475 train_loss: 0.019409182 val_loss: 0.05632812
# Step = 476 train_loss: 0.021451205 val_loss: 0.054143276
# Step = 477 train_loss: 0.02310036 val_loss: 0.052610137
# Step = 478 train_loss: 0.01717302 val_loss: 0.052638896
# Step = 479 train_loss: 0.022493608 val_loss: 0.052911527
# Step = 480 train_loss: 0.02733449 val_loss: 0.053142432
# Step = 481 train_loss: 0.02934788 val_loss: 0.053834025
# Step = 482 train_loss: 0.02324957 val_loss: 0.05414778
# Step = 483 train_loss: 0.023418603 val_loss: 0.05434684
# Step = 484 train_loss: 0.014610412 val_loss: 0.054403905
# Step = 485 train_loss: 0.014374213 val_loss: 0.05466756
# Step = 486 train_loss: 0.017622354 val_loss: 0.054840043
# Step = 487 train_loss: 0.013058886 val_loss: 0.05497634
# Step = 488 train_loss: 0.028485576 val_loss: 0.055509266
# Step = 489 train_loss: 0.022115985 val_loss: 0.055490896
# Step = 490 train_loss: 0.021538936 val_loss: 0.055247057
# Step = 491 train_loss: 0.02056698 val_loss: 0.055466715
# Step = 492 train_loss: 0.020777337 val_loss: 0.05582488
# Step = 493 train_loss: 0.021105327 val_loss: 0.05606477
# Step = 494 train_loss: 0.016819019 val_loss: 0.056226816
# Step = 495 train_loss: 0.016076915 val_loss: 0.057925086
# Step = 496 train_loss: 0.011656453 val_loss: 0.062009025
# Step = 497 train_loss: 0.01748788 val_loss: 0.067031205
# Step = 498 train_loss: 0.016708048 val_loss: 0.07192471
# Step = 499 train_loss: 0.012414498 val_loss: 0.07557813
# Step = 500 train_loss: 0.020845015 val_loss: 0.07841241
# Step = 501 train_loss: 0.01919515 val_loss: 0.08077101
# Step = 502 train_loss: 0.013546272 val_loss: 0.08313639
# Step = 503 train_loss: 0.011073685 val_loss: 0.08453553
# Step = 504 train_loss: 0.0123032415 val_loss: 0.08534631
# Step = 505 train_loss: 0.010228887 val_loss: 0.0853658
# Step = 506 train_loss: 0.023482561 val_loss: 0.08535707
# Step = 507 train_loss: 0.02046642 val_loss: 0.08450624
# Step = 508 train_loss: 0.0269077 val_loss: 0.08261825
# Step = 509 train_loss: 0.014730265 val_loss: 0.07911214
# Step = 510 train_loss: 0.023622703 val_loss: 0.073518254
# Step = 511 train_loss: 0.018177258 val_loss: 0.063674584
# Step = 512 train_loss: 0.019418515 val_loss: 0.05574545
# Step = 513 train_loss: 0.016413383 val_loss: 0.05594243
# Step = 514 train_loss: 0.01943948 val_loss: 0.05591378
# Step = 515 train_loss: 0.012914513 val_loss: 0.056063645
# Step = 516 train_loss: 0.017202593 val_loss: 0.05658671
# Step = 517 train_loss: 0.0126120355 val_loss: 0.056838494
# Step = 518 train_loss: 0.01401466 val_loss: 0.057245545
# Step = 519 train_loss: 0.0115422625 val_loss: 0.065743886
# Step = 520 train_loss: 0.012794061 val_loss: 0.06680913
# Step = 521 train_loss: 0.010072029 val_loss: 0.0670939
# Step = 522 train_loss: 0.009835588 val_loss: 0.0676731
# Step = 523 train_loss: 0.011191159 val_loss: 0.067872696
# Step = 524 train_loss: 0.01590805 val_loss: 0.06803273
# Step = 525 train_loss: 0.016018856 val_loss: 0.0677871
# Step = 526 train_loss: 0.008586587 val_loss: 0.06939115
# Step = 527 train_loss: 0.018668402 val_loss: 0.07342473
# Step = 528 train_loss: 0.012253625 val_loss: 0.07595694
# Step = 529 train_loss: 0.006598442 val_loss: 0.07662538
# Step = 530 train_loss: 0.014130114 val_loss: 0.07730771
# Step = 531 train_loss: 0.011350935 val_loss: 0.078221425
# Step = 532 train_loss: 0.013519025 val_loss: 0.07827602
# Step = 533 train_loss: 0.010933993 val_loss: 0.07749891
# Step = 534 train_loss: 0.015086458 val_loss: 0.08117867
# Step = 535 train_loss: 0.01118184 val_loss: 0.34350026
# Step = 536 train_loss: 0.0108939 val_loss: 0.50667983
# Step = 537 train_loss: 0.016353644 val_loss: 0.50928307
# Step = 538 train_loss: 0.017902048 val_loss: 0.5094241
# Step = 539 train_loss: 0.0148100415 val_loss: 0.5094209
# Step = 540 train_loss: 0.021822058 val_loss: 0.5091682
# Step = 541 train_loss: 0.019911923 val_loss: 0.5074061
# Step = 542 train_loss: 0.014484281 val_loss: 0.4954397
# Step = 543 train_loss: 0.010947953 val_loss: 0.44118485
# Step = 544 train_loss: 0.017263083 val_loss: 0.23017901
# Step = 545 train_loss: 0.010679394 val_loss: 0.00870072
# Step = 546 train_loss: 0.017155636 val_loss: 0.08194464
# Step = 547 train_loss: 0.011829833 val_loss: 0.091717534
# Step = 548 train_loss: 0.013308436 val_loss: 0.08465132
# Step = 549 train_loss: 0.0092508 val_loss: 0.085441604
# Step = 550 train_loss: 0.013307736 val_loss: 0.0853069
# Step = 551 train_loss: 0.0133945 val_loss: 0.08483453
# Step = 552 train_loss: 0.01624043 val_loss: 0.08381781
# Step = 553 train_loss: 0.012751335 val_loss: 0.08269116
# Step = 554 train_loss: 0.013705652 val_loss: 0.08100623
# Step = 555 train_loss: 0.00989889 val_loss: 0.07879167
# Step = 556 train_loss: 0.014665923 val_loss: 0.07689692
# Step = 557 train_loss: 0.011222814 val_loss: 0.07438105
# Step = 558 train_loss: 0.015913866 val_loss: 0.50842977
# Step = 559 train_loss: 0.01257977 val_loss: 0.50959194
# Step = 560 train_loss: 0.017484806 val_loss: 0.5095921
# Step = 561 train_loss: 0.01624958 val_loss: 0.5095921
# Step = 562 train_loss: 0.014409727 val_loss: 0.50959224
# Step = 563 train_loss: 0.034523483 val_loss: 0.50959224
# Step = 564 train_loss: 0.015191412 val_loss: 0.50959224
# Step = 565 train_loss: 0.033296946 val_loss: 0.50959224
# Step = 566 train_loss: 0.02937111 val_loss: 0.50959206
# Step = 567 train_loss: 0.019421726 val_loss: 0.50959176
# Step = 568 train_loss: 0.02249579 val_loss: 0.50959086
# Step = 569 train_loss: 0.02378879 val_loss: 0.5095887
# Step = 570 train_loss: 0.021219704 val_loss: 0.50958425
# Step = 571 train_loss: 0.020686058 val_loss: 0.5095759
# Step = 572 train_loss: 0.026783576 val_loss: 0.5095585
# Step = 573 train_loss: 0.02521486 val_loss: 0.5095219
# Step = 574 train_loss: 0.02293967 val_loss: 0.5094154
# Step = 575 train_loss: 0.030227883 val_loss: 0.5090823
# Step = 576 train_loss: 0.026311027 val_loss: 0.5081394
# Step = 577 train_loss: 0.022485405 val_loss: 0.5055947
# Step = 578 train_loss: 0.03821365 val_loss: 0.49928224
# Step = 579 train_loss: 0.026932804 val_loss: 0.4852679
# Step = 580 train_loss: 0.023377042 val_loss: 0.46424136
# Step = 581 train_loss: 0.026374834 val_loss: 0.43444467
# Step = 582 train_loss: 0.018531198 val_loss: 0.3946592
# Step = 583 train_loss: 0.028549375 val_loss: 0.3367514
# Step = 584 train_loss: 0.033582542 val_loss: 0.25788563
# Step = 585 train_loss: 0.019177489 val_loss: 0.17584231
# Step = 586 train_loss: 0.023644704 val_loss: 0.102266066
# Step = 587 train_loss: 0.014286857 val_loss: 0.045788698
# Step = 588 train_loss: 0.021148456 val_loss: 0.018005352
# Step = 589 train_loss: 0.027593961 val_loss: 0.010729013
# Step = 590 train_loss: 0.029822309 val_loss: 0.013218706
# Step = 591 train_loss: 0.017817315 val_loss: 0.017665349
# Step = 592 train_loss: 0.01781982 val_loss: 0.023066217
# Step = 593 train_loss: 0.025411503 val_loss: 0.030001195
# Step = 594 train_loss: 0.022129439 val_loss: 0.039298195
# Step = 595 train_loss: 0.013699482 val_loss: 0.048569884
# Step = 596 train_loss: 0.02681212 val_loss: 0.056060407
# Step = 597 train_loss: 0.019261062 val_loss: 0.06068118
# Step = 598 train_loss: 0.023847349 val_loss: 0.06489999
# Step = 599 train_loss: 0.02494606 val_loss: 0.06725068
# Step = 600 train_loss: 0.027488487 val_loss: 0.069790594
# Step = 601 train_loss: 0.029470665 val_loss: 0.07297409
# Step = 602 train_loss: 0.031110333 val_loss: 0.07528852
# Step = 603 train_loss: 0.016658874 val_loss: 0.076739095
# Step = 604 train_loss: 0.015339116 val_loss: 0.076278776
# Step = 605 train_loss: 0.018213259 val_loss: 0.075647555
# Step = 606 train_loss: 0.029005477 val_loss: 0.074873365
# Step = 607 train_loss: 0.028150132 val_loss: 0.07479512
# Step = 608 train_loss: 0.016615443 val_loss: 0.077108696
# Step = 609 train_loss: 0.01835111 val_loss: 0.080038354
# Step = 610 train_loss: 0.025207253 val_loss: 0.08272571
# Step = 611 train_loss: 0.02015784 val_loss: 0.084510416
# Step = 612 train_loss: 0.026315706 val_loss: 0.085902385
# Step = 613 train_loss: 0.024978757 val_loss: 0.0858917
# Step = 614 train_loss: 0.021190058 val_loss: 0.08274827
# Step = 615 train_loss: 0.025475118 val_loss: 0.073393635
# Step = 616 train_loss: 0.02088217 val_loss: 0.0598593
# Step = 617 train_loss: 0.023680221 val_loss: 0.045269042
# Step = 618 train_loss: 0.017229972 val_loss: 0.030968219
# Step = 619 train_loss: 0.031262137 val_loss: 0.010635394
# Step = 620 train_loss: 0.024488974 val_loss: 0.019261384
# Step = 621 train_loss: 0.024076661 val_loss: 0.22472522
# Step = 622 train_loss: 0.023101248 val_loss: 0.4315983
# Step = 623 train_loss: 0.029913306 val_loss: 0.47206748
# Step = 624 train_loss: 0.016798109 val_loss: 0.4956423
# Step = 625 train_loss: 0.017820789 val_loss: 0.5085853
# Step = 626 train_loss: 0.019219358 val_loss: 0.50944275
# Step = 627 train_loss: 0.025223285 val_loss: 0.5094481
# Step = 628 train_loss: 0.010371488 val_loss: 0.50942516
# Step = 629 train_loss: 0.024539897 val_loss: 0.5094185
# Step = 630 train_loss: 0.02828599 val_loss: 0.5094227
# Step = 631 train_loss: 0.019031439 val_loss: 0.50944144
# Step = 632 train_loss: 0.017549092 val_loss: 0.5094523
# Step = 633 train_loss: 0.018529482 val_loss: 0.509442
# Step = 634 train_loss: 0.017688675 val_loss: 0.50939274
# Step = 635 train_loss: 0.019766582 val_loss: 0.50927013
# Step = 636 train_loss: 0.021723837 val_loss: 0.50898945
# Step = 637 train_loss: 0.021035265 val_loss: 0.5084897
# Step = 638 train_loss: 0.04022259 val_loss: 0.5076409
# Step = 639 train_loss: 0.015436631 val_loss: 0.50623757
# Step = 640 train_loss: 0.029867096 val_loss: 0.50383925
# Step = 641 train_loss: 0.032144018 val_loss: 0.49948707
# Step = 642 train_loss: 0.026092775 val_loss: 0.49315634
# Step = 643 train_loss: 0.01711404 val_loss: 0.484019
# Step = 644 train_loss: 0.019266378 val_loss: 0.47276503
# Step = 645 train_loss: 0.030850274 val_loss: 0.45971483
# Step = 646 train_loss: 0.030183613 val_loss: 0.44021365
# Step = 647 train_loss: 0.012737783 val_loss: 0.41032225
# Step = 648 train_loss: 0.025196834 val_loss: 0.36636886
# Step = 649 train_loss: 0.017072681 val_loss: 0.30753487
# Step = 650 train_loss: 0.026198583 val_loss: 0.23711641
# Step = 651 train_loss: 0.026382904 val_loss: 0.16511539
# Step = 652 train_loss: 0.022782184 val_loss: 0.0987725
# Step = 653 train_loss: 0.012394019 val_loss: 0.049473014
# Step = 654 train_loss: 0.029881014 val_loss: 0.021570938
# Step = 655 train_loss: 0.026642399 val_loss: 0.011309966
# Step = 656 train_loss: 0.017805012 val_loss: 0.013789219
# Step = 657 train_loss: 0.017418096 val_loss: 0.022282757
# Step = 658 train_loss: 0.021751072 val_loss: 0.03289995
# Step = 659 train_loss: 0.013688926 val_loss: 0.04434337
# Step = 660 train_loss: 0.022439202 val_loss: 0.05435649
# Step = 661 train_loss: 0.022333503 val_loss: 0.0618609
# Step = 662 train_loss: 0.017698381 val_loss: 0.067197144
# Step = 663 train_loss: 0.021031084 val_loss: 0.07146784
# Step = 664 train_loss: 0.025847066 val_loss: 0.07413831
# Step = 665 train_loss: 0.028516505 val_loss: 0.07609005
# Step = 666 train_loss: 0.023091666 val_loss: 0.07749745
# Step = 667 train_loss: 0.02768421 val_loss: 0.07851402
# Step = 668 train_loss: 0.025564164 val_loss: 0.079413794
# Step = 669 train_loss: 0.026471432 val_loss: 0.08027655
# Step = 670 train_loss: 0.029876955 val_loss: 0.08082428
# Step = 671 train_loss: 0.018183881 val_loss: 0.08114956
# Step = 672 train_loss: 0.020546209 val_loss: 0.08198039
# Step = 673 train_loss: 0.015843483 val_loss: 0.082483746
# Step = 674 train_loss: 0.031240996 val_loss: 0.08274341
# Step = 675 train_loss: 0.025869887 val_loss: 0.08292551
# Step = 676 train_loss: 0.030773051 val_loss: 0.08289573
# Step = 677 train_loss: 0.029039519 val_loss: 0.08297079
# Step = 678 train_loss: 0.021756949 val_loss: 0.08323004
# Step = 679 train_loss: 0.021039508 val_loss: 0.08319965
# Step = 680 train_loss: 0.01829754 val_loss: 0.083293885
# Step = 681 train_loss: 0.021614201 val_loss: 0.083217986
# Step = 682 train_loss: 0.027856957 val_loss: 0.083089374
# Step = 683 train_loss: 0.020394104 val_loss: 0.08285793
# Step = 684 train_loss: 0.018524978 val_loss: 0.082576334
# Step = 685 train_loss: 0.0176833 val_loss: 0.08237168
# Step = 686 train_loss: 0.01904701 val_loss: 0.082170315
# Step = 687 train_loss: 0.02898666 val_loss: 0.08193323
# Step = 688 train_loss: 0.017443527 val_loss: 0.08183279
# Step = 689 train_loss: 0.020360235 val_loss: 0.08163509
# Step = 690 train_loss: 0.020601245 val_loss: 0.08168402
# Step = 691 train_loss: 0.032445576 val_loss: 0.081592575
# Step = 692 train_loss: 0.02757848 val_loss: 0.081519
# Step = 693 train_loss: 0.024937373 val_loss: 0.08142562
# Step = 694 train_loss: 0.026455302 val_loss: 0.08131527
# Step = 695 train_loss: 0.012551851 val_loss: 0.08126427
# Step = 696 train_loss: 0.025910137 val_loss: 0.08122653
# Step = 697 train_loss: 0.022023818 val_loss: 0.08094815
# Step = 698 train_loss: 0.020892613 val_loss: 0.08104633
# Step = 699 train_loss: 0.018012386 val_loss: 0.080958225
# Step = 700 train_loss: 0.02071743 val_loss: 0.08087024
# Step = 701 train_loss: 0.0154915005 val_loss: 0.080776155
# Step = 702 train_loss: 0.011846334 val_loss: 0.080425724
# Step = 703 train_loss: 0.018381264 val_loss: 0.08027884
# Step = 704 train_loss: 0.02804843 val_loss: 0.08032698
# Step = 705 train_loss: 0.03185535 val_loss: 0.08009158
# Step = 706 train_loss: 0.017908664 val_loss: 0.08007548
# Step = 707 train_loss: 0.021640463 val_loss: 0.08020372
# Step = 708 train_loss: 0.021903683 val_loss: 0.08036217
# Step = 709 train_loss: 0.034182426 val_loss: 0.08038461
# Step = 710 train_loss: 0.010565826 val_loss: 0.080400504
# Step = 711 train_loss: 0.025583684 val_loss: 0.080387056
# Step = 712 train_loss: 0.019787261 val_loss: 0.080427565
# Step = 713 train_loss: 0.016450696 val_loss: 0.0805265
# Step = 714 train_loss: 0.015024439 val_loss: 0.08066305
# Step = 715 train_loss: 0.01631562 val_loss: 0.08085035
# Step = 716 train_loss: 0.019799681 val_loss: 0.08103844
# Step = 717 train_loss: 0.026751105 val_loss: 0.08092036
# Step = 718 train_loss: 0.022615941 val_loss: 0.08102986
# Step = 719 train_loss: 0.013856489 val_loss: 0.081519775
# Step = 720 train_loss: 0.020738162 val_loss: 0.08198796
# Step = 721 train_loss: 0.026684415 val_loss: 0.08223561
# Step = 722 train_loss: 0.029604722 val_loss: 0.08233446
# Step = 723 train_loss: 0.034706436 val_loss: 0.082425825
# Step = 724 train_loss: 0.029750934 val_loss: 0.08244201
# Step = 725 train_loss: 0.018591573 val_loss: 0.082637794
# Step = 726 train_loss: 0.02876088 val_loss: 0.08265454
# Step = 727 train_loss: 0.026976397 val_loss: 0.08280458
# Step = 728 train_loss: 0.01795003 val_loss: 0.08291095
# Step = 729 train_loss: 0.017898984 val_loss: 0.08331769
# Step = 730 train_loss: 0.027658492 val_loss: 0.08344636
# Step = 731 train_loss: 0.015826706 val_loss: 0.08334966
# Step = 732 train_loss: 0.015226887 val_loss: 0.08328803
# Step = 733 train_loss: 0.01753224 val_loss: 0.08305943
# Step = 734 train_loss: 0.0208253 val_loss: 0.08326705
# Step = 735 train_loss: 0.019191844 val_loss: 0.0833942
# Step = 736 train_loss: 0.019218069 val_loss: 0.08346385
# Step = 737 train_loss: 0.023194134 val_loss: 0.08379049
# Step = 738 train_loss: 0.022871925 val_loss: 0.08410979
# Step = 739 train_loss: 0.022202482 val_loss: 0.08425685
# Step = 740 train_loss: 0.016467106 val_loss: 0.08461939
# Step = 741 train_loss: 0.011705096 val_loss: 0.08524876
# Step = 742 train_loss: 0.018628635 val_loss: 0.085442424
# Step = 743 train_loss: 0.01783687 val_loss: 0.085990414
# Step = 744 train_loss: 0.029062502 val_loss: 0.08650294
# Step = 745 train_loss: 0.01776147 val_loss: 0.08679172
# Step = 746 train_loss: 0.012965782 val_loss: 0.086641
# Step = 747 train_loss: 0.014507965 val_loss: 0.08646704
# Step = 748 train_loss: 0.019770432 val_loss: 0.086436614
# Step = 749 train_loss: 0.024464888 val_loss: 0.08659928
# Step = 750 train_loss: 0.029219253 val_loss: 0.0864758
# Step = 751 train_loss: 0.016934223 val_loss: 0.08653686
# Step = 752 train_loss: 0.015699046 val_loss: 0.0869761
# Step = 753 train_loss: 0.024643932 val_loss: 0.08732263
# Step = 754 train_loss: 0.022307437 val_loss: 0.08792131
# Step = 755 train_loss: 0.036146272 val_loss: 0.0884139
# Step = 756 train_loss: 0.025159081 val_loss: 0.088487215
# Step = 757 train_loss: 0.016110964 val_loss: 0.08837769
# Step = 758 train_loss: 0.025346043 val_loss: 0.08833703
# Step = 759 train_loss: 0.01554667 val_loss: 0.088558055
# Step = 760 train_loss: 0.020708283 val_loss: 0.08850474
# Step = 761 train_loss: 0.017870683 val_loss: 0.088461414
# Step = 762 train_loss: 0.024615468 val_loss: 0.08835557
# Step = 763 train_loss: 0.02067828 val_loss: 0.08834446
# Step = 764 train_loss: 0.022460481 val_loss: 0.08877846
# Step = 765 train_loss: 0.027859876 val_loss: 0.08837055
# Step = 766 train_loss: 0.01660287 val_loss: 0.088544026
# Step = 767 train_loss: 0.028857915 val_loss: 0.08802159
# Step = 768 train_loss: 0.023306089 val_loss: 0.088022195
# Step = 769 train_loss: 0.02269382 val_loss: 0.08811417
# Step = 770 train_loss: 0.023334868 val_loss: 0.08857005
# Step = 771 train_loss: 0.025230596 val_loss: 0.0887776
# Step = 772 train_loss: 0.018276665 val_loss: 0.0890373
# Step = 773 train_loss: 0.025921514 val_loss: 0.089680366
# Step = 774 train_loss: 0.0146389855 val_loss: 0.08979071
# Step = 775 train_loss: 0.01942127 val_loss: 0.090021774
# Step = 776 train_loss: 0.026300319 val_loss: 0.09033714
# Step = 777 train_loss: 0.018216902 val_loss: 0.0910729
# Step = 778 train_loss: 0.022483734 val_loss: 0.09178667
# Step = 779 train_loss: 0.02157884 val_loss: 0.09224797
# Step = 780 train_loss: 0.027066015 val_loss: 0.09246623
# Step = 781 train_loss: 0.01967143 val_loss: 0.0923186
# Step = 782 train_loss: 0.021298321 val_loss: 0.09154766
# Step = 783 train_loss: 0.023974726 val_loss: 0.090876624
# Step = 784 train_loss: 0.019699961 val_loss: 0.09053011
# Step = 785 train_loss: 0.01804505 val_loss: 0.091488995
# Step = 786 train_loss: 0.020255623 val_loss: 0.09261802
# Step = 787 train_loss: 0.01524885 val_loss: 0.09259382
# Step = 788 train_loss: 0.023413049 val_loss: 0.09191702
# Step = 789 train_loss: 0.014936799 val_loss: 0.09021584
# Step = 790 train_loss: 0.022080125 val_loss: 0.087068304
# Step = 791 train_loss: 0.019081768 val_loss: 0.08381217
# Step = 792 train_loss: 0.027216528 val_loss: 0.08197815
# Step = 793 train_loss: 0.013397958 val_loss: 0.08169546
# Step = 794 train_loss: 0.013022721 val_loss: 0.08211476
# Step = 795 train_loss: 0.015124483 val_loss: 0.08230117
# Step = 796 train_loss: 0.021109028 val_loss: 0.08173948
# Step = 797 train_loss: 0.018501494 val_loss: 0.078814596
# Step = 798 train_loss: 0.011141878 val_loss: 0.07569507
# Step = 799 train_loss: 0.025331251 val_loss: 0.070781
# Best model at index: 545
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_7104\1978983123.py:109: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('Best_target_model/net_parameters.pkl')

# %%
# history = np.DataFrame(columns=['index','train_loss', 'val_loss'])
#画出训练过程中的loss变化曲线
plt.plot(history['train_loss'], label='train_loss')
plt.plot(history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''Prediction using the best model'''
predict_labels_a=[]
predict_labels_b=[]
predict_labels_train=[]
predict_labels_val = []
model.eval()
with torch.no_grad():
    predict_labels_a.append(model(input_test_a).data.numpy())
    predict_labels_b.append(model(input_test_b).data.numpy())
    
    predict_labels_train.append(model(input_train).data.numpy())   
    predict_labels_val.append(model(input_val).data.numpy())      


actual_label_arr_train=np.round(np.asarray(train_labels*max_label).reshape(-1,1))  
predict_label_arr_train=np.round(np.asarray(predict_labels_train).reshape(-1,1)*max_label)


actual_label_arr_val=np.round(np.asarray(val_labels*max_label).reshape(-1,1))   
predict_label_arr_val=np.round(np.asarray(predict_labels_val).reshape(-1,1)*max_label)


actual_label_arr_a=np.round(np.asarray(test_cycle_life_a*max_label).reshape(-1,1))   
predict_label_arr_a=np.round(np.asarray(predict_labels_a).reshape(-1,1)*max_label)


actual_label_arr_b=np.round(np.asarray(test_cycle_life_b * max_label).reshape(-1,1))   
predict_label_arr_b=np.round(np.asarray(predict_labels_b).reshape(-1,1)*max_label)

# %%
'''Plot the predicted cycle lives'''
plt.scatter(actual_label_arr_train, predict_label_arr_train,s=50,c='k')
plt.scatter(actual_label_arr_val, predict_label_arr_val,s=50,c='b')
plt.scatter(actual_label_arr_a, predict_label_arr_a,s=50,c='r')
plt.scatter(actual_label_arr_b, predict_label_arr_b,s=50,c='g')
plt.plot([100,2500],[100,2500])


'''Evaluation metrics'''
mpe_a=np.mean(np.abs(predict_label_arr_a-actual_label_arr_a)/actual_label_arr_a)
mpe_b=np.mean(np.abs(predict_label_arr_b-actual_label_arr_b)/actual_label_arr_b)
mpe_train = np.mean(np.abs(predict_label_arr_train-actual_label_arr_train)/actual_label_arr_train)
mpe_val = np.mean(np.abs(predict_label_arr_val-actual_label_arr_val)/actual_label_arr_val)


rmse_a=np.sqrt(np.mean((predict_label_arr_a-actual_label_arr_a)**2))
rmse_b=np.sqrt(np.mean((predict_label_arr_b-actual_label_arr_b)**2))
rmse_train=np.sqrt(np.mean((predict_label_arr_train-actual_label_arr_train)**2))
rmse_val=np.sqrt(np.mean((predict_label_arr_val-actual_label_arr_val)**2))


print ('mpe_train:',mpe_train)
print ('mpe_val:',mpe_val)
print ('mpe_a:',mpe_a)
print ('mpe_b:',mpe_b)

print ('rmse_train:', rmse_train)
print ('rmse_val:', rmse_val)
print ('rmse_a:', rmse_a)
print ('rmse_b:', rmse_b)
# Out:
# mpe_train: 0.2665594
# mpe_val: 0.24974865
# mpe_a: 0.2788528665659514
# mpe_b: 0.17339175995288048
# rmse_train: 237.36803
# rmse_val: 208.32304
# rmse_a: 242.50945797907002
# rmse_b: 231.55647259362024

# %%
from sklearn.metrics import r2_score
r2_a = r2_score(actual_label_arr_a, predict_label_arr_a)
r2_b = r2_score(actual_label_arr_b, predict_label_arr_b)
r2_train = r2_score(actual_label_arr_train, predict_label_arr_train)
r2_val = r2_score(actual_label_arr_val, predict_label_arr_val)

print('r2_train:', r2_train)
print('r2_val:', r2_val)
print('r2_a:', r2_a)
print('r2_b:', r2_b)
# Out:
# r2_train: 0.6115248203277588
# r2_val: 0.5830804109573364
# r2_a: 0.6146357575033983
# r2_b: 0.3403931284154089
