# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary
from sklearn.model_selection import train_test_split
import shutil

'''Load data'''
temp_Qd = np.load('Data_processed/Qd_100.npy',allow_pickle=True).item()
temp_life = np.load('Data_processed/cycle_life.npy',allow_pickle=True).item()
all_capacity = np.load('Data_processed/all_capacity.npy',allow_pickle=True).item()
temp_Qd_all = []
temp_life_all = []
all_capacity_all = []

for key in temp_Qd.keys():
    temp_life_all.append(temp_life[key])
    all_capacity_all.append(all_capacity[key])
    temp_Qd_list = []
    for item in temp_Qd[key]:
        temp_Qd_list.append(item)
    temp_Qd_arr = np.asarray(temp_Qd_list)
    temp_Qd_all.append(temp_Qd_arr)
all_Qd_arr = np.asarray(temp_Qd_all)
cycle_life_arr = np.asarray(temp_life_all)    


'''Divide the dataset as the original paper stated'''
test_ind = np.hstack((np.arange(0,(41+43),2),83))
train_ind = np.arange(1,(41+43-1),2)
secondary_test_ind = np.arange(124-40,124)

all_keys = list(temp_Qd.keys())
train_keys = [all_keys[inx] for inx in train_ind]
test_keys = [all_keys[inx] for inx in test_ind]
secondary_test_keys = [all_keys[inx] for inx in secondary_test_ind]

cycle_life_arr=np.asarray(cycle_life_arr).reshape(-1,1)
max_label=np.max(cycle_life_arr)
cycle_life_arr=cycle_life_arr/max_label


train_Qds = np.asarray(all_Qd_arr)[train_ind]
train_cycle_lifes = np.asarray(cycle_life_arr)[train_ind]

test_Qd_a = np.asarray(all_Qd_arr)[test_ind]
test_cycle_life_a = np.asarray(cycle_life_arr)[test_ind]

test_Qd_b = np.asarray(all_Qd_arr)[secondary_test_ind]
test_cycle_life_b = np.asarray(cycle_life_arr)[secondary_test_ind]

train_Qd, _, train_cycle_life, _ = train_test_split(train_Qds, train_cycle_lifes, test_size=0.36, random_state=3)

# %%
# pip install einops

# %%
import torch
import torch.nn as nn
from einops import rearrange

def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')
def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)

class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class SEbox(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(SEbox, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.se = SELayer(out_channel)
        self.cbam = CBAM(out_channel)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = x + self.se(x)
        x = self.dropout(x)
        x = self.cbam(x)
        return x
    
class cnn_box(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(cnn_box, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.dropout(x)
        return x
    
class CBAM(nn.Module):
    def __init__(self, in_channel, reduction=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.max_pool = nn.AdaptiveMaxPool2d(output_size=1)
        self.avg_pool = nn.AdaptiveAvgPool2d(output_size=1)
        self.mlp = nn.Sequential(
            nn.Linear(in_features=in_channel, out_features=in_channel // reduction, bias=False),
            nn.ReLU(),
            nn.Linear(in_features=in_channel // reduction, out_features=in_channel, bias=False)
        )
        self.sigmoid = nn.Sigmoid()
        self.conv = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False)

    def forward(self, x):
        maxout = self.max_pool(x)
        avgout = self.avg_pool(x)
        channel_out = self.sigmoid(self.mlp(maxout.view(maxout.size(0), -1)) + self.mlp(avgout.view(avgout.size(0), -1)))
        channel_out = channel_out.view(x.size(0), x.size(1), 1, 1) * x
        max_out = torch.max(channel_out, dim=1, keepdim=True)[0]
        mean_out = torch.mean(channel_out, dim=1, keepdim=True)
        out = self.sigmoid(self.conv(torch.cat((max_out, mean_out), dim=1))) * channel_out
        return out

class InceptionModule(torch.nn.Module):
    def __init__(self, in_channels=64, out_channels=64):
        super(InceptionModule, self).__init__()
        
        self.inceptions = torch.nn.ModuleList([
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(3, 3), stride=1, padding=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(5, 5), stride=1, padding=2),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
            )
        ])

    def forward(self, x):
        # 将输入传递给所有Inception模块，并将输出连接起来
        outputs = [inception(x) for inception in self.inceptions]
        return torch.cat(outputs, dim=1)  # 这里按通道维度连接输出

# 使用示例
# model = InceptionModule(in_channels=32, out_channels=64)
# output = model(input_tensor)  # input_tensor 是你的输入数据

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=1),
            nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(8, 16, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(16),
            torch.nn.LeakyReLU(inplace=True),
            torch.nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(16, 32, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(32),
            torch.nn.LeakyReLU(inplace=True),            
            
        )
        self.go = InceptionModule()
        self.sebox1 = SEbox(64,64,kernel_size=1,stride=1,padding=1)
        
        
        self.lstm = nn.LSTM(32, 32, num_layers=2, bidirectional=True, batch_first=True)
        self.fc1 = nn.Linear(58368, 1)
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        try:
            x = self.layers1(x)
            # print(f"层1输出形状: {x.shape}")
            x = to_3d(x)
            x,_ = self.lstm(x)
            # x = x[:, -1, :]
            # print(f"LSTM后输出形状: {x.shape}")
            x = to_4d(x,8,19)
            se = self.sebox1(x)
            crop_se = se[:,:,:8,:19]
            go = self.go(x)
            # print(f"SEbox后输出形状: {se.se}")
            # print(f"InceptionModule后输出形状: {go.shape}")
            x = torch.cat((x, crop_se, go), dim=1)
            # print(f"拼接后输出形状: {x.shape}")
            return torch.sigmoid(self.fc1(x.view(x.size(0), -1)))
        except RuntimeError as e:
            print(f"运行时错误：{e}")
            return None
        except Exception as e:
            print(f"发生意外错误：{e}")
            raise  # 重新抛出异常，以便进一步处理

# %%
net = Net()     # define the network
print(net)      # net architecture
# summary(net,(1,100,1000))
# Out:
# Net(
#   (layers1): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Conv2d(8, 16, kernel_size=(2, 3), stride=(1, 1))
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Conv2d(16, 32, kernel_size=(2, 3), stride=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (go): InceptionModule(
#     (inceptions): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (3): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (sebox1): SEbox(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     (se): SELayer(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=4, out_features=64, bias=False)
#         (3): Sigmoid()
#       )
#     )
#     (cbam): CBAM(
#       (max_pool): AdaptiveMaxPool2d(output_size=1)
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (mlp): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU()
#         (2): Linear(in_features=4, out_features=64, bias=False)
#       )
#       (sigmoid): Sigmoid()
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     )
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (lstm): LSTM(32, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=58368, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
import pandas as pd
import torch.optim as optim
'''Data loader for Pytorch'''
input_train = torch.FloatTensor(train_Qd)
input_train = torch.unsqueeze(input_train, 1)
train_labels = torch.FloatTensor(train_cycle_life)

input_val = torch.FloatTensor(train_Qds)
input_val = torch.unsqueeze(input_val, 1)
val_labels = torch.FloatTensor(train_cycle_lifes)

input_test_a = torch.FloatTensor(test_Qd_a)
input_test_a = torch.unsqueeze(input_test_a, 1)
test_labels_a = torch.FloatTensor(test_cycle_life_a)

input_test_b = torch.FloatTensor(test_Qd_b)
input_test_b = torch.unsqueeze(input_test_b, 1)
test_labels_b = torch.FloatTensor(test_cycle_life_b)



seed = 17
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed)    # reproducible    



optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)
loss_func = torch.nn.MSELoss() 

# # 动态调整学习率
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: 0.8 ** (epoch // 40))

# # 将学习率调度器修改为指数下降
# initial_lr = 0.0001  # 初始学习率
# decay_rate = 0.96  # 每个epoch衰减的比例
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: decay_rate ** epoch)

# 假设你已经定义了模型和优化器
# 当验证损失不下降时，减少学习率
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.8, patience=5)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# 创建历史记录DataFrame
history = pd.DataFrame(columns=['index', 'train_loss', 'val_loss'])
val_losses = []
max_models_to_keep = 10
saved_models=[]
import os

import datetime

log_file_path = 'train_log.txt'  # 请替换为实际的日志文件路径

# 初始化日志文件，并且第一行记录时间跟训练参数
with open(log_file_path, 'w') as log_file:
    log_file.write('Time: {}\n'.format(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
    # log_file.write('Training parameters: {}\n'.format(str(vars(args))))

for t in range(1000):
    net.train()
    train_prediction = net(input_train)
    train_loss = loss_func(train_prediction, train_labels)
   
    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    # 保存模型
    model_path = 'Target_model/net_parameters'+str(t)+'.pkl'
    torch.save({
        'epoch': t,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()}, model_path)

    net.eval()
    with torch.no_grad():
        val_prediction = net(input_val)
        val_loss = loss_func(val_prediction, val_labels)
    
    print('Step = %d' % t, 'train_loss:', train_loss.data.numpy(), 'val_loss:', val_loss.data.numpy())


# 打开文件并写入内容
    with open(log_file_path, 'a') as log_file:  # 'a'模式表示追加写入
        log_file.write('Step = %d, train_loss: %s, val_loss: %s\n' % (t, train_loss.data.numpy(), val_loss.data.numpy()))
        
    val_losses.append(val_loss.item())
    
    # 添加当前模型及其验证损失
    saved_models.append((val_loss.item(), model_path))

    # 保持模型数量不超过max_models_to_keep
    if len(saved_models) > max_models_to_keep:
        # 找到验证损失最大的一组模型并删除
        saved_models.sort(key=lambda x: x[0])  # 排序，根据损失
        os.remove(saved_models.pop()[1])  # 删除损失最大的模型
    # 加入训练历史记录
    # 创建新的一行数据
    new_entry = pd.DataFrame({'index': [t], 'train_loss': [train_loss.item()], 'val_loss': [val_loss.item()]})
    
    # 使用concat进行数据合并
    history = pd.concat([history, new_entry], ignore_index=True)

'''find the best model'''
best_index = val_losses.index(np.min(val_losses))
print(f'Best model at index: {best_index}')
print(f'Best model val_loss: {val_losses[best_index]}')

'''copy the best model from model file to the model_test file'''
shutil.copyfile(f'Target_model/net_parameters{best_index}.pkl', 'Best_target_model/net_parameters.pkl')


'''Reload the best model''' 
model = Net()
checkpoint = torch.load('Best_target_model/net_parameters.pkl')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Step = 0 train_loss: 0.038562793 val_loss: 0.04793758
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_21860\2966303312.py:111: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   history = pd.concat([history, new_entry], ignore_index=True)
# Step = 1 train_loss: 0.0783887 val_loss: 0.046985645
# Step = 2 train_loss: 0.07703386 val_loss: 0.04950524
# Step = 3 train_loss: 0.058764238 val_loss: 0.054589864
# Step = 4 train_loss: 0.029797284 val_loss: 0.058308695
# Step = 5 train_loss: 0.07692436 val_loss: 0.055158395
# Step = 6 train_loss: 0.041951377 val_loss: 0.04929279
# Step = 7 train_loss: 0.035802796 val_loss: 0.04461093
# Step = 8 train_loss: 0.043139644 val_loss: 0.042439442
# Step = 9 train_loss: 0.04702914 val_loss: 0.042317834
# Step = 10 train_loss: 0.044146597 val_loss: 0.044103723
# Step = 11 train_loss: 0.026314873 val_loss: 0.0468035
# Step = 12 train_loss: 0.040392257 val_loss: 0.05200686
# Step = 13 train_loss: 0.03681039 val_loss: 0.052456554
# Step = 14 train_loss: 0.04566461 val_loss: 0.048284765
# Step = 15 train_loss: 0.019270433 val_loss: 0.044652015
# Step = 16 train_loss: 0.0180368 val_loss: 0.040728875
# Step = 17 train_loss: 0.02300333 val_loss: 0.0384539
# Step = 18 train_loss: 0.024256248 val_loss: 0.037406847
# Step = 19 train_loss: 0.019283496 val_loss: 0.037301604
# Step = 20 train_loss: 0.019496014 val_loss: 0.038405947
# Step = 21 train_loss: 0.028369445 val_loss: 0.040276177
# Step = 22 train_loss: 0.019473633 val_loss: 0.041541863
# Step = 23 train_loss: 0.023447303 val_loss: 0.041730586
# Step = 24 train_loss: 0.03168395 val_loss: 0.03964665
# Step = 25 train_loss: 0.021203972 val_loss: 0.037044168
# Step = 26 train_loss: 0.017741159 val_loss: 0.034255944
# Step = 27 train_loss: 0.02161513 val_loss: 0.03142322
# Step = 28 train_loss: 0.01884716 val_loss: 0.029556181
# Step = 29 train_loss: 0.029069869 val_loss: 0.028493041
# Step = 30 train_loss: 0.018788798 val_loss: 0.027774397
# Step = 31 train_loss: 0.020808466 val_loss: 0.026788495
# Step = 32 train_loss: 0.017964225 val_loss: 0.025514143
# Step = 33 train_loss: 0.016810583 val_loss: 0.023982614
# Step = 34 train_loss: 0.021963567 val_loss: 0.02284456
# Step = 35 train_loss: 0.024397787 val_loss: 0.021811362
# Step = 36 train_loss: 0.016352452 val_loss: 0.02096134
# Step = 37 train_loss: 0.011253392 val_loss: 0.020534247
# Step = 38 train_loss: 0.012507154 val_loss: 0.02041572
# Step = 39 train_loss: 0.033756807 val_loss: 0.02044877
# Step = 40 train_loss: 0.020920673 val_loss: 0.020371625
# Step = 41 train_loss: 0.011206531 val_loss: 0.020357462
# Step = 42 train_loss: 0.01272829 val_loss: 0.020786803
# Step = 43 train_loss: 0.022505233 val_loss: 0.030209318
# Step = 44 train_loss: 0.019460203 val_loss: 0.05120852
# Step = 45 train_loss: 0.013259014 val_loss: 0.078900486
# Step = 46 train_loss: 0.015675671 val_loss: 0.10676873
# Step = 47 train_loss: 0.014307406 val_loss: 0.13290174
# Step = 48 train_loss: 0.016545054 val_loss: 0.1547721
# Step = 49 train_loss: 0.01834154 val_loss: 0.16794956
# Step = 50 train_loss: 0.014721224 val_loss: 0.17819284
# Step = 51 train_loss: 0.012445905 val_loss: 0.18005942
# Step = 52 train_loss: 0.0114060445 val_loss: 0.17582098
# Step = 53 train_loss: 0.018012337 val_loss: 0.16629249
# Step = 54 train_loss: 0.014661067 val_loss: 0.15196978
# Step = 55 train_loss: 0.008666968 val_loss: 0.13910662
# Step = 56 train_loss: 0.011010402 val_loss: 0.12740509
# Step = 57 train_loss: 0.031173747 val_loss: 0.11477742
# Step = 58 train_loss: 0.018647036 val_loss: 0.10190348
# Step = 59 train_loss: 0.01129802 val_loss: 0.08965911
# Step = 60 train_loss: 0.018398764 val_loss: 0.0744608
# Step = 61 train_loss: 0.015613165 val_loss: 0.0609491
# Step = 62 train_loss: 0.013070672 val_loss: 0.047874447
# Step = 63 train_loss: 0.0069912886 val_loss: 0.035766374
# Step = 64 train_loss: 0.015793629 val_loss: 0.025992341
# Step = 65 train_loss: 0.016003432 val_loss: 0.018483844
# Step = 66 train_loss: 0.011057894 val_loss: 0.015336731
# Step = 67 train_loss: 0.012023696 val_loss: 0.013679167
# Step = 68 train_loss: 0.013921129 val_loss: 0.013048745
# Step = 69 train_loss: 0.010265905 val_loss: 0.013007739
# Step = 70 train_loss: 0.015419634 val_loss: 0.013341227
# Step = 71 train_loss: 0.009529235 val_loss: 0.013604538
# Step = 72 train_loss: 0.008023651 val_loss: 0.013828143
# Step = 73 train_loss: 0.010298913 val_loss: 0.014314365
# Step = 74 train_loss: 0.011817976 val_loss: 0.015117368
# Step = 75 train_loss: 0.009510606 val_loss: 0.016331054
# Step = 76 train_loss: 0.013847356 val_loss: 0.017932646
# Step = 77 train_loss: 0.01030601 val_loss: 0.019305604
# Step = 78 train_loss: 0.008552726 val_loss: 0.029717617
# Step = 79 train_loss: 0.011901974 val_loss: 0.046409555
# Step = 80 train_loss: 0.014523824 val_loss: 0.052802615
# Step = 81 train_loss: 0.0075773965 val_loss: 0.057284664
# Step = 82 train_loss: 0.010031372 val_loss: 0.06053998
# Step = 83 train_loss: 0.008839933 val_loss: 0.06175973
# Step = 84 train_loss: 0.014331021 val_loss: 0.06069733
# Step = 85 train_loss: 0.011666899 val_loss: 0.058295205
# Step = 86 train_loss: 0.011291863 val_loss: 0.054326337
# Step = 87 train_loss: 0.01166564 val_loss: 0.048990905
# Step = 88 train_loss: 0.012735244 val_loss: 0.040200006
# Step = 89 train_loss: 0.016316513 val_loss: 0.03269101
# Step = 90 train_loss: 0.012622882 val_loss: 0.027575266
# Step = 91 train_loss: 0.0049989717 val_loss: 0.024960756
# Step = 92 train_loss: 0.011776163 val_loss: 0.022999626
# Step = 93 train_loss: 0.010242366 val_loss: 0.02164344
# Step = 94 train_loss: 0.013712267 val_loss: 0.021391338
# Step = 95 train_loss: 0.0063238745 val_loss: 0.02191954
# Step = 96 train_loss: 0.015950892 val_loss: 0.022993322
# Step = 97 train_loss: 0.012179986 val_loss: 0.02461381
# Step = 98 train_loss: 0.008944451 val_loss: 0.027029691
# Step = 99 train_loss: 0.009631826 val_loss: 0.030002562
# Step = 100 train_loss: 0.009282072 val_loss: 0.033098202
# Step = 101 train_loss: 0.009590876 val_loss: 0.036099616
# Step = 102 train_loss: 0.0109073585 val_loss: 0.038714424
# Step = 103 train_loss: 0.011554156 val_loss: 0.04086222
# Step = 104 train_loss: 0.014227261 val_loss: 0.041973863
# Step = 105 train_loss: 0.010333544 val_loss: 0.041916136
# Step = 106 train_loss: 0.007390777 val_loss: 0.04069801
# Step = 107 train_loss: 0.012461027 val_loss: 0.039304733
# Step = 108 train_loss: 0.009378127 val_loss: 0.036001194
# Step = 109 train_loss: 0.008368467 val_loss: 0.03188069
# Step = 110 train_loss: 0.011548314 val_loss: 0.025221882
# Step = 111 train_loss: 0.007222463 val_loss: 0.019254513
# Step = 112 train_loss: 0.011358583 val_loss: 0.013676384
# Step = 113 train_loss: 0.015114004 val_loss: 0.012404064
# Step = 114 train_loss: 0.012725635 val_loss: 0.013031713
# Step = 115 train_loss: 0.013070964 val_loss: 0.019228887
# Step = 116 train_loss: 0.011750521 val_loss: 0.039079554
# Step = 117 train_loss: 0.012271251 val_loss: 0.076886944
# Step = 118 train_loss: 0.012584069 val_loss: 0.08709645
# Step = 119 train_loss: 0.013199847 val_loss: 0.0891403
# Step = 120 train_loss: 0.012234901 val_loss: 0.09015482
# Step = 121 train_loss: 0.009204971 val_loss: 0.090844944
# Step = 122 train_loss: 0.012493514 val_loss: 0.091495395
# Step = 123 train_loss: 0.008627962 val_loss: 0.09180489
# Step = 124 train_loss: 0.016383287 val_loss: 0.0918691
# Step = 125 train_loss: 0.017193215 val_loss: 0.061500665
# Step = 126 train_loss: 0.010626818 val_loss: 0.03998581
# Step = 127 train_loss: 0.012188698 val_loss: 0.04190301
# Step = 128 train_loss: 0.014984865 val_loss: 0.0504311
# Step = 129 train_loss: 0.0054769022 val_loss: 0.08708767
# Step = 130 train_loss: 0.0074330065 val_loss: 0.09478255
# Step = 131 train_loss: 0.009818192 val_loss: 0.09487921
# Step = 132 train_loss: 0.01295353 val_loss: 0.0949135
# Step = 133 train_loss: 0.006504235 val_loss: 0.09517179
# Step = 134 train_loss: 0.009094903 val_loss: 0.095804915
# Step = 135 train_loss: 0.009281731 val_loss: 0.09605674
# Step = 136 train_loss: 0.01119717 val_loss: 0.09648546
# Step = 137 train_loss: 0.011215227 val_loss: 0.0969136
# Step = 138 train_loss: 0.0070578237 val_loss: 0.097780645
# Step = 139 train_loss: 0.011960379 val_loss: 0.09612454
# Step = 140 train_loss: 0.008375182 val_loss: 0.09415373
# Step = 141 train_loss: 0.008037744 val_loss: 0.09452614
# Step = 142 train_loss: 0.013308227 val_loss: 0.09550405
# Step = 143 train_loss: 0.008898834 val_loss: 0.09805172
# Step = 144 train_loss: 0.0062321476 val_loss: 0.09847898
# Step = 145 train_loss: 0.012018824 val_loss: 0.09667835
# Step = 146 train_loss: 0.012023376 val_loss: 0.096474364
# Step = 147 train_loss: 0.009099708 val_loss: 0.094207674
# Step = 148 train_loss: 0.014637312 val_loss: 0.09143916
# Step = 149 train_loss: 0.005977773 val_loss: 0.0882846
# Step = 150 train_loss: 0.012253199 val_loss: 0.08551908
# Step = 151 train_loss: 0.007907814 val_loss: 0.07762954
# Step = 152 train_loss: 0.005598507 val_loss: 0.071777835
# Step = 153 train_loss: 0.008920171 val_loss: 0.067518145
# Step = 154 train_loss: 0.00952839 val_loss: 0.06448495
# Step = 155 train_loss: 0.011640359 val_loss: 0.062282342
# Step = 156 train_loss: 0.0075632976 val_loss: 0.06335558
# Step = 157 train_loss: 0.011384552 val_loss: 0.057560217
# Step = 158 train_loss: 0.009135169 val_loss: 0.05353907
# Step = 159 train_loss: 0.0058801593 val_loss: 0.053577363
# Step = 160 train_loss: 0.010937984 val_loss: 0.055476844
# Step = 161 train_loss: 0.006665252 val_loss: 0.05075045
# Step = 162 train_loss: 0.006293224 val_loss: 0.04915741
# Step = 163 train_loss: 0.006790989 val_loss: 0.048771195
# Step = 164 train_loss: 0.006221088 val_loss: 0.028346032
# Step = 165 train_loss: 0.007863707 val_loss: 0.44083568
# Step = 166 train_loss: 0.014655983 val_loss: 0.5090481
# Step = 167 train_loss: 0.006375687 val_loss: 0.5095539
# Step = 168 train_loss: 0.009833787 val_loss: 0.50956064
# Step = 169 train_loss: 0.017586399 val_loss: 0.50954616
# Step = 170 train_loss: 0.012448824 val_loss: 0.45525044
# Step = 171 train_loss: 0.010593403 val_loss: 0.1436496
# Step = 172 train_loss: 0.01666397 val_loss: 0.06322955
# Step = 173 train_loss: 0.011956693 val_loss: 0.022949554
# Step = 174 train_loss: 0.008224354 val_loss: 0.015492201
# Step = 175 train_loss: 0.018072791 val_loss: 0.04442624
# Step = 176 train_loss: 0.014608312 val_loss: 0.07167481
# Step = 177 train_loss: 0.017207388 val_loss: 0.087434806
# Step = 178 train_loss: 0.01589501 val_loss: 0.093791895
# Step = 179 train_loss: 0.014021254 val_loss: 0.097824015
# Step = 180 train_loss: 0.011690062 val_loss: 0.09830496
# Step = 181 train_loss: 0.012067025 val_loss: 0.098069295
# Step = 182 train_loss: 0.006663461 val_loss: 0.09693298
# Step = 183 train_loss: 0.010774771 val_loss: 0.09203981
# Step = 184 train_loss: 0.014135171 val_loss: 0.095033675
# Step = 185 train_loss: 0.011814614 val_loss: 0.0977398
# Step = 186 train_loss: 0.014928163 val_loss: 0.09929343
# Step = 187 train_loss: 0.017414542 val_loss: 0.09734051
# Step = 188 train_loss: 0.010934719 val_loss: 0.09010083
# Step = 189 train_loss: 0.010344754 val_loss: 0.07203175
# Step = 190 train_loss: 0.006166027 val_loss: 0.052874506
# Step = 191 train_loss: 0.0071925726 val_loss: 0.04262253
# Step = 192 train_loss: 0.0073182066 val_loss: 0.047853228
# Step = 193 train_loss: 0.010115615 val_loss: 0.059461072
# Step = 194 train_loss: 0.011534362 val_loss: 0.059224293
# Step = 195 train_loss: 0.008386947 val_loss: 0.046566095
# Step = 196 train_loss: 0.005766948 val_loss: 0.04531331
# Step = 197 train_loss: 0.011267514 val_loss: 0.053741094
# Step = 198 train_loss: 0.013856431 val_loss: 0.026305158
# Step = 199 train_loss: 0.011054016 val_loss: 0.50959086
# Step = 200 train_loss: 0.020340499 val_loss: 0.50959176
# Step = 201 train_loss: 0.009679109 val_loss: 0.5095924
# Step = 202 train_loss: 0.0078472495 val_loss: 0.5095925
# Step = 203 train_loss: 0.008432702 val_loss: 0.5095925
# Step = 204 train_loss: 0.01790428 val_loss: 0.5095925
# Step = 205 train_loss: 0.019033404 val_loss: 0.5094986
# Step = 206 train_loss: 0.015902556 val_loss: 0.5072421
# Step = 207 train_loss: 0.022910438 val_loss: 0.5031071
# Step = 208 train_loss: 0.028541092 val_loss: 0.50156623
# Step = 209 train_loss: 0.027111638 val_loss: 0.5056471
# Step = 210 train_loss: 0.0070857205 val_loss: 0.5077911
# Step = 211 train_loss: 0.021906924 val_loss: 0.50947297
# Step = 212 train_loss: 0.011357031 val_loss: 0.5095924
# Step = 213 train_loss: 0.01327674 val_loss: 0.5095925
# Step = 214 train_loss: 0.0326488 val_loss: 0.11130476
# Step = 215 train_loss: 0.030828167 val_loss: 0.07617312
# Step = 216 train_loss: 0.012570803 val_loss: 0.091032535
# Step = 217 train_loss: 0.025066456 val_loss: 0.0914236
# Step = 218 train_loss: 0.025314007 val_loss: 0.09229151
# Step = 219 train_loss: 0.036189284 val_loss: 0.097051926
# Step = 220 train_loss: 0.027992103 val_loss: 0.10047787
# Step = 221 train_loss: 0.035426877 val_loss: 0.101007275
# Step = 222 train_loss: 0.033017065 val_loss: 0.097788624
# Step = 223 train_loss: 0.02207409 val_loss: 0.09211646
# Step = 224 train_loss: 0.019092847 val_loss: 0.086969994
# Step = 225 train_loss: 0.041744158 val_loss: 0.090088405
# Step = 226 train_loss: 0.02605587 val_loss: 0.09364487
# Step = 227 train_loss: 0.023965415 val_loss: 0.093793795
# Step = 228 train_loss: 0.032032084 val_loss: 0.08973821
# Step = 229 train_loss: 0.025588648 val_loss: 0.08130617
# Step = 230 train_loss: 0.024246505 val_loss: 0.076655455
# Step = 231 train_loss: 0.016738161 val_loss: 0.07213559
# Step = 232 train_loss: 0.029042693 val_loss: 0.07442374
# Step = 233 train_loss: 0.027018253 val_loss: 0.077958256
# Step = 234 train_loss: 0.028052766 val_loss: 0.08024789
# Step = 235 train_loss: 0.028560162 val_loss: 0.07894876
# Step = 236 train_loss: 0.03414986 val_loss: 0.07175606
# Step = 237 train_loss: 0.019919077 val_loss: 0.06335316
# Step = 238 train_loss: 0.02275552 val_loss: 0.0571472
# Step = 239 train_loss: 0.030646477 val_loss: 0.05557982
# Step = 240 train_loss: 0.026634218 val_loss: 0.058881354
# Step = 241 train_loss: 0.02416033 val_loss: 0.05752527
# Step = 242 train_loss: 0.038368918 val_loss: 0.04433839
# Step = 243 train_loss: 0.020524032 val_loss: 0.033701975
# Step = 244 train_loss: 0.028753828 val_loss: 0.047792546
# Step = 245 train_loss: 0.021928854 val_loss: 0.048744157
# Step = 246 train_loss: 0.01803514 val_loss: 0.049293894
# Step = 247 train_loss: 0.021637935 val_loss: 0.057403542
# Step = 248 train_loss: 0.022257833 val_loss: 0.06533534
# Step = 249 train_loss: 0.026387574 val_loss: 0.07040637
# Step = 250 train_loss: 0.022987168 val_loss: 0.07347103
# Step = 251 train_loss: 0.030897189 val_loss: 0.068211436
# Step = 252 train_loss: 0.022968624 val_loss: 0.047763
# Step = 253 train_loss: 0.016829072 val_loss: 0.021854924
# Step = 254 train_loss: 0.014974332 val_loss: 0.03867714
# Step = 255 train_loss: 0.0343034 val_loss: 0.061231997
# Step = 256 train_loss: 0.027694581 val_loss: 0.06828779
# Step = 257 train_loss: 0.032482956 val_loss: 0.25702623
# Step = 258 train_loss: 0.017621167 val_loss: 0.48845688
# Step = 259 train_loss: 0.010745883 val_loss: 0.4728751
# Step = 260 train_loss: 0.019903116 val_loss: 0.4625159
# Step = 261 train_loss: 0.015205032 val_loss: 0.47809395
# Step = 262 train_loss: 0.011133939 val_loss: 0.45542517
# Step = 263 train_loss: 0.011254659 val_loss: 0.31580588
# Step = 264 train_loss: 0.011637388 val_loss: 0.052723005
# Step = 265 train_loss: 0.019672308 val_loss: 0.022195354
# Step = 266 train_loss: 0.021706153 val_loss: 0.05486626
# Step = 267 train_loss: 0.015796551 val_loss: 0.1260485
# Step = 268 train_loss: 0.011575745 val_loss: 0.10588275
# Step = 269 train_loss: 0.02477536 val_loss: 0.08592967
# Step = 270 train_loss: 0.010217486 val_loss: 0.022801545
# Step = 271 train_loss: 0.015383186 val_loss: 0.0140947355
# Step = 272 train_loss: 0.01562676 val_loss: 0.100903325
# Step = 273 train_loss: 0.008885512 val_loss: 0.073888645
# Step = 274 train_loss: 0.013895526 val_loss: 0.039806724
# Step = 275 train_loss: 0.011405365 val_loss: 0.011320803
# Step = 276 train_loss: 0.011397226 val_loss: 0.013115947
# Step = 277 train_loss: 0.012912697 val_loss: 0.008496608
# Step = 278 train_loss: 0.012253189 val_loss: 0.016167453
# Step = 279 train_loss: 0.01038417 val_loss: 0.051993772
# Step = 280 train_loss: 0.008084609 val_loss: 0.054542124
# Step = 281 train_loss: 0.013336612 val_loss: 0.039056376
# Step = 282 train_loss: 0.00856486 val_loss: 0.02036068
# Step = 283 train_loss: 0.006452046 val_loss: 0.012002076
# Step = 284 train_loss: 0.008267175 val_loss: 0.015233988
# Step = 285 train_loss: 0.015065606 val_loss: 0.021511918
# Step = 286 train_loss: 0.015284864 val_loss: 0.029999472
# Step = 287 train_loss: 0.01067765 val_loss: 0.04072139
# Step = 288 train_loss: 0.011875526 val_loss: 0.052504674
# Step = 289 train_loss: 0.010518791 val_loss: 0.05722796
# Step = 290 train_loss: 0.008615397 val_loss: 0.059633248
# Step = 291 train_loss: 0.006699696 val_loss: 0.060177214
# Step = 292 train_loss: 0.0120773995 val_loss: 0.059655923
# Step = 293 train_loss: 0.0074009574 val_loss: 0.059150532
# Step = 294 train_loss: 0.004687387 val_loss: 0.05829697
# Step = 295 train_loss: 0.006705344 val_loss: 0.057940222
# Step = 296 train_loss: 0.00872654 val_loss: 0.056766354
# Step = 297 train_loss: 0.008367461 val_loss: 0.0556349
# Step = 298 train_loss: 0.011033861 val_loss: 0.05461674
# Step = 299 train_loss: 0.006561697 val_loss: 0.053698126
# Step = 300 train_loss: 0.00875257 val_loss: 0.052955896
# Step = 301 train_loss: 0.004631199 val_loss: 0.05204826
# Step = 302 train_loss: 0.0053897626 val_loss: 0.051116157
# Step = 303 train_loss: 0.0038877393 val_loss: 0.049872003
# Step = 304 train_loss: 0.008411505 val_loss: 0.04877878
# Step = 305 train_loss: 0.00909258 val_loss: 0.04685927
# Step = 306 train_loss: 0.009032049 val_loss: 0.043539718
# Step = 307 train_loss: 0.0068368604 val_loss: 0.03780722
# Step = 308 train_loss: 0.0058628665 val_loss: 0.029275639
# Step = 309 train_loss: 0.006628339 val_loss: 0.019246532
# Step = 310 train_loss: 0.0052673994 val_loss: 0.011931057
# Step = 311 train_loss: 0.009218446 val_loss: 0.019924369
# Step = 312 train_loss: 0.006863232 val_loss: 0.036364112
# Step = 313 train_loss: 0.01280297 val_loss: 0.029133404
# Step = 314 train_loss: 0.0077245417 val_loss: 0.015407497
# Step = 315 train_loss: 0.010000199 val_loss: 0.02550931
# Step = 316 train_loss: 0.0077147963 val_loss: 0.04141423
# Step = 317 train_loss: 0.0055553685 val_loss: 0.03987003
# Step = 318 train_loss: 0.0064197998 val_loss: 0.044636708
# Step = 319 train_loss: 0.01520648 val_loss: 0.044069882
# Step = 320 train_loss: 0.012474774 val_loss: 0.03674868
# Step = 321 train_loss: 0.009581099 val_loss: 0.029611565
# Step = 322 train_loss: 0.011431498 val_loss: 0.040192917
# Step = 323 train_loss: 0.009867479 val_loss: 0.08863154
# Step = 324 train_loss: 0.0066656047 val_loss: 0.031118045
# Step = 325 train_loss: 0.010467892 val_loss: 0.012519233
# Step = 326 train_loss: 0.008919748 val_loss: 0.023032548
# Step = 327 train_loss: 0.008812693 val_loss: 0.03136373
# Step = 328 train_loss: 0.0106380675 val_loss: 0.02867824
# Step = 329 train_loss: 0.0113153765 val_loss: 0.026001735
# Step = 330 train_loss: 0.011744588 val_loss: 0.032099996
# Step = 331 train_loss: 0.006683938 val_loss: 0.39334172
# Step = 332 train_loss: 0.011812326 val_loss: 0.47208795
# Step = 333 train_loss: 0.009953991 val_loss: 0.4575575
# Step = 334 train_loss: 0.0115539525 val_loss: 0.4457894
# Step = 335 train_loss: 0.00971718 val_loss: 0.34208632
# Step = 336 train_loss: 0.006923236 val_loss: 0.16493395
# Step = 337 train_loss: 0.008057684 val_loss: 0.06398398
# Step = 338 train_loss: 0.0051461286 val_loss: 0.009124034
# Step = 339 train_loss: 0.007765721 val_loss: 0.02490719
# Step = 340 train_loss: 0.006178346 val_loss: 0.025569595
# Step = 341 train_loss: 0.0072996328 val_loss: 0.023248035
# Step = 342 train_loss: 0.009216148 val_loss: 0.022563254
# Step = 343 train_loss: 0.008240941 val_loss: 0.17661612
# Step = 344 train_loss: 0.009123028 val_loss: 0.26822335
# Step = 345 train_loss: 0.008884027 val_loss: 0.0974812
# Step = 346 train_loss: 0.009831162 val_loss: 0.015681868
# Step = 347 train_loss: 0.006005096 val_loss: 0.035553582
# Step = 348 train_loss: 0.0071951672 val_loss: 0.02492814
# Step = 349 train_loss: 0.005845743 val_loss: 0.026283735
# Step = 350 train_loss: 0.01133813 val_loss: 0.025981234
# Step = 351 train_loss: 0.0059487326 val_loss: 0.035587303
# Step = 352 train_loss: 0.0050663045 val_loss: 0.042173292
# Step = 353 train_loss: 0.0060953107 val_loss: 0.0422963
# Step = 354 train_loss: 0.006550808 val_loss: 0.038279302
# Step = 355 train_loss: 0.011450394 val_loss: 0.045905557
# Step = 356 train_loss: 0.0038864561 val_loss: 0.043245956
# Step = 357 train_loss: 0.004187818 val_loss: 0.03815585
# Step = 358 train_loss: 0.0038419915 val_loss: 0.036630016
# Step = 359 train_loss: 0.006295231 val_loss: 0.03502178
# Step = 360 train_loss: 0.0061075147 val_loss: 0.013170956
# Step = 361 train_loss: 0.008231897 val_loss: 0.08162026
# Step = 362 train_loss: 0.004722235 val_loss: 0.30915287
# Step = 363 train_loss: 0.0046414714 val_loss: 0.48300678
# Step = 364 train_loss: 0.0034650522 val_loss: 0.49322715
# Step = 365 train_loss: 0.009932771 val_loss: 0.488334
# Step = 366 train_loss: 0.008390663 val_loss: 0.4618481
# Step = 367 train_loss: 0.003220577 val_loss: 0.10225078
# Step = 368 train_loss: 0.0077588568 val_loss: 0.045841765
# Step = 369 train_loss: 0.00553389 val_loss: 0.036408365
# Step = 370 train_loss: 0.0038557276 val_loss: 0.032022737
# Step = 371 train_loss: 0.003666971 val_loss: 0.027459115
# Step = 372 train_loss: 0.00370656 val_loss: 0.02478513
# Step = 373 train_loss: 0.01111743 val_loss: 0.026339298
# Step = 374 train_loss: 0.015696602 val_loss: 0.027146086
# Step = 375 train_loss: 0.010826646 val_loss: 0.036923323
# Step = 376 train_loss: 0.007887923 val_loss: 0.04852605
# Step = 377 train_loss: 0.006825618 val_loss: 0.055252146
# Step = 378 train_loss: 0.017405547 val_loss: 0.050880287
# Step = 379 train_loss: 0.0046164542 val_loss: 0.48915753
# Step = 380 train_loss: 0.0048995772 val_loss: 0.5095881
# Step = 381 train_loss: 0.008024033 val_loss: 0.50959194
# Step = 382 train_loss: 0.010714932 val_loss: 0.5095631
# Step = 383 train_loss: 0.0074588666 val_loss: 0.5050761
# Step = 384 train_loss: 0.0074535166 val_loss: 0.47385707
# Step = 385 train_loss: 0.010915683 val_loss: 0.06580917
# Step = 386 train_loss: 0.014335139 val_loss: 0.02668474
# Step = 387 train_loss: 0.011015797 val_loss: 0.4928734
# Step = 388 train_loss: 0.005033207 val_loss: 0.50955063
# Step = 389 train_loss: 0.00876696 val_loss: 0.5095867
# Step = 390 train_loss: 0.016441645 val_loss: 0.50956327
# Step = 391 train_loss: 0.013259469 val_loss: 0.5087628
# Step = 392 train_loss: 0.008803869 val_loss: 0.48940694
# Step = 393 train_loss: 0.011736635 val_loss: 0.23223227
# Step = 394 train_loss: 0.011603564 val_loss: 0.06330267
# Step = 395 train_loss: 0.007064367 val_loss: 0.058269043
# Step = 396 train_loss: 0.01737027 val_loss: 0.06693003
# Step = 397 train_loss: 0.016153406 val_loss: 0.07841307
# Step = 398 train_loss: 0.015907725 val_loss: 0.067669936
# Step = 399 train_loss: 0.012563953 val_loss: 0.054457363
# Step = 400 train_loss: 0.008129741 val_loss: 0.051198523
# Step = 401 train_loss: 0.016151067 val_loss: 0.05246202
# Step = 402 train_loss: 0.014190709 val_loss: 0.05073334
# Step = 403 train_loss: 0.017899038 val_loss: 0.04411092
# Step = 404 train_loss: 0.021909293 val_loss: 0.044120625
# Step = 405 train_loss: 0.01796336 val_loss: 0.06039204
# Step = 406 train_loss: 0.006966163 val_loss: 0.4799823
# Step = 407 train_loss: 0.011546107 val_loss: 0.5065866
# Step = 408 train_loss: 0.009571159 val_loss: 0.50813866
# Step = 409 train_loss: 0.013595679 val_loss: 0.5067456
# Step = 410 train_loss: 0.014671337 val_loss: 0.5001619
# Step = 411 train_loss: 0.006231512 val_loss: 0.48669565
# Step = 412 train_loss: 0.006913394 val_loss: 0.45306072
# Step = 413 train_loss: 0.010591685 val_loss: 0.021975407
# Step = 414 train_loss: 0.0056615025 val_loss: 0.01539694
# Step = 415 train_loss: 0.009175101 val_loss: 0.015847646
# Step = 416 train_loss: 0.01198786 val_loss: 0.012000244
# Step = 417 train_loss: 0.0066528074 val_loss: 0.007196356
# Step = 418 train_loss: 0.0067489883 val_loss: 0.013745792
# Step = 419 train_loss: 0.004163945 val_loss: 0.024052255
# Step = 420 train_loss: 0.0061207656 val_loss: 0.023760885
# Step = 421 train_loss: 0.0032293475 val_loss: 0.02331628
# Step = 422 train_loss: 0.01030453 val_loss: 0.021680491
# Step = 423 train_loss: 0.0056896997 val_loss: 0.022989651
# Step = 424 train_loss: 0.0068434007 val_loss: 0.023764053
# Step = 425 train_loss: 0.010083299 val_loss: 0.02387228
# Step = 426 train_loss: 0.0066588763 val_loss: 0.022585414
# Step = 427 train_loss: 0.0064535607 val_loss: 0.02399431
# Step = 428 train_loss: 0.012206417 val_loss: 0.036288314
# Step = 429 train_loss: 0.0068584327 val_loss: 0.046073582
# Step = 430 train_loss: 0.008414759 val_loss: 0.04879403
# Step = 431 train_loss: 0.0071940767 val_loss: 0.020940434
# Step = 432 train_loss: 0.0058158967 val_loss: 0.119776495
# Step = 433 train_loss: 0.0039482065 val_loss: 0.40097094
# Step = 434 train_loss: 0.0057666153 val_loss: 0.46755636
# Step = 435 train_loss: 0.007963114 val_loss: 0.48635715
# Step = 436 train_loss: 0.0053913156 val_loss: 0.49098942
# Step = 437 train_loss: 0.005532841 val_loss: 0.49214432
# Step = 438 train_loss: 0.022079648 val_loss: 0.4709389
# Step = 439 train_loss: 0.004063065 val_loss: 0.15522386
# Step = 440 train_loss: 0.005901491 val_loss: 0.00844043
# Step = 441 train_loss: 0.009159876 val_loss: 0.0058231857
# Step = 442 train_loss: 0.009770978 val_loss: 0.114183016
# Step = 443 train_loss: 0.004827964 val_loss: 0.1110965
# Step = 444 train_loss: 0.01515313 val_loss: 0.026181433
# Step = 445 train_loss: 0.009534498 val_loss: 0.051452696
# Step = 446 train_loss: 0.0057468335 val_loss: 0.04810165
# Step = 447 train_loss: 0.006592651 val_loss: 0.04550272
# Step = 448 train_loss: 0.0064708474 val_loss: 0.045047905
# Step = 449 train_loss: 0.006837936 val_loss: 0.045827005
# Step = 450 train_loss: 0.005123956 val_loss: 0.046258274
# Step = 451 train_loss: 0.0065540774 val_loss: 0.04436839
# Step = 452 train_loss: 0.005964741 val_loss: 0.038837846
# Step = 453 train_loss: 0.0035727026 val_loss: 0.0052195676
# Step = 454 train_loss: 0.005581348 val_loss: 0.40861475
# Step = 455 train_loss: 0.003334465 val_loss: 0.49134967
# Step = 456 train_loss: 0.007847773 val_loss: 0.50298846
# Step = 457 train_loss: 0.0052344864 val_loss: 0.5047545
# Step = 458 train_loss: 0.0051243603 val_loss: 0.50236845
# Step = 459 train_loss: 0.007148445 val_loss: 0.49360535
# Step = 460 train_loss: 0.009649313 val_loss: 0.47823268
# Step = 461 train_loss: 0.0052405107 val_loss: 0.37927487
# Step = 462 train_loss: 0.004342898 val_loss: 0.122419395
# Step = 463 train_loss: 0.009553277 val_loss: 0.008001587
# Step = 464 train_loss: 0.0033682638 val_loss: 0.03848471
# Step = 465 train_loss: 0.005301454 val_loss: 0.045760654
# Step = 466 train_loss: 0.009068887 val_loss: 0.046635274
# Step = 467 train_loss: 0.00935428 val_loss: 0.04798032
# Step = 468 train_loss: 0.00525103 val_loss: 0.04946975
# Step = 469 train_loss: 0.0063123656 val_loss: 0.05078372
# Step = 470 train_loss: 0.003982144 val_loss: 0.051729422
# Step = 471 train_loss: 0.0070958715 val_loss: 0.050594814
# Step = 472 train_loss: 0.0069630267 val_loss: 0.048407696
# Step = 473 train_loss: 0.0050741625 val_loss: 0.044829853
# Step = 474 train_loss: 0.0074608447 val_loss: 0.03763087
# Step = 475 train_loss: 0.0025206504 val_loss: 0.030358128
# Step = 476 train_loss: 0.0035085997 val_loss: 0.025464064
# Step = 477 train_loss: 0.007834915 val_loss: 0.015643256
# Step = 478 train_loss: 0.005686975 val_loss: 0.0066811386
# Step = 479 train_loss: 0.003525289 val_loss: 0.005742322
# Step = 480 train_loss: 0.004509442 val_loss: 0.0057957317
# Step = 481 train_loss: 0.0030795196 val_loss: 0.0058091036
# Step = 482 train_loss: 0.0075047123 val_loss: 0.008660649
# Step = 483 train_loss: 0.0045488835 val_loss: 0.011569805
# Step = 484 train_loss: 0.008228624 val_loss: 0.014435217
# Step = 485 train_loss: 0.0035072353 val_loss: 0.017702658
# Step = 486 train_loss: 0.0032438003 val_loss: 0.015335856
# Step = 487 train_loss: 0.006432672 val_loss: 0.0099491
# Step = 488 train_loss: 0.008092767 val_loss: 0.0068092933
# Step = 489 train_loss: 0.0035376798 val_loss: 0.0059399856
# Step = 490 train_loss: 0.005388883 val_loss: 0.006521134
# Step = 491 train_loss: 0.0031069566 val_loss: 0.007656555
# Step = 492 train_loss: 0.0059600896 val_loss: 0.009537891
# Step = 493 train_loss: 0.004318098 val_loss: 0.011811337
# Step = 494 train_loss: 0.004598455 val_loss: 0.013570361
# Step = 495 train_loss: 0.0051701684 val_loss: 0.015088353
# Step = 496 train_loss: 0.0037632708 val_loss: 0.016384434
# Step = 497 train_loss: 0.0058608595 val_loss: 0.017183194
# Step = 498 train_loss: 0.0038434668 val_loss: 0.017551944
# Step = 499 train_loss: 0.003752025 val_loss: 0.017892722
# Step = 500 train_loss: 0.003580604 val_loss: 0.018139789
# Step = 501 train_loss: 0.009019475 val_loss: 0.018378457
# Step = 502 train_loss: 0.009371193 val_loss: 0.018926404
# Step = 503 train_loss: 0.008926489 val_loss: 0.019543346
# Step = 504 train_loss: 0.004723874 val_loss: 0.020283187
# Step = 505 train_loss: 0.005848498 val_loss: 0.021546982
# Step = 506 train_loss: 0.00695971 val_loss: 0.023257982
# Step = 507 train_loss: 0.006509533 val_loss: 0.025025565
# Step = 508 train_loss: 0.0039985445 val_loss: 0.026548034
# Step = 509 train_loss: 0.0069751297 val_loss: 0.028781565
# Step = 510 train_loss: 0.0077256486 val_loss: 0.031478595
# Step = 511 train_loss: 0.002431301 val_loss: 0.03330161
# Step = 512 train_loss: 0.004554138 val_loss: 0.03470026
# Step = 513 train_loss: 0.003329222 val_loss: 0.035905503
# Step = 514 train_loss: 0.005444954 val_loss: 0.036257267
# Step = 515 train_loss: 0.005532083 val_loss: 0.036467627
# Step = 516 train_loss: 0.010260133 val_loss: 0.037058115
# Step = 517 train_loss: 0.002526037 val_loss: 0.037464637
# Step = 518 train_loss: 0.0037262181 val_loss: 0.037500966
# Step = 519 train_loss: 0.0045905863 val_loss: 0.037207
# Step = 520 train_loss: 0.008336453 val_loss: 0.037227105
# Step = 521 train_loss: 0.005010463 val_loss: 0.03737332
# Step = 522 train_loss: 0.004685961 val_loss: 0.03742567
# Step = 523 train_loss: 0.0057097822 val_loss: 0.037391994
# Step = 524 train_loss: 0.005158286 val_loss: 0.0372563
# Step = 525 train_loss: 0.0059816865 val_loss: 0.03705254
# Step = 526 train_loss: 0.0072430526 val_loss: 0.036875546
# Step = 527 train_loss: 0.008281695 val_loss: 0.03629046
# Step = 528 train_loss: 0.0054957946 val_loss: 0.03566524
# Step = 529 train_loss: 0.0042858412 val_loss: 0.034608465
# Step = 530 train_loss: 0.0026000154 val_loss: 0.03316143
# Step = 531 train_loss: 0.0023234354 val_loss: 0.031630766
# Step = 532 train_loss: 0.0060411897 val_loss: 0.030490853
# Step = 533 train_loss: 0.0045452905 val_loss: 0.030134099
# Step = 534 train_loss: 0.00908614 val_loss: 0.029537829
# Step = 535 train_loss: 0.0044893245 val_loss: 0.025770761
# Step = 536 train_loss: 0.0041069374 val_loss: 0.016007805
# Step = 537 train_loss: 0.007055934 val_loss: 0.004448033
# Step = 538 train_loss: 0.0032823237 val_loss: 0.0308396
# Step = 539 train_loss: 0.0053722756 val_loss: 0.019457327
# Step = 540 train_loss: 0.0025315008 val_loss: 0.0064710095
# Step = 541 train_loss: 0.0060710306 val_loss: 0.015589532
# Step = 542 train_loss: 0.0046054767 val_loss: 0.018764108
# Step = 543 train_loss: 0.004081985 val_loss: 0.010998502
# Step = 544 train_loss: 0.007032902 val_loss: 0.02087957
# Step = 545 train_loss: 0.0012978005 val_loss: 0.028189681
# Step = 546 train_loss: 0.0046034944 val_loss: 0.010374089
# Step = 547 train_loss: 0.0052902177 val_loss: 0.03230743
# Step = 548 train_loss: 0.004164814 val_loss: 0.081397586
# Step = 549 train_loss: 0.0034614557 val_loss: 0.103488855
# Step = 550 train_loss: 0.0037820265 val_loss: 0.068179026
# Step = 551 train_loss: 0.004193171 val_loss: 0.05909401
# Step = 552 train_loss: 0.0045402385 val_loss: 0.049847905
# Step = 553 train_loss: 0.0034448928 val_loss: 0.05102278
# Step = 554 train_loss: 0.0029748166 val_loss: 0.003376014
# Step = 555 train_loss: 0.0060053426 val_loss: 0.03198011
# Step = 556 train_loss: 0.006240376 val_loss: 0.040572815
# Step = 557 train_loss: 0.0030291746 val_loss: 0.04355395
# Step = 558 train_loss: 0.0047167125 val_loss: 0.04681996
# Step = 559 train_loss: 0.009919784 val_loss: 0.04552454
# Step = 560 train_loss: 0.00647774 val_loss: 0.34712645
# Step = 561 train_loss: 0.006456351 val_loss: 0.50953025
# Step = 562 train_loss: 0.014359612 val_loss: 0.50958955
# Step = 563 train_loss: 0.011958171 val_loss: 0.509583
# Step = 564 train_loss: 0.006144225 val_loss: 0.50951535
# Step = 565 train_loss: 0.0077296225 val_loss: 0.5086519
# Step = 566 train_loss: 0.0051443833 val_loss: 0.4995246
# Step = 567 train_loss: 0.0041189697 val_loss: 0.45108047
# Step = 568 train_loss: 0.009285379 val_loss: 0.16281885
# Step = 569 train_loss: 0.0061516017 val_loss: 0.008539132
# Step = 570 train_loss: 0.005360598 val_loss: 0.05576109
# Step = 571 train_loss: 0.008544712 val_loss: 0.31647152
# Step = 572 train_loss: 0.0076299002 val_loss: 0.13793068
# Step = 573 train_loss: 0.006718974 val_loss: 0.40139654
# Step = 574 train_loss: 0.0062164087 val_loss: 0.5025082
# Step = 575 train_loss: 0.0046369205 val_loss: 0.49085036
# Step = 576 train_loss: 0.004724529 val_loss: 0.4819379
# Step = 577 train_loss: 0.0062696985 val_loss: 0.359895
# Step = 578 train_loss: 0.008249558 val_loss: 0.10237221
# Step = 579 train_loss: 0.008293076 val_loss: 0.034276918
# Step = 580 train_loss: 0.003902514 val_loss: 0.04655236
# Step = 581 train_loss: 0.0028266772 val_loss: 0.046820648
# Step = 582 train_loss: 0.0052553946 val_loss: 0.0479644
# Step = 583 train_loss: 0.0055808276 val_loss: 0.047954213
# Step = 584 train_loss: 0.0042268867 val_loss: 0.044283092
# Step = 585 train_loss: 0.005191437 val_loss: 0.038633514
# Step = 586 train_loss: 0.0053751078 val_loss: 0.039185185
# Step = 587 train_loss: 0.0062411977 val_loss: 0.04421407
# Step = 588 train_loss: 0.005510245 val_loss: 0.047457874
# Step = 589 train_loss: 0.007996351 val_loss: 0.055370018
# Step = 590 train_loss: 0.0050863703 val_loss: 0.0525579
# Step = 591 train_loss: 0.0066082235 val_loss: 0.04719093
# Step = 592 train_loss: 0.0031017924 val_loss: 0.04061456
# Step = 593 train_loss: 0.00893609 val_loss: 0.028647823
# Step = 594 train_loss: 0.005197999 val_loss: 0.02618435
# Step = 595 train_loss: 0.0052795717 val_loss: 0.1883508
# Step = 596 train_loss: 0.009773723 val_loss: 0.0031861577
# Step = 597 train_loss: 0.010978333 val_loss: 0.03302073
# Step = 598 train_loss: 0.010304158 val_loss: 0.07003362
# Step = 599 train_loss: 0.008402652 val_loss: 0.13439308
# Step = 600 train_loss: 0.005778315 val_loss: 0.46478444
# Step = 601 train_loss: 0.010604961 val_loss: 0.043649253
# Step = 602 train_loss: 0.007934334 val_loss: 0.029977484
# Step = 603 train_loss: 0.003549627 val_loss: 0.023435729
# Step = 604 train_loss: 0.0069467598 val_loss: 0.026965834
# Step = 605 train_loss: 0.007036104 val_loss: 0.029655213
# Step = 606 train_loss: 0.008623725 val_loss: 0.05499439
# Step = 607 train_loss: 0.0054104184 val_loss: 0.26632175
# Step = 608 train_loss: 0.009820756 val_loss: 0.008781101
# Step = 609 train_loss: 0.0027550454 val_loss: 0.037210934
# Step = 610 train_loss: 0.0075981226 val_loss: 0.010775759
# Step = 611 train_loss: 0.0068565193 val_loss: 0.37636426
# Step = 612 train_loss: 0.006511956 val_loss: 0.49055472
# Step = 613 train_loss: 0.0069752624 val_loss: 0.4902546
# Step = 614 train_loss: 0.0040262216 val_loss: 0.4714124
# Step = 615 train_loss: 0.0098971715 val_loss: 0.04130998
# Step = 616 train_loss: 0.008936413 val_loss: 0.031230314
# Step = 617 train_loss: 0.0066861687 val_loss: 0.011864466
# Step = 618 train_loss: 0.0082381535 val_loss: 0.012433193
# Step = 619 train_loss: 0.0073961485 val_loss: 0.19118257
# Step = 620 train_loss: 0.0041785445 val_loss: 0.416516
# Step = 621 train_loss: 0.012006532 val_loss: 0.39500752
# Step = 622 train_loss: 0.008195983 val_loss: 0.15654741
# Step = 623 train_loss: 0.002709307 val_loss: 0.005207902
# Step = 624 train_loss: 0.009072004 val_loss: 0.04979561
# Step = 625 train_loss: 0.0038564205 val_loss: 0.049827226
# Step = 626 train_loss: 0.007472992 val_loss: 0.03942225
# Step = 627 train_loss: 0.0032365075 val_loss: 0.025842704
# Step = 628 train_loss: 0.0035520585 val_loss: 0.005426625
# Step = 629 train_loss: 0.005708176 val_loss: 0.00651812
# Step = 630 train_loss: 0.0060349116 val_loss: 0.02515032
# Step = 631 train_loss: 0.006392896 val_loss: 0.03342494
# Step = 632 train_loss: 0.006543925 val_loss: 0.040718995
# Step = 633 train_loss: 0.0028637408 val_loss: 0.048057742
# Step = 634 train_loss: 0.008575748 val_loss: 0.045007803
# Step = 635 train_loss: 0.006145135 val_loss: 0.10358272
# Step = 636 train_loss: 0.0055456753 val_loss: 0.44983506
# Step = 637 train_loss: 0.0057377117 val_loss: 0.48820427
# Step = 638 train_loss: 0.00538782 val_loss: 0.4898025
# Step = 639 train_loss: 0.0061758277 val_loss: 0.47815508
# Step = 640 train_loss: 0.0064721834 val_loss: 0.48110044
# Step = 641 train_loss: 0.0076557766 val_loss: 0.42775363
# Step = 642 train_loss: 0.0068724956 val_loss: 0.14691556
# Step = 643 train_loss: 0.009504953 val_loss: 0.01943712
# Step = 644 train_loss: 0.0057129506 val_loss: 0.013375948
# Step = 645 train_loss: 0.0061256294 val_loss: 0.0062453724
# Step = 646 train_loss: 0.007065334 val_loss: 0.14896168
# Step = 647 train_loss: 0.0053739864 val_loss: 0.330918
# Step = 648 train_loss: 0.0073667592 val_loss: 0.47284767
# Step = 649 train_loss: 0.0071218293 val_loss: 0.4878187
# Step = 650 train_loss: 0.0074212137 val_loss: 0.48079416
# Step = 651 train_loss: 0.008280761 val_loss: 0.32908845
# Step = 652 train_loss: 0.005503784 val_loss: 0.011252979
# Step = 653 train_loss: 0.0041431254 val_loss: 0.022468673
# Step = 654 train_loss: 0.0039847237 val_loss: 0.03246604
# Step = 655 train_loss: 0.0070854374 val_loss: 0.037989344
# Step = 656 train_loss: 0.0062295687 val_loss: 0.040974483
# Step = 657 train_loss: 0.0064664455 val_loss: 0.04484406
# Step = 658 train_loss: 0.0064235236 val_loss: 0.04511317
# Step = 659 train_loss: 0.006999848 val_loss: 0.043693922
# Step = 660 train_loss: 0.0050163995 val_loss: 0.039799303
# Step = 661 train_loss: 0.005428345 val_loss: 0.03454481
# Step = 662 train_loss: 0.006803645 val_loss: 0.026156383
# Step = 663 train_loss: 0.0023268603 val_loss: 0.0054185893
# Step = 664 train_loss: 0.0033360196 val_loss: 0.026739137
# Step = 665 train_loss: 0.0022685193 val_loss: 0.03843796
# Step = 666 train_loss: 0.00570543 val_loss: 0.025204845
# Step = 667 train_loss: 0.0044445945 val_loss: 0.011931656
# Step = 668 train_loss: 0.0042844154 val_loss: 0.004521187
# Step = 669 train_loss: 0.0029636396 val_loss: 0.009933596
# Step = 670 train_loss: 0.0051862495 val_loss: 0.024925517
# Step = 671 train_loss: 0.0038443638 val_loss: 0.03189356
# Step = 672 train_loss: 0.0023971815 val_loss: 0.034731407
# Step = 673 train_loss: 0.0027566776 val_loss: 0.037296247
# Step = 674 train_loss: 0.0067368965 val_loss: 0.038729463
# Step = 675 train_loss: 0.0062840064 val_loss: 0.03935548
# Step = 676 train_loss: 0.0067404886 val_loss: 0.039800227
# Step = 677 train_loss: 0.0049301805 val_loss: 0.038507666
# Step = 678 train_loss: 0.0027606362 val_loss: 0.036229886
# Step = 679 train_loss: 0.0035060884 val_loss: 0.031006481
# Step = 680 train_loss: 0.003153217 val_loss: 0.021571323
# Step = 681 train_loss: 0.0056191855 val_loss: 0.011518045
# Step = 682 train_loss: 0.0046576723 val_loss: 0.008773762
# Step = 683 train_loss: 0.0035335426 val_loss: 0.008892816
# Step = 684 train_loss: 0.0052244333 val_loss: 0.0093853455
# Step = 685 train_loss: 0.0030588345 val_loss: 0.010960328
# Step = 686 train_loss: 0.0047805086 val_loss: 0.015881816
# Step = 687 train_loss: 0.0040516807 val_loss: 0.020372856
# Step = 688 train_loss: 0.003686065 val_loss: 0.022101343
# Step = 689 train_loss: 0.0035166289 val_loss: 0.023062425
# Step = 690 train_loss: 0.003990232 val_loss: 0.022741752
# Step = 691 train_loss: 0.0017482614 val_loss: 0.02240367
# Step = 692 train_loss: 0.0036735092 val_loss: 0.022220343
# Step = 693 train_loss: 0.0032500504 val_loss: 0.021783536
# Step = 694 train_loss: 0.002917449 val_loss: 0.021417212
# Step = 695 train_loss: 0.0031929268 val_loss: 0.020937564
# Step = 696 train_loss: 0.0025719455 val_loss: 0.020262033
# Step = 697 train_loss: 0.004083275 val_loss: 0.019551158
# Step = 698 train_loss: 0.0049667857 val_loss: 0.018897332
# Step = 699 train_loss: 0.0033219918 val_loss: 0.018383298
# Step = 700 train_loss: 0.0032235333 val_loss: 0.017834283
# Step = 701 train_loss: 0.0037010743 val_loss: 0.017398706
# Step = 702 train_loss: 0.0026600796 val_loss: 0.016951403
# Step = 703 train_loss: 0.0043254117 val_loss: 0.01647825
# Step = 704 train_loss: 0.0037186933 val_loss: 0.016016867
# Step = 705 train_loss: 0.0028877126 val_loss: 0.015370156
# Step = 706 train_loss: 0.002085948 val_loss: 0.014711723
# Step = 707 train_loss: 0.0033657516 val_loss: 0.01439796
# Step = 708 train_loss: 0.005905556 val_loss: 0.01438981
# Step = 709 train_loss: 0.004111396 val_loss: 0.014140324
# Step = 710 train_loss: 0.0030591758 val_loss: 0.013553993
# Step = 711 train_loss: 0.003039789 val_loss: 0.012727369
# Step = 712 train_loss: 0.004218743 val_loss: 0.011909657
# Step = 713 train_loss: 0.0031613065 val_loss: 0.011465837
# Step = 714 train_loss: 0.0037369074 val_loss: 0.012580322
# Step = 715 train_loss: 0.002567281 val_loss: 0.013093906
# Step = 716 train_loss: 0.004334708 val_loss: 0.01323957
# Step = 717 train_loss: 0.0050256867 val_loss: 0.011849127
# Step = 718 train_loss: 0.004071944 val_loss: 0.014411278
# Step = 719 train_loss: 0.0031994977 val_loss: 0.014652316
# Step = 720 train_loss: 0.003854943 val_loss: 0.013546306
# Step = 721 train_loss: 0.0026196097 val_loss: 0.014753673
# Step = 722 train_loss: 0.0033060585 val_loss: 0.017973758
# Step = 723 train_loss: 0.003363259 val_loss: 0.017175764
# Step = 724 train_loss: 0.0036044365 val_loss: 0.018342001
# Step = 725 train_loss: 0.0058669746 val_loss: 0.02107748
# Step = 726 train_loss: 0.004809196 val_loss: 0.020131081
# Step = 727 train_loss: 0.0024560748 val_loss: 0.016132351
# Step = 728 train_loss: 0.0046826084 val_loss: 0.02021153
# Step = 729 train_loss: 0.0041047945 val_loss: 0.01840938
# Step = 730 train_loss: 0.0014439496 val_loss: 0.008762041
# Step = 731 train_loss: 0.0021437895 val_loss: 0.0045530954
# Step = 732 train_loss: 0.0029201782 val_loss: 0.0067222263
# Step = 733 train_loss: 0.0030604934 val_loss: 0.0041498775
# Step = 734 train_loss: 0.0020614136 val_loss: 0.005723716
# Step = 735 train_loss: 0.0024147453 val_loss: 0.010400118
# Step = 736 train_loss: 0.0030205755 val_loss: 0.017663185
# Step = 737 train_loss: 0.003589243 val_loss: 0.012768982
# Step = 738 train_loss: 0.0018653405 val_loss: 0.006813308
# Step = 739 train_loss: 0.0058342298 val_loss: 0.003053828
# Step = 740 train_loss: 0.0022453454 val_loss: 0.002956769
# Step = 741 train_loss: 0.0036656635 val_loss: 0.0065121013
# Step = 742 train_loss: 0.0031301123 val_loss: 0.010319529
# Step = 743 train_loss: 0.002731302 val_loss: 0.02024336
# Step = 744 train_loss: 0.0059233466 val_loss: 0.021347376
# Step = 745 train_loss: 0.0062079476 val_loss: 0.028909346
# Step = 746 train_loss: 0.0019239505 val_loss: 0.03300431
# Step = 747 train_loss: 0.0033820053 val_loss: 0.028981613
# Step = 748 train_loss: 0.0034242088 val_loss: 0.026951935
# Step = 749 train_loss: 0.0033182066 val_loss: 0.018532839
# Step = 750 train_loss: 0.0051031867 val_loss: 0.007161043
# Step = 751 train_loss: 0.0034481694 val_loss: 0.0029042896
# Step = 752 train_loss: 0.004970515 val_loss: 0.008950483
# Step = 753 train_loss: 0.0031939817 val_loss: 0.021862762
# Step = 754 train_loss: 0.0037181638 val_loss: 0.027655883
# Step = 755 train_loss: 0.004454268 val_loss: 0.03507346
# Step = 756 train_loss: 0.0042639943 val_loss: 0.03946727
# Step = 757 train_loss: 0.004208091 val_loss: 0.039655972
# Step = 758 train_loss: 0.004710012 val_loss: 0.039679535
# Step = 759 train_loss: 0.0039310493 val_loss: 0.035475504
# Step = 760 train_loss: 0.003563445 val_loss: 0.03452593
# Step = 761 train_loss: 0.0056316056 val_loss: 0.040238965
# Step = 762 train_loss: 0.002208699 val_loss: 0.042987365
# Step = 763 train_loss: 0.002960093 val_loss: 0.04302243
# Step = 764 train_loss: 0.0035282911 val_loss: 0.040346626
# Step = 765 train_loss: 0.0039058477 val_loss: 0.03188415
# Step = 766 train_loss: 0.0022800076 val_loss: 0.01516296
# Step = 767 train_loss: 0.002543311 val_loss: 0.039042912
# Step = 768 train_loss: 0.004705036 val_loss: 0.021905417
# Step = 769 train_loss: 0.0025444592 val_loss: 0.0029008272
# Step = 770 train_loss: 0.0041687656 val_loss: 0.015147178
# Step = 771 train_loss: 0.0051744273 val_loss: 0.030196315
# Step = 772 train_loss: 0.0026347798 val_loss: 0.03416503
# Step = 773 train_loss: 0.0028564697 val_loss: 0.03503846
# Step = 774 train_loss: 0.004470791 val_loss: 0.042717595
# Step = 775 train_loss: 0.008525194 val_loss: 0.33402547
# Step = 776 train_loss: 0.0026160579 val_loss: 0.5095921
# Step = 777 train_loss: 0.004817831 val_loss: 0.5095925
# Step = 778 train_loss: 0.013825283 val_loss: 0.5095925
# Step = 779 train_loss: 0.00923066 val_loss: 0.5095924
# Step = 780 train_loss: 0.012737985 val_loss: 0.50959206
# Step = 781 train_loss: 0.009973615 val_loss: 0.50943226
# Step = 782 train_loss: 0.007894183 val_loss: 0.48974004
# Step = 783 train_loss: 0.0067532156 val_loss: 0.19310614
# Step = 784 train_loss: 0.0069614546 val_loss: 0.009358894
# Step = 785 train_loss: 0.007398983 val_loss: 0.010155108
# Step = 786 train_loss: 0.007889312 val_loss: 0.076949984
# Step = 787 train_loss: 0.0066192714 val_loss: 0.39575434
# Step = 788 train_loss: 0.0045945346 val_loss: 0.49007973
# Step = 789 train_loss: 0.0067509664 val_loss: 0.49187437
# Step = 790 train_loss: 0.008128816 val_loss: 0.4912247
# Step = 791 train_loss: 0.004201654 val_loss: 0.48726156
# Step = 792 train_loss: 0.013424244 val_loss: 0.29886612
# Step = 793 train_loss: 0.006138397 val_loss: 0.008728752
# Step = 794 train_loss: 0.007868282 val_loss: 0.054002814
# Step = 795 train_loss: 0.0042843483 val_loss: 0.06115783
# Step = 796 train_loss: 0.0066545373 val_loss: 0.06672658
# Step = 797 train_loss: 0.006896707 val_loss: 0.06252385
# Step = 798 train_loss: 0.005766659 val_loss: 0.050310425
# Step = 799 train_loss: 0.0025428128 val_loss: 0.04252665
# Step = 800 train_loss: 0.004733346 val_loss: 0.036801126
# Step = 801 train_loss: 0.00959355 val_loss: 0.045186296
# Step = 802 train_loss: 0.0041906293 val_loss: 0.059772894
# Step = 803 train_loss: 0.008805909 val_loss: 0.062777825
# Step = 804 train_loss: 0.0051363194 val_loss: 0.059211485
# Step = 805 train_loss: 0.0048598265 val_loss: 0.05177901
# Step = 806 train_loss: 0.008412527 val_loss: 0.042405684
# Step = 807 train_loss: 0.008961549 val_loss: 0.42070213
# Step = 808 train_loss: 0.005546673 val_loss: 0.49057117
# Step = 809 train_loss: 0.005612818 val_loss: 0.488996
# Step = 810 train_loss: 0.0029279878 val_loss: 0.46730572
# Step = 811 train_loss: 0.005001701 val_loss: 0.18532205
# Step = 812 train_loss: 0.0035813649 val_loss: 0.02752874
# Step = 813 train_loss: 0.0046803798 val_loss: 0.07426658
# Step = 814 train_loss: 0.006920554 val_loss: 0.08115764
# Step = 815 train_loss: 0.0074594733 val_loss: 0.07975379
# Step = 816 train_loss: 0.007885202 val_loss: 0.07584989
# Step = 817 train_loss: 0.008324108 val_loss: 0.049963392
# Step = 818 train_loss: 0.006051968 val_loss: 0.48556635
# Step = 819 train_loss: 0.012801925 val_loss: 0.49518284
# Step = 820 train_loss: 0.008934059 val_loss: 0.49770057
# Step = 821 train_loss: 0.010307128 val_loss: 0.49003765
# Step = 822 train_loss: 0.0077830064 val_loss: 0.37976494
# Step = 823 train_loss: 0.00852893 val_loss: 0.013287995
# Step = 824 train_loss: 0.0042809504 val_loss: 0.058481134
# Step = 825 train_loss: 0.004173987 val_loss: 0.059452638
# Step = 826 train_loss: 0.006141499 val_loss: 0.058640674
# Step = 827 train_loss: 0.012648761 val_loss: 0.06382772
# Step = 828 train_loss: 0.0068442994 val_loss: 0.067043826
# Step = 829 train_loss: 0.00421352 val_loss: 0.065022945
# Step = 830 train_loss: 0.0058329348 val_loss: 0.056740265
# Step = 831 train_loss: 0.005510509 val_loss: 0.045534324
# Step = 832 train_loss: 0.005532888 val_loss: 0.03754972
# Step = 833 train_loss: 0.004860357 val_loss: 0.031939298
# Step = 834 train_loss: 0.004421902 val_loss: 0.033602376
# Step = 835 train_loss: 0.008562751 val_loss: 0.035468355
# Step = 836 train_loss: 0.0058125537 val_loss: 0.03942397
# Step = 837 train_loss: 0.0033724145 val_loss: 0.040231954
# Step = 838 train_loss: 0.0039865156 val_loss: 0.03954813
# Step = 839 train_loss: 0.002802752 val_loss: 0.040630188
# Step = 840 train_loss: 0.0026512598 val_loss: 0.044142958
# Step = 841 train_loss: 0.0070626293 val_loss: 0.04683366
# Step = 842 train_loss: 0.0050894073 val_loss: 0.017852437
# Step = 843 train_loss: 0.0042146402 val_loss: 0.35981694
# Step = 844 train_loss: 0.0034568696 val_loss: 0.4913089
# Step = 845 train_loss: 0.005644479 val_loss: 0.5038007
# Step = 846 train_loss: 0.007042366 val_loss: 0.5057619
# Step = 847 train_loss: 0.005807112 val_loss: 0.50124747
# Step = 848 train_loss: 0.0058363853 val_loss: 0.4914856
# Step = 849 train_loss: 0.0050344663 val_loss: 0.4704409
# Step = 850 train_loss: 0.0049633672 val_loss: 0.23850536
# Step = 851 train_loss: 0.0056437794 val_loss: 0.01696907
# Step = 852 train_loss: 0.0050947443 val_loss: 0.027846906
# Step = 853 train_loss: 0.0046038246 val_loss: 0.053830013
# Step = 854 train_loss: 0.005415854 val_loss: 0.062263373
# Step = 855 train_loss: 0.0051741074 val_loss: 0.062699735
# Step = 856 train_loss: 0.005271939 val_loss: 0.061947998
# Step = 857 train_loss: 0.0038204477 val_loss: 0.06157819
# Step = 858 train_loss: 0.003382325 val_loss: 0.056836095
# Step = 859 train_loss: 0.0029820895 val_loss: 0.048906054
# Step = 860 train_loss: 0.0036651676 val_loss: 0.041872866
# Step = 861 train_loss: 0.0021081776 val_loss: 0.036203463
# Step = 862 train_loss: 0.0036642717 val_loss: 0.0362775
# Step = 863 train_loss: 0.0023814072 val_loss: 0.03705836
# Step = 864 train_loss: 0.0028594746 val_loss: 0.040982496
# Step = 865 train_loss: 0.0059404927 val_loss: 0.043118674
# Step = 866 train_loss: 0.004313297 val_loss: 0.04515064
# Step = 867 train_loss: 0.0021706196 val_loss: 0.04656058
# Step = 868 train_loss: 0.0031151383 val_loss: 0.047135834
# Step = 869 train_loss: 0.003689878 val_loss: 0.046795137
# Step = 870 train_loss: 0.0047011646 val_loss: 0.0456461
# Step = 871 train_loss: 0.0038681573 val_loss: 0.044285834
# Step = 872 train_loss: 0.0025504155 val_loss: 0.042964764
# Step = 873 train_loss: 0.0032739083 val_loss: 0.042167556
# Step = 874 train_loss: 0.0043941704 val_loss: 0.041973356
# Step = 875 train_loss: 0.0045643416 val_loss: 0.042492963
# Step = 876 train_loss: 0.0026708124 val_loss: 0.041766305
# Step = 877 train_loss: 0.0033385488 val_loss: 0.038399212
# Step = 878 train_loss: 0.0022539063 val_loss: 0.03515378
# Step = 879 train_loss: 0.002482753 val_loss: 0.030328227
# Step = 880 train_loss: 0.0037860984 val_loss: 0.023802226
# Step = 881 train_loss: 0.0059091975 val_loss: 0.015460994
# Step = 882 train_loss: 0.0022556784 val_loss: 0.009573061
# Step = 883 train_loss: 0.003586352 val_loss: 0.0061798007
# Step = 884 train_loss: 0.0020929081 val_loss: 0.0058097783
# Step = 885 train_loss: 0.0030560566 val_loss: 0.0072420663
# Step = 886 train_loss: 0.007064337 val_loss: 0.009340723
# Step = 887 train_loss: 0.0031712514 val_loss: 0.0104353195
# Step = 888 train_loss: 0.0036396682 val_loss: 0.010346884
# Step = 889 train_loss: 0.0019831785 val_loss: 0.009959217
# Step = 890 train_loss: 0.0035001384 val_loss: 0.00895711
# Step = 891 train_loss: 0.0014718713 val_loss: 0.007610651
# Step = 892 train_loss: 0.0036672319 val_loss: 0.0065688286
# Step = 893 train_loss: 0.003960616 val_loss: 0.005767251
# Step = 894 train_loss: 0.0024235225 val_loss: 0.005437889
# Step = 895 train_loss: 0.002470098 val_loss: 0.005464638
# Step = 896 train_loss: 0.0026301746 val_loss: 0.0057338765
# Step = 897 train_loss: 0.0025690037 val_loss: 0.006223444
# Step = 898 train_loss: 0.004725421 val_loss: 0.0067856973
# Step = 899 train_loss: 0.004926965 val_loss: 0.007522227
# Step = 900 train_loss: 0.0033494867 val_loss: 0.008238497
# Step = 901 train_loss: 0.0033497908 val_loss: 0.008804785
# Step = 902 train_loss: 0.004649527 val_loss: 0.009459749
# Step = 903 train_loss: 0.0012622891 val_loss: 0.010148067
# Step = 904 train_loss: 0.0031627282 val_loss: 0.010790408
# Step = 905 train_loss: 0.002092802 val_loss: 0.011407883
# Step = 906 train_loss: 0.0022749803 val_loss: 0.011943077
# Step = 907 train_loss: 0.0030162563 val_loss: 0.012471721
# Step = 908 train_loss: 0.0022760755 val_loss: 0.013155694
# Step = 909 train_loss: 0.0025468734 val_loss: 0.013969936
# Step = 910 train_loss: 0.0024995168 val_loss: 0.014917234
# Step = 911 train_loss: 0.0034629963 val_loss: 0.017023139
# Step = 912 train_loss: 0.0031811649 val_loss: 0.019105086
# Step = 913 train_loss: 0.0033632973 val_loss: 0.020837268
# Step = 914 train_loss: 0.004222013 val_loss: 0.022539757
# Step = 915 train_loss: 0.0023507378 val_loss: 0.024651617
# Step = 916 train_loss: 0.0042463494 val_loss: 0.026674332
# Step = 917 train_loss: 0.0039679524 val_loss: 0.028938904
# Step = 918 train_loss: 0.0040360456 val_loss: 0.03122226
# Step = 919 train_loss: 0.0031858464 val_loss: 0.032169014
# Step = 920 train_loss: 0.0030173636 val_loss: 0.03311849
# Step = 921 train_loss: 0.006761984 val_loss: 0.032203585
# Step = 922 train_loss: 0.004307159 val_loss: 0.029787188
# Step = 923 train_loss: 0.0019463842 val_loss: 0.026320547
# Step = 924 train_loss: 0.0031105853 val_loss: 0.021719148
# Step = 925 train_loss: 0.00467812 val_loss: 0.018560594
# Step = 926 train_loss: 0.0027723783 val_loss: 0.013328863
# Step = 927 train_loss: 0.0019972478 val_loss: 0.011051627
# Step = 928 train_loss: 0.0027202691 val_loss: 0.00761479
# Step = 929 train_loss: 0.0039244415 val_loss: 0.008355205
# Step = 930 train_loss: 0.0030061065 val_loss: 0.009953866
# Step = 931 train_loss: 0.0038247742 val_loss: 0.014080933
# Step = 932 train_loss: 0.0033467826 val_loss: 0.018547535
# Step = 933 train_loss: 0.0023745066 val_loss: 0.021006439
# Step = 934 train_loss: 0.005010653 val_loss: 0.027941896
# Step = 935 train_loss: 0.0026365905 val_loss: 0.031188436
# Step = 936 train_loss: 0.0027746272 val_loss: 0.03461353
# Step = 937 train_loss: 0.0024983024 val_loss: 0.03959038
# Step = 938 train_loss: 0.0028877666 val_loss: 0.04371991
# Step = 939 train_loss: 0.0027564326 val_loss: 0.046383496
# Step = 940 train_loss: 0.0024491225 val_loss: 0.047087222
# Step = 941 train_loss: 0.0027387552 val_loss: 0.04682024
# Step = 942 train_loss: 0.0020263172 val_loss: 0.046688214
# Step = 943 train_loss: 0.00337702 val_loss: 0.047924925
# Step = 944 train_loss: 0.0041421605 val_loss: 0.046909075
# Step = 945 train_loss: 0.0069421274 val_loss: 0.036763806
# Step = 946 train_loss: 0.0034287039 val_loss: 0.020281592
# Step = 947 train_loss: 0.0027687373 val_loss: 0.0050140033
# Step = 948 train_loss: 0.0021168147 val_loss: 0.021989355
# Step = 949 train_loss: 0.002818329 val_loss: 0.13916013
# Step = 950 train_loss: 0.002290431 val_loss: 0.3553112
# Step = 951 train_loss: 0.002350582 val_loss: 0.39312464
# Step = 952 train_loss: 0.0028679406 val_loss: 0.3473414
# Step = 953 train_loss: 0.002878815 val_loss: 0.24980727
# Step = 954 train_loss: 0.002530027 val_loss: 0.08975954
# Step = 955 train_loss: 0.0034788975 val_loss: 0.015976744
# Step = 956 train_loss: 0.001917431 val_loss: 0.04437461
# Step = 957 train_loss: 0.0039358055 val_loss: 0.050591014
# Step = 958 train_loss: 0.0048813554 val_loss: 0.048291035
# Step = 959 train_loss: 0.0023068278 val_loss: 0.04418285
# Step = 960 train_loss: 0.0029211475 val_loss: 0.039256625
# Step = 961 train_loss: 0.006012082 val_loss: 0.04759811
# Step = 962 train_loss: 0.0030575858 val_loss: 0.050651595
# Step = 963 train_loss: 0.0045764623 val_loss: 0.04223308
# Step = 964 train_loss: 0.003453883 val_loss: 0.014152594
# Step = 965 train_loss: 0.0035631603 val_loss: 0.0076099066
# Step = 966 train_loss: 0.00529781 val_loss: 0.0153696695
# Step = 967 train_loss: 0.0021696868 val_loss: 0.029693997
# Step = 968 train_loss: 0.0035569747 val_loss: 0.07301411
# Step = 969 train_loss: 0.0028750584 val_loss: 0.07117895
# Step = 970 train_loss: 0.0022449768 val_loss: 0.074667364
# Step = 971 train_loss: 0.0024253726 val_loss: 0.023667902
# Step = 972 train_loss: 0.00284527 val_loss: 0.0060030418
# Step = 973 train_loss: 0.0018106169 val_loss: 0.02135286
# Step = 974 train_loss: 0.0023784349 val_loss: 0.022870021
# Step = 975 train_loss: 0.0029606451 val_loss: 0.022539988
# Step = 976 train_loss: 0.0021472203 val_loss: 0.017535914
# Step = 977 train_loss: 0.0022253066 val_loss: 0.0120579945
# Step = 978 train_loss: 0.0032460168 val_loss: 0.028951462
# Step = 979 train_loss: 0.0029902083 val_loss: 0.045959998
# Step = 980 train_loss: 0.0029756872 val_loss: 0.057404034
# Step = 981 train_loss: 0.0024708745 val_loss: 0.055402476
# Step = 982 train_loss: 0.0032951245 val_loss: 0.04862068
# Step = 983 train_loss: 0.0028824417 val_loss: 0.043261558
# Step = 984 train_loss: 0.002673775 val_loss: 0.04162533
# Step = 985 train_loss: 0.0033205152 val_loss: 0.04823964
# Step = 986 train_loss: 0.0043564653 val_loss: 0.016280947
# Step = 987 train_loss: 0.0030622466 val_loss: 0.19051768
# Step = 988 train_loss: 0.002367407 val_loss: 0.3683196
# Step = 989 train_loss: 0.0035242848 val_loss: 0.23816366
# Step = 990 train_loss: 0.0016033959 val_loss: 0.298169
# Step = 991 train_loss: 0.0031245186 val_loss: 0.13142721
# Step = 992 train_loss: 0.0038214189 val_loss: 0.084723555
# Step = 993 train_loss: 0.0033412096 val_loss: 0.082957655
# Step = 994 train_loss: 0.0015751192 val_loss: 0.049290948
# Step = 995 train_loss: 0.0021111423 val_loss: 0.0906496
# Step = 996 train_loss: 0.0029443575 val_loss: 0.08110331
# Step = 997 train_loss: 0.0022411237 val_loss: 0.007665034
# Step = 998 train_loss: 0.0030517285 val_loss: 0.016124208
# Step = 999 train_loss: 0.0020983976 val_loss: 0.033969827
# Best model at index: 769
# Best model val_loss: 0.0029008272103965282
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_21860\2966303312.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('Best_target_model/net_parameters.pkl')

# %%
# history = np.DataFrame(columns=['index','train_loss', 'val_loss'])
#画出训练过程中的loss变化曲线
plt.plot(history['train_loss'], label='train_loss')
plt.plot(history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''Prediction using the best model'''
predict_labels_a=[]
predict_labels_b=[]
predict_labels_train=[]
predict_labels_val = []
model.eval()
with torch.no_grad():
    predict_labels_a.append(model(input_test_a).data.numpy())
    predict_labels_b.append(model(input_test_b).data.numpy())
    
    predict_labels_train.append(model(input_train).data.numpy())   
    predict_labels_val.append(model(input_val).data.numpy())      


actual_label_arr_train=np.round(np.asarray(train_labels*max_label).reshape(-1,1))  
predict_label_arr_train=np.round(np.asarray(predict_labels_train).reshape(-1,1)*max_label)


actual_label_arr_val=np.round(np.asarray(val_labels*max_label).reshape(-1,1))   
predict_label_arr_val=np.round(np.asarray(predict_labels_val).reshape(-1,1)*max_label)


actual_label_arr_a=np.round(np.asarray(test_cycle_life_a*max_label).reshape(-1,1))   
predict_label_arr_a=np.round(np.asarray(predict_labels_a).reshape(-1,1)*max_label)


actual_label_arr_b=np.round(np.asarray(test_cycle_life_b * max_label).reshape(-1,1))   
predict_label_arr_b=np.round(np.asarray(predict_labels_b).reshape(-1,1)*max_label)

# %%
'''Plot the predicted cycle lives'''
plt.scatter(actual_label_arr_train, predict_label_arr_train,s=50,c='k')
plt.scatter(actual_label_arr_val, predict_label_arr_val,s=50,c='b')
plt.scatter(actual_label_arr_a, predict_label_arr_a,s=50,c='r')
plt.scatter(actual_label_arr_b, predict_label_arr_b,s=50,c='g')
plt.plot([100,2500],[100,2500])


'''Evaluation metrics'''
mpe_a=np.mean(np.abs(predict_label_arr_a-actual_label_arr_a)/actual_label_arr_a)
mpe_b=np.mean(np.abs(predict_label_arr_b-actual_label_arr_b)/actual_label_arr_b)
mpe_train = np.mean(np.abs(predict_label_arr_train-actual_label_arr_train)/actual_label_arr_train)
mpe_val = np.mean(np.abs(predict_label_arr_val-actual_label_arr_val)/actual_label_arr_val)


rmse_a=np.sqrt(np.mean((predict_label_arr_a-actual_label_arr_a)**2))
rmse_b=np.sqrt(np.mean((predict_label_arr_b-actual_label_arr_b)**2))
rmse_train=np.sqrt(np.mean((predict_label_arr_train-actual_label_arr_train)**2))
rmse_val=np.sqrt(np.mean((predict_label_arr_val-actual_label_arr_val)**2))


print ('mpe_train:',mpe_train)
print ('mpe_val:',mpe_val)
print ('mpe_a:',mpe_a)
print ('mpe_b:',mpe_b)

print ('rmse_train:', rmse_train)
print ('rmse_val:', rmse_val)
print ('rmse_a:', rmse_a)
print ('rmse_b:', rmse_b)
# Out:
# mpe_train: 0.11391477
# mpe_val: 0.14195623
# mpe_a: 0.14267775960484952
# mpe_b: 0.16727415170100318
# rmse_train: 109.99947
# rmse_val: 120.26434
# rmse_a: 110.6459890087342
# rmse_b: 238.22662529616625

# %%
from sklearn.metrics import r2_score
r2_a = r2_score(actual_label_arr_a, predict_label_arr_a)
r2_b = r2_score(actual_label_arr_b, predict_label_arr_b)
r2_train = r2_score(actual_label_arr_train, predict_label_arr_train)
r2_val = r2_score(actual_label_arr_val, predict_label_arr_val)

print('r2_train:', r2_train)
print('r2_val:', r2_val)
print('r2_a:', r2_a)
print('r2_b:', r2_b)
# Out:
# r2_train: 0.916574239730835
# r2_val: 0.8610522747039795
# r2_a: 0.9197794929374496
# r2_b: 0.30184489455758945
