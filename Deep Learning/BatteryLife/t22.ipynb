# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary
from sklearn.model_selection import train_test_split
import shutil

'''Load data'''
temp_Qd = np.load('Data_processed/Qd_100.npy',allow_pickle=True).item()
temp_life = np.load('Data_processed/cycle_life.npy',allow_pickle=True).item()
all_capacity = np.load('Data_processed/all_capacity.npy',allow_pickle=True).item()
temp_Qd_all = []
temp_life_all = []
all_capacity_all = []

for key in temp_Qd.keys():
    temp_life_all.append(temp_life[key])
    all_capacity_all.append(all_capacity[key])
    temp_Qd_list = []
    for item in temp_Qd[key]:
        temp_Qd_list.append(item)
    temp_Qd_arr = np.asarray(temp_Qd_list)
    temp_Qd_all.append(temp_Qd_arr)
all_Qd_arr = np.asarray(temp_Qd_all)
cycle_life_arr = np.asarray(temp_life_all)    


'''Divide the dataset as the original paper stated'''
test_ind = np.hstack((np.arange(0,(41+43),2),83))
train_ind = np.arange(1,(41+43-1),2)
secondary_test_ind = np.arange(124-40,124)

all_keys = list(temp_Qd.keys())
train_keys = [all_keys[inx] for inx in train_ind]
test_keys = [all_keys[inx] for inx in test_ind]
secondary_test_keys = [all_keys[inx] for inx in secondary_test_ind]

cycle_life_arr=np.asarray(cycle_life_arr).reshape(-1,1)
max_label=np.max(cycle_life_arr)
cycle_life_arr=cycle_life_arr/max_label


train_Qds = np.asarray(all_Qd_arr)[train_ind]
train_cycle_lifes = np.asarray(cycle_life_arr)[train_ind]

test_Qd_a = np.asarray(all_Qd_arr)[test_ind]
test_cycle_life_a = np.asarray(cycle_life_arr)[test_ind]

test_Qd_b = np.asarray(all_Qd_arr)[secondary_test_ind]
test_cycle_life_b = np.asarray(cycle_life_arr)[secondary_test_ind]

train_Qd, _, train_cycle_life, _ = train_test_split(train_Qds, train_cycle_lifes, test_size=0.36, random_state=3)

# %%
# pip install einops

# %%
import torch
import torch.nn as nn
from einops import rearrange

def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')
def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)

class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class SEbox(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(SEbox, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.pool_out = nn.AdaptiveMaxPool2d(output_size=(8,19))
        self.se = SELayer(out_channel)
        self.cbam = CBAM(out_channel)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.pool_out(x)
        x = x + self.se(x)
        x = self.dropout(x)
        x = self.cbam(x)
        return x
    
class cnn_box(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(cnn_box, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.dropout(x)
        return x
    
class CBAM(nn.Module):
    def __init__(self, in_channel, reduction=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.max_pool = nn.AdaptiveMaxPool2d(output_size=1)
        self.avg_pool = nn.AdaptiveAvgPool2d(output_size=1)
        self.mlp = nn.Sequential(
            nn.Linear(in_features=in_channel, out_features=in_channel // reduction, bias=False),
            nn.ReLU(),
            nn.Linear(in_features=in_channel // reduction, out_features=in_channel, bias=False)
        )
        self.sigmoid = nn.Sigmoid()
        self.conv = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False)

    def forward(self, x):
        maxout = self.max_pool(x)
        avgout = self.avg_pool(x)
        channel_out = self.sigmoid(self.mlp(maxout.view(maxout.size(0), -1)) + self.mlp(avgout.view(avgout.size(0), -1)))
        channel_out = channel_out.view(x.size(0), x.size(1), 1, 1) * x
        max_out = torch.max(channel_out, dim=1, keepdim=True)[0]
        mean_out = torch.mean(channel_out, dim=1, keepdim=True)
        out = self.sigmoid(self.conv(torch.cat((max_out, mean_out), dim=1))) * channel_out
        return out

class InceptionModule(torch.nn.Module):
    def __init__(self, in_channels=64, out_channels=64):
        super(InceptionModule, self).__init__()
        
        self.inceptions = torch.nn.ModuleList([
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(3, 3), stride=1, padding=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(5, 5), stride=1, padding=2),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
            )
        ])

    def forward(self, x):
        # 将输入传递给所有Inception模块，并将输出连接起来
        outputs = [inception(x) for inception in self.inceptions]
        return torch.cat(outputs, dim=1)  # 这里按通道维度连接输出

# 使用示例
# model = InceptionModule(in_channels=32, out_channels=64)
# output = model(input_tensor)  # input_tensor 是你的输入数据

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=1),
            nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(8, 16, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(16),
            torch.nn.LeakyReLU(inplace=True),
            torch.nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(16, 32, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(32),
            torch.nn.LeakyReLU(inplace=True),            
            
        )
        self.go = InceptionModule()
        self.sebox1 = SEbox(64,64,kernel_size=1,stride=1,padding=1)
        self.sebox2 = SEbox(64,128,kernel_size=2,stride=1,padding=1)
        self.sebox3 = SEbox(64,128,kernel_size=4,stride=1,padding=1)
        
        self.lstm1 = nn.LSTM(32, 32, num_layers=2, bidirectional=True, batch_first=True)
        
        self.lstm2 = nn.LSTM(576, 576, num_layers=2, bidirectional=True, batch_first=True)
        self.fc1 = nn.Linear(184832, 1)
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        try:
            # 网络结构部分
            x = self.layers1(x)
            x = to_3d(x)
            x, _ = self.lstm1(x)
            x = to_4d(x, 8, 19)
            
            # 网络结构部分，计算三个 SEbox 的输出并合并
            se1 = self.sebox1(x)
            se2 = self.sebox2(x)
            se3 = self.sebox3(x)
            
            # print(f"SEbox1输出形状: {se1.shape}")  # 输出SEbox1的形状
            # print(f"SEbox2输出形状: {se2.shape}")  # 输出SEbox2的形状   
            # print(f"SEbox3输出形状: {se3.shape}")  # 输出SEbox3的形状
            # 合并三个 SEbox 的输出
            se = torch.cat((se1, se2, se3), dim=1)
            
            # 裁剪合并后的输出
            crop_se = se[:, :, :8, :19]

            go = self.go(x)
            
            cat1 = torch.cat((crop_se, go), dim=1)
            
            lstm2_input = to_3d(cat1)
            
            lstm2_output, _ = self.lstm2(lstm2_input)
            
            lstm2 = to_4d(lstm2_output, 8, 19)
            
            x = torch.cat((x, lstm2), dim=1)
            # # 输出部分
        
            # print(f"层1输出形状: {x.shape}")  # 输出层1的形状
            # print(f"转换为3D后的形状: {x.shape}")  # 输出转换后的形状
            # print(f"LSTM后输出形状: {x.shape}")  # 输出LSTM的形状
            # print(f"转换为4D后的形状: {x.shape}")  # 输出转换后的形状
            # print(f"SEbox后输出形状: {se.shape}")  # 输出SEbox的形状
            # print(f"裁剪后SEbox形状: {crop_se.shape}")  # 输出裁剪后的形状
            # print(f"InceptionModule后输出形状: {go.shape}")  # 输出InceptionModule的形状
            # print(f"拼接后输出形状(取crop_se和go): {cat1.shape}")  # 输出拼接后的形状
            # print(f"LSTM2输入形状: {lstm2_input.shape}")  # 输出LSTM2的输入形状
            # print(f"LSTM2后输出形状: {lstm2_output.shape}")  # 输出LSTM2的输出形状
            # print(f"转换为4D后LSTM2的形状: {lstm2.shape}")  # 输出转换后的LSTM2形状
            # print(f"最终拼接后输出形状: {x.shape}")  # 输出最终拼接后的形状

            return torch.sigmoid(self.fc1(x.view(x.size(0), -1)))
        except RuntimeError as e:
            print(f"运行时错误：{e}")
            return None
        except Exception as e:
            print(f"发生意外错误：{e}")
            raise  # 重新抛出异常，以便进一步处理

# %%
net = Net()     # define the network
print(net)      # net architecture
# summary(net,(1,100,1000))
# Out:
# Net(
#   (layers1): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Conv2d(8, 16, kernel_size=(2, 3), stride=(1, 1))
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Conv2d(16, 32, kernel_size=(2, 3), stride=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (go): InceptionModule(
#     (inceptions): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (3): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (sebox1): SEbox(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     (pool_out): AdaptiveMaxPool2d(output_size=(8, 19))
#     (se): SELayer(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=4, out_features=64, bias=False)
#         (3): Sigmoid()
#       )
#     )
#     (cbam): CBAM(
#       (max_pool): AdaptiveMaxPool2d(output_size=1)
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (mlp): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU()
#         (2): Linear(in_features=4, out_features=64, bias=False)
#       )
#       (sigmoid): Sigmoid()
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     )
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (sebox2): SEbox(
#     (conv): Conv2d(64, 128, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     (pool_out): AdaptiveMaxPool2d(output_size=(8, 19))
#     (se): SELayer(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc): Sequential(
#         (0): Linear(in_features=128, out_features=8, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=8, out_features=128, bias=False)
#         (3): Sigmoid()
#       )
#     )
#     (cbam): CBAM(
#       (max_pool): AdaptiveMaxPool2d(output_size=1)
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=8, bias=False)
#         (1): ReLU()
#         (2): Linear(in_features=8, out_features=128, bias=False)
#       )
#       (sigmoid): Sigmoid()
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     )
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (sebox3): SEbox(
#     (conv): Conv2d(64, 128, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     (pool_out): AdaptiveMaxPool2d(output_size=(8, 19))
#     (se): SELayer(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc): Sequential(
#         (0): Linear(in_features=128, out_features=8, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=8, out_features=128, bias=False)
#         (3): Sigmoid()
#       )
#     )
#     (cbam): CBAM(
#       (max_pool): AdaptiveMaxPool2d(output_size=1)
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (mlp): Sequential(
#         (0): Linear(in_features=128, out_features=8, bias=False)
#         (1): ReLU()
#         (2): Linear(in_features=8, out_features=128, bias=False)
#       )
#       (sigmoid): Sigmoid()
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     )
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (lstm1): LSTM(32, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(576, 576, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=184832, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
import pandas as pd
import torch.optim as optim
'''Data loader for Pytorch'''
input_train = torch.FloatTensor(train_Qd)
input_train = torch.unsqueeze(input_train, 1)
train_labels = torch.FloatTensor(train_cycle_life)

input_val = torch.FloatTensor(train_Qds)
input_val = torch.unsqueeze(input_val, 1)
val_labels = torch.FloatTensor(train_cycle_lifes)

input_test_a = torch.FloatTensor(test_Qd_a)
input_test_a = torch.unsqueeze(input_test_a, 1)
test_labels_a = torch.FloatTensor(test_cycle_life_a)

input_test_b = torch.FloatTensor(test_Qd_b)
input_test_b = torch.unsqueeze(input_test_b, 1)
test_labels_b = torch.FloatTensor(test_cycle_life_b)



seed = 17
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed)    # reproducible    



optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)
loss_func = torch.nn.MSELoss() 

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# 创建历史记录DataFrame
history = pd.DataFrame(columns=['index', 'train_loss', 'val_loss'])
val_losses = []
max_models_to_keep = 10
saved_models=[]
import os

import datetime

log_file_path = 'train_log.txt'  # 请替换为实际的日志文件路径

# 初始化日志文件，并且第一行记录时间跟训练参数
with open(log_file_path, 'w') as log_file:
    log_file.write('Time: {}\n'.format(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
    # log_file.write('Training parameters: {}\n'.format(str(vars(args))))

for t in range(1000):
    net.train()
    train_prediction = net(input_train)
    train_loss = loss_func(train_prediction, train_labels)
   
    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    # 保存模型
    model_path = 'Target_model/net_parameters'+str(t)+'.pkl'
    torch.save({
        'epoch': t,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()}, model_path)

    net.eval()
    with torch.no_grad():
        val_prediction = net(input_val)
        val_loss = loss_func(val_prediction, val_labels)
    
    print('Step = %d' % t, 'train_loss:', train_loss.data.numpy(), 'val_loss:', val_loss.data.numpy())


# 打开文件并写入内容
    with open(log_file_path, 'a') as log_file:  # 'a'模式表示追加写入
        log_file.write('Step = %d, train_loss: %s, val_loss: %s\n' % (t, train_loss.data.numpy(), val_loss.data.numpy()))
        
    val_losses.append(val_loss.item())
    
    # 添加当前模型及其验证损失
    saved_models.append((val_loss.item(), model_path))

    # 保持模型数量不超过max_models_to_keep
    if len(saved_models) > max_models_to_keep:
        # 找到验证损失最大的一组模型并删除
        saved_models.sort(key=lambda x: x[0])  # 排序，根据损失
        os.remove(saved_models.pop()[1])  # 删除损失最大的模型
    # 加入训练历史记录
    # 创建新的一行数据
    new_entry = pd.DataFrame({'index': [t], 'train_loss': [train_loss.item()], 'val_loss': [val_loss.item()]})
    
    # 使用concat进行数据合并
    history = pd.concat([history, new_entry], ignore_index=True)

'''find the best model'''
best_index = val_losses.index(np.min(val_losses))
print(f'Best model at index: {best_index}')
print(f'Best model val_loss: {val_losses[best_index]}')

'''copy the best model from model file to the model_test file'''
shutil.copyfile(f'Target_model/net_parameters{best_index}.pkl', 'Best_target_model/net_parameters.pkl')


'''Reload the best model''' 
model = Net()
checkpoint = torch.load('Best_target_model/net_parameters.pkl')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Step = 0 train_loss: 0.066993274 val_loss: 0.044230253
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_2240\2966303312.py:111: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   history = pd.concat([history, new_entry], ignore_index=True)
# Step = 1 train_loss: 0.029678822 val_loss: 0.037483886
# Step = 2 train_loss: 0.038576696 val_loss: 0.035928495
# Step = 3 train_loss: 0.038189784 val_loss: 0.03669563
# Step = 4 train_loss: 0.030104585 val_loss: 0.0384463
# Step = 5 train_loss: 0.0275582 val_loss: 0.040016275
# Step = 6 train_loss: 0.03347311 val_loss: 0.039928306
# Step = 7 train_loss: 0.032926194 val_loss: 0.038242575
# Step = 8 train_loss: 0.02767389 val_loss: 0.035910614
# Step = 9 train_loss: 0.028997382 val_loss: 0.033783205
# Step = 10 train_loss: 0.026128063 val_loss: 0.03232261
# Step = 11 train_loss: 0.027939035 val_loss: 0.031732596
# Step = 12 train_loss: 0.027060397 val_loss: 0.031937074
# Step = 13 train_loss: 0.02205851 val_loss: 0.032763183
# Step = 14 train_loss: 0.028137418 val_loss: 0.03443879
# Step = 15 train_loss: 0.02381682 val_loss: 0.03659649
# Step = 16 train_loss: 0.02099827 val_loss: 0.03768912
# Step = 17 train_loss: 0.022703558 val_loss: 0.03732697
# Step = 18 train_loss: 0.018165525 val_loss: 0.036362045
# Step = 19 train_loss: 0.017742343 val_loss: 0.034457263
# Step = 20 train_loss: 0.015169912 val_loss: 0.032462843
# Step = 21 train_loss: 0.019038083 val_loss: 0.03137846
# Step = 22 train_loss: 0.022760252 val_loss: 0.031431563
# Step = 23 train_loss: 0.021185635 val_loss: 0.032888897
# Step = 24 train_loss: 0.018425893 val_loss: 0.035810895
# Step = 25 train_loss: 0.017530061 val_loss: 0.040500436
# Step = 26 train_loss: 0.025015246 val_loss: 0.044874176
# Step = 27 train_loss: 0.018602353 val_loss: 0.04648366
# Step = 28 train_loss: 0.018233027 val_loss: 0.04642927
# Step = 29 train_loss: 0.018078642 val_loss: 0.04648657
# Step = 30 train_loss: 0.015755916 val_loss: 0.048824582
# Step = 31 train_loss: 0.009829607 val_loss: 0.051726826
# Step = 32 train_loss: 0.014503981 val_loss: 0.053862248
# Step = 33 train_loss: 0.019636821 val_loss: 0.055361457
# Step = 34 train_loss: 0.02395953 val_loss: 0.054209318
# Step = 35 train_loss: 0.019317238 val_loss: 0.052072875
# Step = 36 train_loss: 0.013931783 val_loss: 0.049833253
# Step = 37 train_loss: 0.014509231 val_loss: 0.04779401
# Step = 38 train_loss: 0.017820489 val_loss: 0.046031702
# Step = 39 train_loss: 0.016945478 val_loss: 0.04423733
# Step = 40 train_loss: 0.015363766 val_loss: 0.043460745
# Step = 41 train_loss: 0.015273785 val_loss: 0.041787937
# Step = 42 train_loss: 0.019979753 val_loss: 0.037865732
# Step = 43 train_loss: 0.016695935 val_loss: 0.03443936
# Step = 44 train_loss: 0.019827498 val_loss: 0.03172879
# Step = 45 train_loss: 0.010837068 val_loss: 0.029355137
# Step = 46 train_loss: 0.01577174 val_loss: 0.02689401
# Step = 47 train_loss: 0.013380643 val_loss: 0.024298614
# Step = 48 train_loss: 0.016512109 val_loss: 0.02207898
# Step = 49 train_loss: 0.009310783 val_loss: 0.01981504
# Step = 50 train_loss: 0.013977265 val_loss: 0.018108318
# Step = 51 train_loss: 0.017397342 val_loss: 0.017100362
# Step = 52 train_loss: 0.014579119 val_loss: 0.016024584
# Step = 53 train_loss: 0.016874459 val_loss: 0.015599489
# Step = 54 train_loss: 0.0110427 val_loss: 0.0151469605
# Step = 55 train_loss: 0.016582293 val_loss: 0.014458145
# Step = 56 train_loss: 0.017587649 val_loss: 0.015411409
# Step = 57 train_loss: 0.014431892 val_loss: 0.02013237
# Step = 58 train_loss: 0.010324455 val_loss: 0.02360337
# Step = 59 train_loss: 0.0085382145 val_loss: 0.023264514
# Step = 60 train_loss: 0.011732573 val_loss: 0.019932909
# Step = 61 train_loss: 0.008691272 val_loss: 0.016467111
# Step = 62 train_loss: 0.011107101 val_loss: 0.0148887085
# Step = 63 train_loss: 0.008898503 val_loss: 0.022781331
# Step = 64 train_loss: 0.008347818 val_loss: 0.05270405
# Step = 65 train_loss: 0.010918589 val_loss: 0.105274156
# Step = 66 train_loss: 0.0070280293 val_loss: 0.14894176
# Step = 67 train_loss: 0.008102556 val_loss: 0.18296047
# Step = 68 train_loss: 0.008525066 val_loss: 0.19202876
# Step = 69 train_loss: 0.006407847 val_loss: 0.19059464
# Step = 70 train_loss: 0.0062646638 val_loss: 0.19009969
# Step = 71 train_loss: 0.006968128 val_loss: 0.19163382
# Step = 72 train_loss: 0.009032402 val_loss: 0.19312273
# Step = 73 train_loss: 0.007150226 val_loss: 0.18693598
# Step = 74 train_loss: 0.007827407 val_loss: 0.17530972
# Step = 75 train_loss: 0.0068101357 val_loss: 0.16133858
# Step = 76 train_loss: 0.008326854 val_loss: 0.14216182
# Step = 77 train_loss: 0.007097985 val_loss: 0.11564221
# Step = 78 train_loss: 0.0051303958 val_loss: 0.08209464
# Step = 79 train_loss: 0.007274385 val_loss: 0.04220546
# Step = 80 train_loss: 0.008246475 val_loss: 0.013955148
# Step = 81 train_loss: 0.0065786513 val_loss: 0.013079257
# Step = 82 train_loss: 0.005173824 val_loss: 0.03202451
# Step = 83 train_loss: 0.004224561 val_loss: 0.053303923
# Step = 84 train_loss: 0.0040411893 val_loss: 0.064130634
# Step = 85 train_loss: 0.006196241 val_loss: 0.06965419
# Step = 86 train_loss: 0.007495326 val_loss: 0.071896456
# Step = 87 train_loss: 0.005955687 val_loss: 0.0728527
# Step = 88 train_loss: 0.0071484703 val_loss: 0.07346157
# Step = 89 train_loss: 0.008300561 val_loss: 0.074077316
# Step = 90 train_loss: 0.0060500484 val_loss: 0.07489694
# Step = 91 train_loss: 0.008070435 val_loss: 0.075418316
# Step = 92 train_loss: 0.007671496 val_loss: 0.07570006
# Step = 93 train_loss: 0.0070874137 val_loss: 0.07577599
# Step = 94 train_loss: 0.0038957668 val_loss: 0.075840205
# Step = 95 train_loss: 0.007594744 val_loss: 0.07579462
# Step = 96 train_loss: 0.0041564265 val_loss: 0.07578705
# Step = 97 train_loss: 0.0038159129 val_loss: 0.0756904
# Step = 98 train_loss: 0.0040272283 val_loss: 0.07548324
# Step = 99 train_loss: 0.0064261733 val_loss: 0.075264394
# Step = 100 train_loss: 0.011111568 val_loss: 0.075000614
# Step = 101 train_loss: 0.0062833494 val_loss: 0.074766256
# Step = 102 train_loss: 0.0075097424 val_loss: 0.07452963
# Step = 103 train_loss: 0.00594425 val_loss: 0.07429401
# Step = 104 train_loss: 0.007495445 val_loss: 0.07409026
# Step = 105 train_loss: 0.0057525625 val_loss: 0.07388421
# Step = 106 train_loss: 0.0061655063 val_loss: 0.073801406
# Step = 107 train_loss: 0.007825596 val_loss: 0.07401379
# Step = 108 train_loss: 0.00615683 val_loss: 0.07424939
# Step = 109 train_loss: 0.005772956 val_loss: 0.074624315
# Step = 110 train_loss: 0.008544903 val_loss: 0.075103246
# Step = 111 train_loss: 0.005434806 val_loss: 0.07523267
# Step = 112 train_loss: 0.0044392976 val_loss: 0.07507013
# Step = 113 train_loss: 0.006520832 val_loss: 0.074599214
# Step = 114 train_loss: 0.005197509 val_loss: 0.07392713
# Step = 115 train_loss: 0.0038710064 val_loss: 0.073105186
# Step = 116 train_loss: 0.005385835 val_loss: 0.071732685
# Step = 117 train_loss: 0.0072479304 val_loss: 0.068176225
# Step = 118 train_loss: 0.006570884 val_loss: 0.04533025
# Step = 119 train_loss: 0.003779739 val_loss: 0.011048083
# Step = 120 train_loss: 0.0056627747 val_loss: 0.05914368
# Step = 121 train_loss: 0.0060198726 val_loss: 0.16503507
# Step = 122 train_loss: 0.008089774 val_loss: 0.2261829
# Step = 123 train_loss: 0.0057728407 val_loss: 0.24968638
# Step = 124 train_loss: 0.0062671867 val_loss: 0.24582332
# Step = 125 train_loss: 0.0057618967 val_loss: 0.23863734
# Step = 126 train_loss: 0.010326032 val_loss: 0.21801227
# Step = 127 train_loss: 0.0066987225 val_loss: 0.17854042
# Step = 128 train_loss: 0.006511351 val_loss: 0.11858378
# Step = 129 train_loss: 0.0037328096 val_loss: 0.0560981
# Step = 130 train_loss: 0.0054455427 val_loss: 0.0084994165
# Step = 131 train_loss: 0.003028533 val_loss: 0.009175922
# Step = 132 train_loss: 0.0071739447 val_loss: 0.009934993
# Step = 133 train_loss: 0.0043434766 val_loss: 0.007831663
# Step = 134 train_loss: 0.0083740195 val_loss: 0.022281298
# Step = 135 train_loss: 0.0052071195 val_loss: 0.042722344
# Step = 136 train_loss: 0.0046294886 val_loss: 0.05188851
# Step = 137 train_loss: 0.003835859 val_loss: 0.05491694
# Step = 138 train_loss: 0.0022190202 val_loss: 0.03705229
# Step = 139 train_loss: 0.004782252 val_loss: 0.008976022
# Step = 140 train_loss: 0.0035706384 val_loss: 0.011583992
# Step = 141 train_loss: 0.004385833 val_loss: 0.035575338
# Step = 142 train_loss: 0.0031182442 val_loss: 0.04044577
# Step = 143 train_loss: 0.003113913 val_loss: 0.03633084
# Step = 144 train_loss: 0.006989223 val_loss: 0.041059725
# Step = 145 train_loss: 0.0044829445 val_loss: 0.31903642
# Step = 146 train_loss: 0.005662153 val_loss: 0.3271505
# Step = 147 train_loss: 0.0048162695 val_loss: 0.37286118
# Step = 148 train_loss: 0.0052071456 val_loss: 0.3888456
# Step = 149 train_loss: 0.005273882 val_loss: 0.40680587
# Step = 150 train_loss: 0.005982375 val_loss: 0.42628694
# Step = 151 train_loss: 0.0064360867 val_loss: 0.4322859
# Step = 152 train_loss: 0.0035922104 val_loss: 0.46533218
# Step = 153 train_loss: 0.004798197 val_loss: 0.47893956
# Step = 154 train_loss: 0.007474319 val_loss: 0.48048294
# Step = 155 train_loss: 0.004207049 val_loss: 0.47306627
# Step = 156 train_loss: 0.0067130704 val_loss: 0.4844784
# Step = 157 train_loss: 0.007988876 val_loss: 0.44548035
# Step = 158 train_loss: 0.008259807 val_loss: 0.43093216
# Step = 159 train_loss: 0.010301193 val_loss: 0.41919503
# Step = 160 train_loss: 0.0062942854 val_loss: 0.37468728
# Step = 161 train_loss: 0.0046765674 val_loss: 0.20254011
# Step = 162 train_loss: 0.0027298634 val_loss: 0.014822211
# Step = 163 train_loss: 0.011941662 val_loss: 0.008922169
# Step = 164 train_loss: 0.0043821875 val_loss: 0.015288234
# Step = 165 train_loss: 0.0033586917 val_loss: 0.3036437
# Step = 166 train_loss: 0.0040651155 val_loss: 0.4703478
# Step = 167 train_loss: 0.0033439363 val_loss: 0.46174586
# Step = 168 train_loss: 0.006325634 val_loss: 0.44109815
# Step = 169 train_loss: 0.0055763554 val_loss: 0.23531635
# Step = 170 train_loss: 0.0064489297 val_loss: 0.020938123
# Step = 171 train_loss: 0.0040613366 val_loss: 0.04446269
# Step = 172 train_loss: 0.004390808 val_loss: 0.027843595
# Step = 173 train_loss: 0.008211437 val_loss: 0.037794895
# Step = 174 train_loss: 0.006659297 val_loss: 0.03292767
# Step = 175 train_loss: 0.0040634396 val_loss: 0.034009933
# Step = 176 train_loss: 0.0046758014 val_loss: 0.036407884
# Step = 177 train_loss: 0.003696121 val_loss: 0.038850274
# Step = 178 train_loss: 0.0059585627 val_loss: 0.04024912
# Step = 179 train_loss: 0.010035872 val_loss: 0.044224996
# Step = 180 train_loss: 0.0153567735 val_loss: 0.04766241
# Step = 181 train_loss: 0.0067831716 val_loss: 0.04687307
# Step = 182 train_loss: 0.0058801402 val_loss: 0.04309357
# Step = 183 train_loss: 0.011431644 val_loss: 0.041552313
# Step = 184 train_loss: 0.008699844 val_loss: 0.04131084
# Step = 185 train_loss: 0.010034095 val_loss: 0.050152455
# Step = 186 train_loss: 0.010423759 val_loss: 0.06090523
# Step = 187 train_loss: 0.0029259347 val_loss: 0.0703665
# Step = 188 train_loss: 0.016059864 val_loss: 0.07647874
# Step = 189 train_loss: 0.008660579 val_loss: 0.07732429
# Step = 190 train_loss: 0.008039108 val_loss: 0.06755393
# Step = 191 train_loss: 0.0037154225 val_loss: 0.026512954
# Step = 192 train_loss: 0.0045806225 val_loss: 0.0141664455
# Step = 193 train_loss: 0.0057846275 val_loss: 0.027777173
# Step = 194 train_loss: 0.004623887 val_loss: 0.045353163
# Step = 195 train_loss: 0.00481607 val_loss: 0.05035248
# Step = 196 train_loss: 0.002973871 val_loss: 0.049688455
# Step = 197 train_loss: 0.0031558115 val_loss: 0.046429377
# Step = 198 train_loss: 0.008624464 val_loss: 0.4612537
# Step = 199 train_loss: 0.0077351504 val_loss: 0.50322455
# Step = 200 train_loss: 0.0045013567 val_loss: 0.3987193
# Step = 201 train_loss: 0.007902646 val_loss: 0.35607523
# Step = 202 train_loss: 0.0060177078 val_loss: 0.32971388
# Step = 203 train_loss: 0.015721252 val_loss: 0.3494539
# Step = 204 train_loss: 0.01836177 val_loss: 0.39481264
# Step = 205 train_loss: 0.016574858 val_loss: 0.44045538
# Step = 206 train_loss: 0.014852977 val_loss: 0.46913952
# Step = 207 train_loss: 0.020066006 val_loss: 0.4777643
# Step = 208 train_loss: 0.013530131 val_loss: 0.4850511
# Step = 209 train_loss: 0.011533231 val_loss: 0.4971854
# Step = 210 train_loss: 0.015248443 val_loss: 0.5069062
# Step = 211 train_loss: 0.012344558 val_loss: 0.50922346
# Step = 212 train_loss: 0.011277908 val_loss: 0.5093872
# Step = 213 train_loss: 0.012605661 val_loss: 0.5090006
# Step = 214 train_loss: 0.021324476 val_loss: 0.49765977
# Step = 215 train_loss: 0.019444901 val_loss: 0.34972286
# Step = 216 train_loss: 0.005898994 val_loss: 0.0173324
# Step = 217 train_loss: 0.010538537 val_loss: 0.018092304
# Step = 218 train_loss: 0.0066039036 val_loss: 0.026517257
# Step = 219 train_loss: 0.006756707 val_loss: 0.031054486
# Step = 220 train_loss: 0.0036956968 val_loss: 0.032761693
# Step = 221 train_loss: 0.0050876928 val_loss: 0.035691418
# Step = 222 train_loss: 0.0067774737 val_loss: 0.03873834
# Step = 223 train_loss: 0.009331419 val_loss: 0.03999566
# Step = 224 train_loss: 0.008125726 val_loss: 0.04053529
# Step = 225 train_loss: 0.010883878 val_loss: 0.04138022
# Step = 226 train_loss: 0.0026988792 val_loss: 0.04208436
# Step = 227 train_loss: 0.0031710672 val_loss: 0.04442268
# Step = 228 train_loss: 0.0045451927 val_loss: 0.043975294
# Step = 229 train_loss: 0.0025892034 val_loss: 0.041665033
# Step = 230 train_loss: 0.0045969747 val_loss: 0.042676046
# Step = 231 train_loss: 0.0073694307 val_loss: 0.04314766
# Step = 232 train_loss: 0.002972398 val_loss: 0.019947369
# Step = 233 train_loss: 0.006917186 val_loss: 0.039871417
# Step = 234 train_loss: 0.003692277 val_loss: 0.042805564
# Step = 235 train_loss: 0.0027934574 val_loss: 0.040205535
# Step = 236 train_loss: 0.010674512 val_loss: 0.03363447
# Step = 237 train_loss: 0.0040073716 val_loss: 0.15256573
# Step = 238 train_loss: 0.0049868682 val_loss: 0.1940332
# Step = 239 train_loss: 0.004736504 val_loss: 0.08160596
# Step = 240 train_loss: 0.0052078394 val_loss: 0.056011394
# Step = 241 train_loss: 0.002391066 val_loss: 0.052802574
# Step = 242 train_loss: 0.0065988144 val_loss: 0.05349879
# Step = 243 train_loss: 0.0047755367 val_loss: 0.053600136
# Step = 244 train_loss: 0.007558453 val_loss: 0.049075354
# Step = 245 train_loss: 0.003613555 val_loss: 0.04516274
# Step = 246 train_loss: 0.0026346217 val_loss: 0.042228177
# Step = 247 train_loss: 0.0042536524 val_loss: 0.04137105
# Step = 248 train_loss: 0.003324678 val_loss: 0.03621127
# Step = 249 train_loss: 0.006244757 val_loss: 0.029521542
# Step = 250 train_loss: 0.0027374844 val_loss: 0.025063738
# Step = 251 train_loss: 0.006181853 val_loss: 0.021442907
# Step = 252 train_loss: 0.0061040204 val_loss: 0.01927304
# Step = 253 train_loss: 0.0022548628 val_loss: 0.01778921
# Step = 254 train_loss: 0.0024835025 val_loss: 0.10720537
# Step = 255 train_loss: 0.0055640256 val_loss: 0.0337985
# Step = 256 train_loss: 0.0073162187 val_loss: 0.01272463
# Step = 257 train_loss: 0.003639322 val_loss: 0.01597938
# Step = 258 train_loss: 0.008527578 val_loss: 0.018526241
# Step = 259 train_loss: 0.0058945836 val_loss: 0.020487221
# Step = 260 train_loss: 0.0032889966 val_loss: 0.022486588
# Step = 261 train_loss: 0.0054508774 val_loss: 0.022105282
# Step = 262 train_loss: 0.0052444767 val_loss: 0.0064544487
# Step = 263 train_loss: 0.0051687052 val_loss: 0.08333187
# Step = 264 train_loss: 0.005938199 val_loss: 0.31940058
# Step = 265 train_loss: 0.002431779 val_loss: 0.43713704
# Step = 266 train_loss: 0.0017753479 val_loss: 0.47268206
# Step = 267 train_loss: 0.0066997586 val_loss: 0.4587427
# Step = 268 train_loss: 0.0052502775 val_loss: 0.3943871
# Step = 269 train_loss: 0.004024914 val_loss: 0.17439502
# Step = 270 train_loss: 0.0019825683 val_loss: 0.026270756
# Step = 271 train_loss: 0.0040974207 val_loss: 0.005146609
# Step = 272 train_loss: 0.0042977906 val_loss: 0.027330128
# Step = 273 train_loss: 0.0035592031 val_loss: 0.030544266
# Step = 274 train_loss: 0.004878508 val_loss: 0.031585436
# Step = 275 train_loss: 0.0069921785 val_loss: 0.031978562
# Step = 276 train_loss: 0.003882072 val_loss: 0.032425296
# Step = 277 train_loss: 0.0027656727 val_loss: 0.03280439
# Step = 278 train_loss: 0.0025380852 val_loss: 0.033365563
# Step = 279 train_loss: 0.0064431215 val_loss: 0.034040295
# Step = 280 train_loss: 0.0018040978 val_loss: 0.03449234
# Step = 281 train_loss: 0.002141606 val_loss: 0.03466233
# Step = 282 train_loss: 0.0032978123 val_loss: 0.034545317
# Step = 283 train_loss: 0.0034604038 val_loss: 0.03445689
# Step = 284 train_loss: 0.0040337685 val_loss: 0.034615345
# Step = 285 train_loss: 0.0024143707 val_loss: 0.034926727
# Step = 286 train_loss: 0.0020641026 val_loss: 0.03509474
# Step = 287 train_loss: 0.0038145287 val_loss: 0.035325278
# Step = 288 train_loss: 0.0030151291 val_loss: 0.035540402
# Step = 289 train_loss: 0.004119743 val_loss: 0.035744276
# Step = 290 train_loss: 0.002038919 val_loss: 0.035893552
# Step = 291 train_loss: 0.0028807085 val_loss: 0.036010787
# Step = 292 train_loss: 0.0026534905 val_loss: 0.035878357
# Step = 293 train_loss: 0.002417357 val_loss: 0.0355177
# Step = 294 train_loss: 0.0026234288 val_loss: 0.034842502
# Step = 295 train_loss: 0.0023248435 val_loss: 0.033985384
# Step = 296 train_loss: 0.004323522 val_loss: 0.03275043
# Step = 297 train_loss: 0.0014872003 val_loss: 0.031602878
# Step = 298 train_loss: 0.0045567527 val_loss: 0.030682825
# Step = 299 train_loss: 0.0042367894 val_loss: 0.029962013
# Step = 300 train_loss: 0.0033348673 val_loss: 0.029246313
# Step = 301 train_loss: 0.0022631022 val_loss: 0.02852455
# Step = 302 train_loss: 0.0031450803 val_loss: 0.02775925
# Step = 303 train_loss: 0.0031098824 val_loss: 0.026829388
# Step = 304 train_loss: 0.0014398106 val_loss: 0.025585445
# Step = 305 train_loss: 0.0036998328 val_loss: 0.023728188
# Step = 306 train_loss: 0.0041067 val_loss: 0.022172693
# Step = 307 train_loss: 0.0022067411 val_loss: 0.01952283
# Step = 308 train_loss: 0.0037469147 val_loss: 0.015852699
# Step = 309 train_loss: 0.0022447922 val_loss: 0.013918089
# Step = 310 train_loss: 0.0018215039 val_loss: 0.011624209
# Step = 311 train_loss: 0.002618586 val_loss: 0.01199125
# Step = 312 train_loss: 0.0034055077 val_loss: 0.014510613
# Step = 313 train_loss: 0.0033644417 val_loss: 0.020129211
# Step = 314 train_loss: 0.0029291485 val_loss: 0.02165527
# Step = 315 train_loss: 0.0030982941 val_loss: 0.030095205
# Step = 316 train_loss: 0.003672918 val_loss: 0.034394514
# Step = 317 train_loss: 0.0025668505 val_loss: 0.03479564
# Step = 318 train_loss: 0.0038436577 val_loss: 0.033826914
# Step = 319 train_loss: 0.0035027026 val_loss: 0.020892728
# Step = 320 train_loss: 0.0023407748 val_loss: 0.021973576
# Step = 321 train_loss: 0.0029740126 val_loss: 0.16931565
# Step = 322 train_loss: 0.0026741314 val_loss: 0.38161162
# Step = 323 train_loss: 0.0010940061 val_loss: 0.45406315
# Step = 324 train_loss: 0.003206477 val_loss: 0.48179036
# Step = 325 train_loss: 0.0045065125 val_loss: 0.48591375
# Step = 326 train_loss: 0.003828619 val_loss: 0.48722336
# Step = 327 train_loss: 0.0038387713 val_loss: 0.4878692
# Step = 328 train_loss: 0.003580355 val_loss: 0.48723087
# Step = 329 train_loss: 0.009038903 val_loss: 0.48445338
# Step = 330 train_loss: 0.0072503556 val_loss: 0.45773733
# Step = 331 train_loss: 0.0048018177 val_loss: 0.27096382
# Step = 332 train_loss: 0.0043287766 val_loss: 0.014112281
# Step = 333 train_loss: 0.0030384471 val_loss: 0.0301182
# Step = 334 train_loss: 0.0027901852 val_loss: 0.03737334
# Step = 335 train_loss: 0.003541281 val_loss: 0.03809764
# Step = 336 train_loss: 0.0019626454 val_loss: 0.038131293
# Step = 337 train_loss: 0.001729992 val_loss: 0.037948478
# Step = 338 train_loss: 0.0049271616 val_loss: 0.03863475
# Step = 339 train_loss: 0.0044877874 val_loss: 0.03796104
# Step = 340 train_loss: 0.0050176685 val_loss: 0.037088558
# Step = 341 train_loss: 0.0034804805 val_loss: 0.036145706
# Step = 342 train_loss: 0.002134611 val_loss: 0.035161324
# Step = 343 train_loss: 0.007528935 val_loss: 0.034179717
# Step = 344 train_loss: 0.0050961752 val_loss: 0.029383369
# Step = 345 train_loss: 0.0023964911 val_loss: 0.0049880603
# Step = 346 train_loss: 0.0039122645 val_loss: 0.0074228854
# Step = 347 train_loss: 0.0036655539 val_loss: 0.010142932
# Step = 348 train_loss: 0.0019879816 val_loss: 0.027018966
# Step = 349 train_loss: 0.0037651884 val_loss: 0.047235377
# Step = 350 train_loss: 0.0038603065 val_loss: 0.016198214
# Step = 351 train_loss: 0.0017803552 val_loss: 0.0050678025
# Step = 352 train_loss: 0.0025916013 val_loss: 0.014720513
# Step = 353 train_loss: 0.005623038 val_loss: 0.028905476
# Step = 354 train_loss: 0.0030296135 val_loss: 0.03252966
# Step = 355 train_loss: 0.0027923654 val_loss: 0.033884294
# Step = 356 train_loss: 0.0021041208 val_loss: 0.034788515
# Step = 357 train_loss: 0.0028938965 val_loss: 0.034304637
# Step = 358 train_loss: 0.0019163738 val_loss: 0.08066045
# Step = 359 train_loss: 0.003196701 val_loss: 0.48579317
# Step = 360 train_loss: 0.005205266 val_loss: 0.48800153
# Step = 361 train_loss: 0.0055519696 val_loss: 0.47915208
# Step = 362 train_loss: 0.005343639 val_loss: 0.02186978
# Step = 363 train_loss: 0.007083763 val_loss: 0.044123754
# Step = 364 train_loss: 0.0037268833 val_loss: 0.045830667
# Step = 365 train_loss: 0.004580331 val_loss: 0.047532566
# Step = 366 train_loss: 0.004697866 val_loss: 0.04894562
# Step = 367 train_loss: 0.0036183635 val_loss: 0.048228893
# Step = 368 train_loss: 0.002981393 val_loss: 0.044826977
# Step = 369 train_loss: 0.0023461538 val_loss: 0.042516124
# Step = 370 train_loss: 0.002301081 val_loss: 0.038909707
# Step = 371 train_loss: 0.0026940508 val_loss: 0.03541438
# Step = 372 train_loss: 0.0031253598 val_loss: 0.028534615
# Step = 373 train_loss: 0.0025619045 val_loss: 0.2043115
# Step = 374 train_loss: 0.003437171 val_loss: 0.42732298
# Step = 375 train_loss: 0.0025786895 val_loss: 0.13524728
# Step = 376 train_loss: 0.0023500584 val_loss: 0.010466786
# Step = 377 train_loss: 0.003909683 val_loss: 0.033092126
# Step = 378 train_loss: 0.0043494944 val_loss: 0.036911435
# Step = 379 train_loss: 0.0015847558 val_loss: 0.038351182
# Step = 380 train_loss: 0.0024820738 val_loss: 0.038424194
# Step = 381 train_loss: 0.006243597 val_loss: 0.1301248
# Step = 382 train_loss: 0.0018304356 val_loss: 0.47817853
# Step = 383 train_loss: 0.0044645565 val_loss: 0.42202592
# Step = 384 train_loss: 0.006622751 val_loss: 0.46004668
# Step = 385 train_loss: 0.007667804 val_loss: 0.49511012
# Step = 386 train_loss: 0.0038437706 val_loss: 0.48669428
# Step = 387 train_loss: 0.009468626 val_loss: 0.24884556
# Step = 388 train_loss: 0.007162251 val_loss: 0.009156801
# Step = 389 train_loss: 0.007340432 val_loss: 0.05284411
# Step = 390 train_loss: 0.0049126265 val_loss: 0.04595747
# Step = 391 train_loss: 0.0058256485 val_loss: 0.039087858
# Step = 392 train_loss: 0.0030416674 val_loss: 0.033683896
# Step = 393 train_loss: 0.0037282514 val_loss: 0.02558431
# Step = 394 train_loss: 0.0027060534 val_loss: 0.021643285
# Step = 395 train_loss: 0.0041622375 val_loss: 0.020537743
# Step = 396 train_loss: 0.0041426676 val_loss: 0.02219979
# Step = 397 train_loss: 0.0042915996 val_loss: 0.029848348
# Step = 398 train_loss: 0.002521162 val_loss: 0.03893885
# Step = 399 train_loss: 0.0030008554 val_loss: 0.047339734
# Step = 400 train_loss: 0.0034422514 val_loss: 0.010255501
# Step = 401 train_loss: 0.0061154785 val_loss: 0.012820329
# Step = 402 train_loss: 0.004111059 val_loss: 0.030731445
# Step = 403 train_loss: 0.0039085154 val_loss: 0.46674728
# Step = 404 train_loss: 0.00420054 val_loss: 0.36668286
# Step = 405 train_loss: 0.0031796324 val_loss: 0.35369423
# Step = 406 train_loss: 0.004376084 val_loss: 0.112808265
# Step = 407 train_loss: 0.0038195488 val_loss: 0.0041730334
# Step = 408 train_loss: 0.0028952835 val_loss: 0.009264361
# Step = 409 train_loss: 0.0034119135 val_loss: 0.043817602
# Step = 410 train_loss: 0.0030788793 val_loss: 0.051259745
# Step = 411 train_loss: 0.007090452 val_loss: 0.009774872
# Step = 412 train_loss: 0.0039548967 val_loss: 0.021040183
# Step = 413 train_loss: 0.0038501467 val_loss: 0.035110794
# Step = 414 train_loss: 0.003318153 val_loss: 0.030524408
# Step = 415 train_loss: 0.0029155635 val_loss: 0.107425675
# Step = 416 train_loss: 0.004655665 val_loss: 0.09581289
# Step = 417 train_loss: 0.005107954 val_loss: 0.03039532
# Step = 418 train_loss: 0.0022227499 val_loss: 0.033399563
# Step = 419 train_loss: 0.0082609495 val_loss: 0.028712848
# Step = 420 train_loss: 0.0018369704 val_loss: 0.020184731
# Step = 421 train_loss: 0.0036916009 val_loss: 0.04302227
# Step = 422 train_loss: 0.0032339687 val_loss: 0.044604544
# Step = 423 train_loss: 0.0037428897 val_loss: 0.045438662
# Step = 424 train_loss: 0.0033801682 val_loss: 0.04601664
# Step = 425 train_loss: 0.0025639103 val_loss: 0.045584973
# Step = 426 train_loss: 0.0020095317 val_loss: 0.1473788
# Step = 427 train_loss: 0.0020830971 val_loss: 0.48254403
# Step = 428 train_loss: 0.002209308 val_loss: 0.48215666
# Step = 429 train_loss: 0.0030670199 val_loss: 0.48165223
# Step = 430 train_loss: 0.0032325701 val_loss: 0.48170182
# Step = 431 train_loss: 0.004680306 val_loss: 0.46909183
# Step = 432 train_loss: 0.0034791068 val_loss: 0.3785833
# Step = 433 train_loss: 0.005846957 val_loss: 0.41125378
# Step = 434 train_loss: 0.004250681 val_loss: 0.13592696
# Step = 435 train_loss: 0.0031121357 val_loss: 0.09520335
# Step = 436 train_loss: 0.005354973 val_loss: 0.09468582
# Step = 437 train_loss: 0.0052730935 val_loss: 0.09927831
# Step = 438 train_loss: 0.0023193317 val_loss: 0.10456105
# Step = 439 train_loss: 0.0013498864 val_loss: 0.11251037
# Step = 440 train_loss: 0.008216298 val_loss: 0.12286056
# Step = 441 train_loss: 0.001535651 val_loss: 0.13022096
# Step = 442 train_loss: 0.0025925715 val_loss: 0.13281445
# Step = 443 train_loss: 0.0013874222 val_loss: 0.13536347
# Step = 444 train_loss: 0.001612804 val_loss: 0.13775152
# Step = 445 train_loss: 0.0024163988 val_loss: 0.12607652
# Step = 446 train_loss: 0.002788555 val_loss: 0.10068348
# Step = 447 train_loss: 0.0019062818 val_loss: 0.08247867
# Step = 448 train_loss: 0.0022591178 val_loss: 0.066969104
# Step = 449 train_loss: 0.0028495295 val_loss: 0.050649848
# Step = 450 train_loss: 0.002803892 val_loss: 0.038496844
# Step = 451 train_loss: 0.003749721 val_loss: 0.027768767
# Step = 452 train_loss: 0.0040934337 val_loss: 0.02118483
# Step = 453 train_loss: 0.002932621 val_loss: 0.016497085
# Step = 454 train_loss: 0.0013136507 val_loss: 0.014370664
# Step = 455 train_loss: 0.0023557323 val_loss: 0.012934672
# Step = 456 train_loss: 0.002707555 val_loss: 0.015592306
# Step = 457 train_loss: 0.0030082022 val_loss: 0.017392712
# Step = 458 train_loss: 0.0019662655 val_loss: 0.019021766
# Step = 459 train_loss: 0.0022252293 val_loss: 0.01998181
# Step = 460 train_loss: 0.003187864 val_loss: 0.021800201
# Step = 461 train_loss: 0.003526747 val_loss: 0.023906088
# Step = 462 train_loss: 0.0022692448 val_loss: 0.025658425
# Step = 463 train_loss: 0.0017010941 val_loss: 0.027462997
# Step = 464 train_loss: 0.001414358 val_loss: 0.029221717
# Step = 465 train_loss: 0.003186338 val_loss: 0.03097488
# Step = 466 train_loss: 0.0020717273 val_loss: 0.030138753
# Step = 467 train_loss: 0.0015812148 val_loss: 0.00871598
# Step = 468 train_loss: 0.0016182496 val_loss: 0.034752168
# Step = 469 train_loss: 0.0019120009 val_loss: 0.15486713
# Step = 470 train_loss: 0.0023632264 val_loss: 0.2246478
# Step = 471 train_loss: 0.002347023 val_loss: 0.19789688
# Step = 472 train_loss: 0.0013884363 val_loss: 0.13979173
# Step = 473 train_loss: 0.0063476814 val_loss: 0.0480695
# Step = 474 train_loss: 0.004635646 val_loss: 0.005446695
# Step = 475 train_loss: 0.002238162 val_loss: 0.021411575
# Step = 476 train_loss: 0.0027440554 val_loss: 0.027707519
# Step = 477 train_loss: 0.0024760142 val_loss: 0.029276019
# Step = 478 train_loss: 0.0011901062 val_loss: 0.030399054
# Step = 479 train_loss: 0.0014691313 val_loss: 0.02994301
# Step = 480 train_loss: 0.0040910793 val_loss: 0.02747346
# Step = 481 train_loss: 0.003075659 val_loss: 0.021681143
# Step = 482 train_loss: 0.002313455 val_loss: 0.019619389
# Step = 483 train_loss: 0.0010968914 val_loss: 0.019186798
# Step = 484 train_loss: 0.0020261628 val_loss: 0.022205187
# Step = 485 train_loss: 0.0018604696 val_loss: 0.023093067
# Step = 486 train_loss: 0.0026010103 val_loss: 0.02415183
# Step = 487 train_loss: 0.0010233942 val_loss: 0.024036199
# Step = 488 train_loss: 0.0022937534 val_loss: 0.024947917
# Step = 489 train_loss: 0.0023429417 val_loss: 0.023877041
# Step = 490 train_loss: 0.0015983639 val_loss: 0.022988748
# Step = 491 train_loss: 0.0026105738 val_loss: 0.021296
# Step = 492 train_loss: 0.002567285 val_loss: 0.020594696
# Step = 493 train_loss: 0.002335717 val_loss: 0.020195723
# Step = 494 train_loss: 0.0018480278 val_loss: 0.01985893
# Step = 495 train_loss: 0.0016800173 val_loss: 0.01991431
# Step = 496 train_loss: 0.002297932 val_loss: 0.019918656
# Step = 497 train_loss: 0.0065453 val_loss: 0.020228779
# Step = 498 train_loss: 0.002290772 val_loss: 0.020353641
# Step = 499 train_loss: 0.0018162716 val_loss: 0.020308377
# Step = 500 train_loss: 0.0014852697 val_loss: 0.02023979
# Step = 501 train_loss: 0.0036642095 val_loss: 0.020215329
# Step = 502 train_loss: 0.0015959603 val_loss: 0.020194136
# Step = 503 train_loss: 0.0015170866 val_loss: 0.020378988
# Step = 504 train_loss: 0.0031746547 val_loss: 0.02051235
# Step = 505 train_loss: 0.0020810037 val_loss: 0.021184865
# Step = 506 train_loss: 0.0019994623 val_loss: 0.021743726
# Step = 507 train_loss: 0.002796378 val_loss: 0.02284544
# Step = 508 train_loss: 0.0039627785 val_loss: 0.025214734
# Step = 509 train_loss: 0.0028962968 val_loss: 0.02833237
# Step = 510 train_loss: 0.0024092284 val_loss: 0.031491175
# Step = 511 train_loss: 0.0018629237 val_loss: 0.03384605
# Step = 512 train_loss: 0.0023500142 val_loss: 0.03528241
# Step = 513 train_loss: 0.0022857978 val_loss: 0.036377877
# Step = 514 train_loss: 0.0017393443 val_loss: 0.037257288
# Step = 515 train_loss: 0.003405326 val_loss: 0.037715197
# Step = 516 train_loss: 0.0013236766 val_loss: 0.037981648
# Step = 517 train_loss: 0.0029304517 val_loss: 0.03821007
# Step = 518 train_loss: 0.002027597 val_loss: 0.038232036
# Step = 519 train_loss: 0.0024879759 val_loss: 0.03838917
# Step = 520 train_loss: 0.0020121387 val_loss: 0.0385765
# Step = 521 train_loss: 0.0017702157 val_loss: 0.03873488
# Step = 522 train_loss: 0.0017155274 val_loss: 0.03881478
# Step = 523 train_loss: 0.004151781 val_loss: 0.03882722
# Step = 524 train_loss: 0.0030071733 val_loss: 0.038444355
# Step = 525 train_loss: 0.0018030963 val_loss: 0.0384018
# Step = 526 train_loss: 0.0012418533 val_loss: 0.038080614
# Step = 527 train_loss: 0.0024167134 val_loss: 0.03555052
# Step = 528 train_loss: 0.0019840612 val_loss: 0.02559349
# Step = 529 train_loss: 0.0014420566 val_loss: 0.009718321
# Step = 530 train_loss: 0.0019243504 val_loss: 0.013970368
# Step = 531 train_loss: 0.0030637286 val_loss: 0.10958789
# Step = 532 train_loss: 0.0022829352 val_loss: 0.28332213
# Step = 533 train_loss: 0.002036968 val_loss: 0.25800413
# Step = 534 train_loss: 0.0025251342 val_loss: 0.16006482
# Step = 535 train_loss: 0.0018939456 val_loss: 0.0463666
# Step = 536 train_loss: 0.0017750631 val_loss: 0.011786643
# Step = 537 train_loss: 0.0022677956 val_loss: 0.004647698
# Step = 538 train_loss: 0.0022671772 val_loss: 0.012022804
# Step = 539 train_loss: 0.0073310947 val_loss: 0.009511216
# Step = 540 train_loss: 0.0024864674 val_loss: 0.013638322
# Step = 541 train_loss: 0.0015682371 val_loss: 0.023724824
# Step = 542 train_loss: 0.0018954879 val_loss: 0.027259393
# Step = 543 train_loss: 0.0015435929 val_loss: 0.026553785
# Step = 544 train_loss: 0.0030484772 val_loss: 0.035100304
# Step = 545 train_loss: 0.0022394597 val_loss: 0.04134283
# Step = 546 train_loss: 0.002455402 val_loss: 0.042329583
# Step = 547 train_loss: 0.0024635007 val_loss: 0.041859183
# Step = 548 train_loss: 0.0016109976 val_loss: 0.04191443
# Step = 549 train_loss: 0.001477711 val_loss: 0.04220481
# Step = 550 train_loss: 0.0043275077 val_loss: 0.042982213
# Step = 551 train_loss: 0.0016672318 val_loss: 0.04324771
# Step = 552 train_loss: 0.0013935915 val_loss: 0.041388176
# Step = 553 train_loss: 0.0008029577 val_loss: 0.0280663
# Step = 554 train_loss: 0.0023747876 val_loss: 0.017207231
# Step = 555 train_loss: 0.0010147218 val_loss: 0.11419526
# Step = 556 train_loss: 0.0022922615 val_loss: 0.090033434
# Step = 557 train_loss: 0.0043799686 val_loss: 0.029435504
# Step = 558 train_loss: 0.003270443 val_loss: 0.04558822
# Step = 559 train_loss: 0.0024923796 val_loss: 0.045571372
# Step = 560 train_loss: 0.0018989457 val_loss: 0.041489996
# Step = 561 train_loss: 0.0020863148 val_loss: 0.020312231
# Step = 562 train_loss: 0.0024224392 val_loss: 0.45048118
# Step = 563 train_loss: 0.0022572568 val_loss: 0.45566005
# Step = 564 train_loss: 0.003974159 val_loss: 0.013832909
# Step = 565 train_loss: 0.0019451255 val_loss: 0.049055606
# Step = 566 train_loss: 0.0018844542 val_loss: 0.051888593
# Step = 567 train_loss: 0.0039439374 val_loss: 0.050055794
# Step = 568 train_loss: 0.004344498 val_loss: 0.027570631
# Step = 569 train_loss: 0.0041321227 val_loss: 0.1923025
# Step = 570 train_loss: 0.0031197993 val_loss: 0.49173158
# Step = 571 train_loss: 0.0034347945 val_loss: 0.49197817
# Step = 572 train_loss: 0.004380146 val_loss: 0.24896154
# Step = 573 train_loss: 0.005363922 val_loss: 0.043695454
# Step = 574 train_loss: 0.002496672 val_loss: 0.043860838
# Step = 575 train_loss: 0.014389142 val_loss: 0.044240832
# Step = 576 train_loss: 0.012641156 val_loss: 0.04613954
# Step = 577 train_loss: 0.01449874 val_loss: 0.049582366
# Step = 578 train_loss: 0.009630924 val_loss: 0.05549539
# Step = 579 train_loss: 0.00783894 val_loss: 0.4912415
# Step = 580 train_loss: 0.015319591 val_loss: 0.5095896
# Step = 581 train_loss: 0.007951459 val_loss: 0.50924414
# Step = 582 train_loss: 0.012333792 val_loss: 0.50893134
# Step = 583 train_loss: 0.019929301 val_loss: 0.50951195
# Step = 584 train_loss: 0.015894724 val_loss: 0.5095774
# Step = 585 train_loss: 0.005707629 val_loss: 0.50957876
# Step = 586 train_loss: 0.011094036 val_loss: 0.50954217
# Step = 587 train_loss: 0.014186592 val_loss: 0.5079059
# Step = 588 train_loss: 0.009133849 val_loss: 0.5017069
# Step = 589 train_loss: 0.0033770525 val_loss: 0.47908536
# Step = 590 train_loss: 0.002285045 val_loss: 0.36266956
# Step = 591 train_loss: 0.0050073275 val_loss: 0.32317007
# Step = 592 train_loss: 0.010337066 val_loss: 0.28281197
# Step = 593 train_loss: 0.008326496 val_loss: 0.46306053
# Step = 594 train_loss: 0.011054159 val_loss: 0.47540385
# Step = 595 train_loss: 0.0068272906 val_loss: 0.3909138
# Step = 596 train_loss: 0.0053853 val_loss: 0.17740427
# Step = 597 train_loss: 0.01050259 val_loss: 0.13337828
# Step = 598 train_loss: 0.013474877 val_loss: 0.4477617
# Step = 599 train_loss: 0.0052705687 val_loss: 0.49218607
# Step = 600 train_loss: 0.00848019 val_loss: 0.49073055
# Step = 601 train_loss: 0.00958495 val_loss: 0.45611417
# Step = 602 train_loss: 0.0063297283 val_loss: 0.07117047
# Step = 603 train_loss: 0.0022103698 val_loss: 0.014841834
# Step = 604 train_loss: 0.004968788 val_loss: 0.018328164
# Step = 605 train_loss: 0.0073056584 val_loss: 0.014518365
# Step = 606 train_loss: 0.005163818 val_loss: 0.0022385158
# Step = 607 train_loss: 0.0034854992 val_loss: 0.0070283436
# Step = 608 train_loss: 0.005597062 val_loss: 0.022016462
# Step = 609 train_loss: 0.0032824795 val_loss: 0.023152024
# Step = 610 train_loss: 0.0030381319 val_loss: 0.019499483
# Step = 611 train_loss: 0.00622509 val_loss: 0.020233195
# Step = 612 train_loss: 0.003407373 val_loss: 0.022007272
# Step = 613 train_loss: 0.003155024 val_loss: 0.02612822
# Step = 614 train_loss: 0.0038371438 val_loss: 0.030131122
# Step = 615 train_loss: 0.0021689413 val_loss: 0.034599658
# Step = 616 train_loss: 0.0036936481 val_loss: 0.033934224
# Step = 617 train_loss: 0.0032213838 val_loss: 0.023918757
# Step = 618 train_loss: 0.0035638104 val_loss: 0.035341773
# Step = 619 train_loss: 0.0024093243 val_loss: 0.038385198
# Step = 620 train_loss: 0.0023483401 val_loss: 0.03828996
# Step = 621 train_loss: 0.0033341208 val_loss: 0.03613494
# Step = 622 train_loss: 0.0039249975 val_loss: 0.03332912
# Step = 623 train_loss: 0.0013889088 val_loss: 0.03157093
# Step = 624 train_loss: 0.002516914 val_loss: 0.032619473
# Step = 625 train_loss: 0.0017282304 val_loss: 0.0339962
# Step = 626 train_loss: 0.0018245478 val_loss: 0.028633233
# Step = 627 train_loss: 0.00092293695 val_loss: 0.022034604
# Step = 628 train_loss: 0.0023790016 val_loss: 0.029228287
# Step = 629 train_loss: 0.0031691007 val_loss: 0.03281573
# Step = 630 train_loss: 0.0020530429 val_loss: 0.033934895
# Step = 631 train_loss: 0.003909817 val_loss: 0.03608655
# Step = 632 train_loss: 0.0018836528 val_loss: 0.039371606
# Step = 633 train_loss: 0.0025611152 val_loss: 0.04389837
# Step = 634 train_loss: 0.0021578171 val_loss: 0.046372607
# Step = 635 train_loss: 0.003169138 val_loss: 0.04631625
# Step = 636 train_loss: 0.0037949865 val_loss: 0.044525936
# Step = 637 train_loss: 0.0024802745 val_loss: 0.041734517
# Step = 638 train_loss: 0.0035999315 val_loss: 0.039730992
# Step = 639 train_loss: 0.0026460548 val_loss: 0.037936017
# Step = 640 train_loss: 0.003025998 val_loss: 0.036428284
# Step = 641 train_loss: 0.003400014 val_loss: 0.20034935
# Step = 642 train_loss: 0.0019137218 val_loss: 0.49204072
# Step = 643 train_loss: 0.002441855 val_loss: 0.5083416
# Step = 644 train_loss: 0.0038143606 val_loss: 0.50868493
# Step = 645 train_loss: 0.003461843 val_loss: 0.50591224
# Step = 646 train_loss: 0.003636841 val_loss: 0.49244192
# Step = 647 train_loss: 0.0038484458 val_loss: 0.44276646
# Step = 648 train_loss: 0.0031234622 val_loss: 0.01976367
# Step = 649 train_loss: 0.0040080133 val_loss: 0.04093347
# Step = 650 train_loss: 0.0024399273 val_loss: 0.05266706
# Step = 651 train_loss: 0.0034271805 val_loss: 0.05318377
# Step = 652 train_loss: 0.005437217 val_loss: 0.048540365
# Step = 653 train_loss: 0.0039869817 val_loss: 0.037392695
# Step = 654 train_loss: 0.0023950706 val_loss: 0.012862807
# Step = 655 train_loss: 0.002898637 val_loss: 0.0070367763
# Step = 656 train_loss: 0.003929846 val_loss: 0.015462671
# Step = 657 train_loss: 0.005566836 val_loss: 0.010982147
# Step = 658 train_loss: 0.0032915364 val_loss: 0.029403856
# Step = 659 train_loss: 0.0024336698 val_loss: 0.028305003
# Step = 660 train_loss: 0.0017722475 val_loss: 0.028181838
# Step = 661 train_loss: 0.0025871987 val_loss: 0.02853261
# Step = 662 train_loss: 0.00323812 val_loss: 0.02866556
# Step = 663 train_loss: 0.0019743398 val_loss: 0.029263718
# Step = 664 train_loss: 0.0016041275 val_loss: 0.030427923
# Step = 665 train_loss: 0.0036046968 val_loss: 0.032058664
# Step = 666 train_loss: 0.0021097725 val_loss: 0.033226933
# Step = 667 train_loss: 0.0023039451 val_loss: 0.03453538
# Step = 668 train_loss: 0.0025315038 val_loss: 0.035857756
# Step = 669 train_loss: 0.0032741649 val_loss: 0.036052935
# Step = 670 train_loss: 0.0028583084 val_loss: 0.03277916
# Step = 671 train_loss: 0.002899336 val_loss: 0.02841485
# Step = 672 train_loss: 0.0028410992 val_loss: 0.027919542
# Step = 673 train_loss: 0.0030478525 val_loss: 0.031523816
# Step = 674 train_loss: 0.0023702274 val_loss: 0.033954136
# Step = 675 train_loss: 0.0018497996 val_loss: 0.03500446
# Step = 676 train_loss: 0.0022459528 val_loss: 0.03566628
# Step = 677 train_loss: 0.0015061795 val_loss: 0.035657544
# Step = 678 train_loss: 0.0017506268 val_loss: 0.03553769
# Step = 679 train_loss: 0.0020485362 val_loss: 0.035245128
# Step = 680 train_loss: 0.0021953594 val_loss: 0.035003174
# Step = 681 train_loss: 0.0025577843 val_loss: 0.0345787
# Step = 682 train_loss: 0.0017847407 val_loss: 0.034171853
# Step = 683 train_loss: 0.0025666584 val_loss: 0.03357882
# Step = 684 train_loss: 0.0022019385 val_loss: 0.032867577
# Step = 685 train_loss: 0.0018741506 val_loss: 0.03140585
# Step = 686 train_loss: 0.002698491 val_loss: 0.029566795
# Step = 687 train_loss: 0.0033163987 val_loss: 0.027062796
# Step = 688 train_loss: 0.0032914851 val_loss: 0.024422128
# Step = 689 train_loss: 0.0022864654 val_loss: 0.022301031
# Step = 690 train_loss: 0.0022580726 val_loss: 0.021205004
# Step = 691 train_loss: 0.0014230746 val_loss: 0.02024941
# Step = 692 train_loss: 0.0026533203 val_loss: 0.019186532
# Step = 693 train_loss: 0.0012196058 val_loss: 0.018887136
# Step = 694 train_loss: 0.0018286011 val_loss: 0.018686868
# Step = 695 train_loss: 0.002642095 val_loss: 0.018462947
# Step = 696 train_loss: 0.001728498 val_loss: 0.018259833
# Step = 697 train_loss: 0.0020904357 val_loss: 0.018189996
# Step = 698 train_loss: 0.0018684269 val_loss: 0.018169874
# Step = 699 train_loss: 0.0017841168 val_loss: 0.018280357
# Step = 700 train_loss: 0.0028449045 val_loss: 0.018350042
# Step = 701 train_loss: 0.002695855 val_loss: 0.018411933
# Step = 702 train_loss: 0.0024675403 val_loss: 0.01853757
# Step = 703 train_loss: 0.002368481 val_loss: 0.018634064
# Step = 704 train_loss: 0.0015255715 val_loss: 0.018592605
# Step = 705 train_loss: 0.001817227 val_loss: 0.018581308
# Step = 706 train_loss: 0.0014232954 val_loss: 0.018557519
# Step = 707 train_loss: 0.0013323174 val_loss: 0.018254943
# Step = 708 train_loss: 0.0022059595 val_loss: 0.018373301
# Step = 709 train_loss: 0.0017566322 val_loss: 0.018336315
# Step = 710 train_loss: 0.0021487267 val_loss: 0.018352877
# Step = 711 train_loss: 0.001605897 val_loss: 0.018626515
# Step = 712 train_loss: 0.0018125258 val_loss: 0.019326286
# Step = 713 train_loss: 0.0015169877 val_loss: 0.020840423
# Step = 714 train_loss: 0.0019920939 val_loss: 0.02104273
# Step = 715 train_loss: 0.0025758157 val_loss: 0.019453758
# Step = 716 train_loss: 0.0019819513 val_loss: 0.018527942
# Step = 717 train_loss: 0.002110699 val_loss: 0.017190073
# Step = 718 train_loss: 0.0016594403 val_loss: 0.016142743
# Step = 719 train_loss: 0.0017860973 val_loss: 0.014338918
# Step = 720 train_loss: 0.0018376772 val_loss: 0.01344602
# Step = 721 train_loss: 0.0021275138 val_loss: 0.014298893
# Step = 722 train_loss: 0.0022034636 val_loss: 0.0125432685
# Step = 723 train_loss: 0.002786587 val_loss: 0.010014283
# Step = 724 train_loss: 0.0025209016 val_loss: 0.008677355
# Step = 725 train_loss: 0.0012708087 val_loss: 0.008508933
# Step = 726 train_loss: 0.0019364886 val_loss: 0.009666941
# Step = 727 train_loss: 0.0017405011 val_loss: 0.008826834
# Step = 728 train_loss: 0.002236335 val_loss: 0.008830414
# Step = 729 train_loss: 0.002503532 val_loss: 0.0092055565
# Step = 730 train_loss: 0.0018833629 val_loss: 0.011692224
# Step = 731 train_loss: 0.0016024522 val_loss: 0.00969669
# Step = 732 train_loss: 0.002201886 val_loss: 0.0088711735
# Step = 733 train_loss: 0.0018127636 val_loss: 0.0045628697
# Step = 734 train_loss: 0.002195176 val_loss: 0.008554625
# Step = 735 train_loss: 0.0018349962 val_loss: 0.0072627845
# Step = 736 train_loss: 0.0017519307 val_loss: 0.003775633
# Step = 737 train_loss: 0.0020819253 val_loss: 0.0057128775
# Step = 738 train_loss: 0.0023444316 val_loss: 0.019824812
# Step = 739 train_loss: 0.0042201695 val_loss: 0.024805965
# Step = 740 train_loss: 0.0015795573 val_loss: 0.028961318
# Step = 741 train_loss: 0.0015518827 val_loss: 0.030733606
# Step = 742 train_loss: 0.0015782529 val_loss: 0.03184627
# Step = 743 train_loss: 0.0023299463 val_loss: 0.03229809
# Step = 744 train_loss: 0.0020394793 val_loss: 0.025638435
# Step = 745 train_loss: 0.0010865978 val_loss: 0.008029802
# Step = 746 train_loss: 0.0025803237 val_loss: 0.006436798
# Step = 747 train_loss: 0.001213066 val_loss: 0.010468945
# Step = 748 train_loss: 0.0011595848 val_loss: 0.009255016
# Step = 749 train_loss: 0.0019956362 val_loss: 0.0060706264
# Step = 750 train_loss: 0.0015665403 val_loss: 0.011168511
# Step = 751 train_loss: 0.0022795363 val_loss: 0.021071142
# Step = 752 train_loss: 0.0018827041 val_loss: 0.0239989
# Step = 753 train_loss: 0.0014606952 val_loss: 0.017503522
# Step = 754 train_loss: 0.0013328332 val_loss: 0.0047815954
# Step = 755 train_loss: 0.0024278376 val_loss: 0.030682445
# Step = 756 train_loss: 0.0009728949 val_loss: 0.1232628
# Step = 757 train_loss: 0.0010179988 val_loss: 0.15224576
# Step = 758 train_loss: 0.0014927691 val_loss: 0.09350606
# Step = 759 train_loss: 0.001741303 val_loss: 0.028312668
# Step = 760 train_loss: 0.002216015 val_loss: 0.005226311
# Step = 761 train_loss: 0.0019023543 val_loss: 0.015644128
# Step = 762 train_loss: 0.0016682715 val_loss: 0.029605854
# Step = 763 train_loss: 0.0012179432 val_loss: 0.031480625
# Step = 764 train_loss: 0.0016536409 val_loss: 0.033958238
# Step = 765 train_loss: 0.002220359 val_loss: 0.03308968
# Step = 766 train_loss: 0.0010255866 val_loss: 0.03213186
# Step = 767 train_loss: 0.0011383033 val_loss: 0.031629957
# Step = 768 train_loss: 0.0025850784 val_loss: 0.031601127
# Step = 769 train_loss: 0.0019107276 val_loss: 0.032846365
# Step = 770 train_loss: 0.0020019864 val_loss: 0.029593399
# Step = 771 train_loss: 0.0024605212 val_loss: 0.0044120615
# Step = 772 train_loss: 0.0013334025 val_loss: 0.009910328
# Step = 773 train_loss: 0.0014545454 val_loss: 0.017187046
# Step = 774 train_loss: 0.0011720124 val_loss: 0.032115854
# Step = 775 train_loss: 0.001969986 val_loss: 0.036390573
# Step = 776 train_loss: 0.0015360109 val_loss: 0.036922272
# Step = 777 train_loss: 0.0019049415 val_loss: 0.037140094
# Step = 778 train_loss: 0.0017590865 val_loss: 0.037576262
# Step = 779 train_loss: 0.0013200964 val_loss: 0.036839567
# Step = 780 train_loss: 0.0022473547 val_loss: 0.017525041
# Step = 781 train_loss: 0.0013881846 val_loss: 0.0133632
# Step = 782 train_loss: 0.0015454759 val_loss: 0.14202537
# Step = 783 train_loss: 0.0021634889 val_loss: 0.106916554
# Step = 784 train_loss: 0.002419987 val_loss: 0.038569193
# Step = 785 train_loss: 0.0013774934 val_loss: 0.043855924
# Step = 786 train_loss: 0.0022342817 val_loss: 0.04637044
# Step = 787 train_loss: 0.004706231 val_loss: 0.28917652
# Step = 788 train_loss: 0.0017398131 val_loss: 0.5091049
# Step = 789 train_loss: 0.004563302 val_loss: 0.508527
# Step = 790 train_loss: 0.006122996 val_loss: 0.5093828
# Step = 791 train_loss: 0.0061159134 val_loss: 0.4912858
# Step = 792 train_loss: 0.0031043773 val_loss: 0.065688446
# Step = 793 train_loss: 0.004445855 val_loss: 0.041784808
# Step = 794 train_loss: 0.0053039715 val_loss: 0.04767082
# Step = 795 train_loss: 0.0028502867 val_loss: 0.030987306
# Step = 796 train_loss: 0.003337711 val_loss: 0.019155217
# Step = 797 train_loss: 0.0026115205 val_loss: 0.02070135
# Step = 798 train_loss: 0.0025303615 val_loss: 0.023975087
# Step = 799 train_loss: 0.0018577682 val_loss: 0.025653278
# Step = 800 train_loss: 0.0024082044 val_loss: 0.02396617
# Step = 801 train_loss: 0.0021127134 val_loss: 0.020792574
# Step = 802 train_loss: 0.0017071982 val_loss: 0.019721828
# Step = 803 train_loss: 0.0014291703 val_loss: 0.017238239
# Step = 804 train_loss: 0.0016307179 val_loss: 0.009164681
# Step = 805 train_loss: 0.003783923 val_loss: 0.013303209
# Step = 806 train_loss: 0.001820971 val_loss: 0.014982918
# Step = 807 train_loss: 0.0026554365 val_loss: 0.011212956
# Step = 808 train_loss: 0.0017602001 val_loss: 0.00588834
# Step = 809 train_loss: 0.0012797099 val_loss: 0.1320452
# Step = 810 train_loss: 0.0015218977 val_loss: 0.17197588
# Step = 811 train_loss: 0.002461422 val_loss: 0.012376581
# Step = 812 train_loss: 0.0024907067 val_loss: 0.017511768
# Step = 813 train_loss: 0.0016757161 val_loss: 0.022319635
# Step = 814 train_loss: 0.0021531757 val_loss: 0.025353841
# Step = 815 train_loss: 0.002083666 val_loss: 0.02790223
# Step = 816 train_loss: 0.0013463349 val_loss: 0.028705297
# Step = 817 train_loss: 0.0014706978 val_loss: 0.02761278
# Step = 818 train_loss: 0.0014030734 val_loss: 0.012522597
# Step = 819 train_loss: 0.0014489022 val_loss: 0.0021987546
# Step = 820 train_loss: 0.0016866723 val_loss: 0.0030903213
# Step = 821 train_loss: 0.0019300572 val_loss: 0.015123676
# Step = 822 train_loss: 0.0018079977 val_loss: 0.019249398
# Step = 823 train_loss: 0.0020697084 val_loss: 0.026485546
# Step = 824 train_loss: 0.0021982167 val_loss: 0.035338268
# Step = 825 train_loss: 0.0019696888 val_loss: 0.038632426
# Step = 826 train_loss: 0.0015654712 val_loss: 0.040642265
# Step = 827 train_loss: 0.0016443108 val_loss: 0.041048117
# Step = 828 train_loss: 0.0034060313 val_loss: 0.037962828
# Step = 829 train_loss: 0.0017149155 val_loss: 0.023677647
# Step = 830 train_loss: 0.0015635564 val_loss: 0.018794136
# Step = 831 train_loss: 0.0017803155 val_loss: 0.033097893
# Step = 832 train_loss: 0.0012191721 val_loss: 0.03680826
# Step = 833 train_loss: 0.0013347231 val_loss: 0.03262734
# Step = 834 train_loss: 0.0012472931 val_loss: 0.030501138
# Step = 835 train_loss: 0.0018143448 val_loss: 0.026322432
# Step = 836 train_loss: 0.001905827 val_loss: 0.010083536
# Step = 837 train_loss: 0.0018303761 val_loss: 0.007229147
# Step = 838 train_loss: 0.0014098664 val_loss: 0.008093087
# Step = 839 train_loss: 0.0013407415 val_loss: 0.0059538097
# Step = 840 train_loss: 0.0012481662 val_loss: 0.004243035
# Step = 841 train_loss: 0.0013155637 val_loss: 0.003173582
# Step = 842 train_loss: 0.0018511395 val_loss: 0.0070369416
# Step = 843 train_loss: 0.0011390602 val_loss: 0.0041392716
# Step = 844 train_loss: 0.0012009959 val_loss: 0.005666595
# Step = 845 train_loss: 0.0011739607 val_loss: 0.006083354
# Step = 846 train_loss: 0.002935112 val_loss: 0.020413164
# Step = 847 train_loss: 0.0023327824 val_loss: 0.035276614
# Step = 848 train_loss: 0.0010593714 val_loss: 0.039556075
# Step = 849 train_loss: 0.0015076795 val_loss: 0.039545227
# Step = 850 train_loss: 0.0009973684 val_loss: 0.037719138
# Step = 851 train_loss: 0.002599926 val_loss: 0.036513254
# Step = 852 train_loss: 0.002272941 val_loss: 0.03619184
# Step = 853 train_loss: 0.0021660791 val_loss: 0.03570933
# Step = 854 train_loss: 0.0014399494 val_loss: 0.0152090555
# Step = 855 train_loss: 0.001435203 val_loss: 0.0065454897
# Step = 856 train_loss: 0.002435612 val_loss: 0.063917965
# Step = 857 train_loss: 0.0016530901 val_loss: 0.0669615
# Step = 858 train_loss: 0.0011086199 val_loss: 0.016574604
# Step = 859 train_loss: 0.0016335563 val_loss: 0.0025010924
# Step = 860 train_loss: 0.0011920605 val_loss: 0.012051782
# Step = 861 train_loss: 0.0018963781 val_loss: 0.023506671
# Step = 862 train_loss: 0.0023354848 val_loss: 0.041317955
# Step = 863 train_loss: 0.0014959538 val_loss: 0.043112356
# Step = 864 train_loss: 0.0013837281 val_loss: 0.04198071
# Step = 865 train_loss: 0.0014985346 val_loss: 0.041373413
# Step = 866 train_loss: 0.0011065387 val_loss: 0.04107335
# Step = 867 train_loss: 0.0014633295 val_loss: 0.04052017
# Step = 868 train_loss: 0.0011013412 val_loss: 0.040023483
# Step = 869 train_loss: 0.0015073416 val_loss: 0.039226457
# Step = 870 train_loss: 0.0012659559 val_loss: 0.03845111
# Step = 871 train_loss: 0.00107492 val_loss: 0.033885684
# Step = 872 train_loss: 0.0012360545 val_loss: 0.027025439
# Step = 873 train_loss: 0.0013842719 val_loss: 0.017715152
# Step = 874 train_loss: 0.0014559132 val_loss: 0.010762677
# Step = 875 train_loss: 0.0019802032 val_loss: 0.005007707
# Step = 876 train_loss: 0.0013567087 val_loss: 0.002826151
# Step = 877 train_loss: 0.0014096951 val_loss: 0.0030316971
# Step = 878 train_loss: 0.0014975063 val_loss: 0.0027725475
# Step = 879 train_loss: 0.0014925333 val_loss: 0.0026839396
# Step = 880 train_loss: 0.0010867922 val_loss: 0.0027782703
# Step = 881 train_loss: 0.0011243456 val_loss: 0.0035751583
# Step = 882 train_loss: 0.0010903478 val_loss: 0.004209025
# Step = 883 train_loss: 0.0010636058 val_loss: 0.0049186586
# Step = 884 train_loss: 0.0015314945 val_loss: 0.0055712815
# Step = 885 train_loss: 0.0011566706 val_loss: 0.006545811
# Step = 886 train_loss: 0.0013297575 val_loss: 0.007986919
# Step = 887 train_loss: 0.0012241454 val_loss: 0.00967954
# Step = 888 train_loss: 0.0013536302 val_loss: 0.011407963
# Step = 889 train_loss: 0.0015542621 val_loss: 0.013022086
# Step = 890 train_loss: 0.0014200591 val_loss: 0.014422901
# Step = 891 train_loss: 0.0008774663 val_loss: 0.015519064
# Step = 892 train_loss: 0.0011745142 val_loss: 0.016019545
# Step = 893 train_loss: 0.0010818623 val_loss: 0.016657276
# Step = 894 train_loss: 0.001071935 val_loss: 0.017463882
# Step = 895 train_loss: 0.0020551702 val_loss: 0.01809031
# Step = 896 train_loss: 0.0011172063 val_loss: 0.018526196
# Step = 897 train_loss: 0.0010240163 val_loss: 0.018814491
# Step = 898 train_loss: 0.001412951 val_loss: 0.019041017
# Step = 899 train_loss: 0.0010916316 val_loss: 0.019118998
# Step = 900 train_loss: 0.0011442355 val_loss: 0.019245556
# Step = 901 train_loss: 0.001076577 val_loss: 0.019393474
# Step = 902 train_loss: 0.001260647 val_loss: 0.019522991
# Step = 903 train_loss: 0.0015845015 val_loss: 0.019835182
# Step = 904 train_loss: 0.00078123104 val_loss: 0.020182258
# Step = 905 train_loss: 0.0018113983 val_loss: 0.02071047
# Step = 906 train_loss: 0.001664222 val_loss: 0.021380441
# Step = 907 train_loss: 0.0014999937 val_loss: 0.0221775
# Step = 908 train_loss: 0.0011460824 val_loss: 0.02307175
# Step = 909 train_loss: 0.0017202572 val_loss: 0.024299556
# Step = 910 train_loss: 0.0012449672 val_loss: 0.025490977
# Step = 911 train_loss: 0.0008972867 val_loss: 0.026644396
# Step = 912 train_loss: 0.001046076 val_loss: 0.027717892
# Step = 913 train_loss: 0.0011390157 val_loss: 0.029004982
# Step = 914 train_loss: 0.0022630752 val_loss: 0.02938263
# Step = 915 train_loss: 0.0008479645 val_loss: 0.030057466
# Step = 916 train_loss: 0.0010713101 val_loss: 0.030155875
# Step = 917 train_loss: 0.002063568 val_loss: 0.030340718
# Step = 918 train_loss: 0.0009610439 val_loss: 0.030046187
# Step = 919 train_loss: 0.0014071532 val_loss: 0.030059975
# Step = 920 train_loss: 0.0011177155 val_loss: 0.029585326
# Step = 921 train_loss: 0.0018364438 val_loss: 0.03211643
# Step = 922 train_loss: 0.0007860308 val_loss: 0.034317788
# Step = 923 train_loss: 0.001155101 val_loss: 0.034747384
# Step = 924 train_loss: 0.0011074683 val_loss: 0.033479664
# Step = 925 train_loss: 0.0013500652 val_loss: 0.030290417
# Step = 926 train_loss: 0.00084431184 val_loss: 0.026173856
# Step = 927 train_loss: 0.0013693491 val_loss: 0.02020107
# Step = 928 train_loss: 0.0015649127 val_loss: 0.009980947
# Step = 929 train_loss: 0.0008804376 val_loss: 0.0033506176
# Step = 930 train_loss: 0.0009566133 val_loss: 0.0028211821
# Step = 931 train_loss: 0.00073983363 val_loss: 0.0031784547
# Step = 932 train_loss: 0.0015887986 val_loss: 0.015688421
# Step = 933 train_loss: 0.00056145503 val_loss: 0.0271394
# Step = 934 train_loss: 0.0013225279 val_loss: 0.03194848
# Step = 935 train_loss: 0.0011739039 val_loss: 0.035217356
# Step = 936 train_loss: 0.0008374552 val_loss: 0.036398247
# Step = 937 train_loss: 0.0010488324 val_loss: 0.03423062
# Step = 938 train_loss: 0.00086369744 val_loss: 0.027276242
# Step = 939 train_loss: 0.0010927723 val_loss: 0.014849238
# Step = 940 train_loss: 0.001282202 val_loss: 0.009438383
# Step = 941 train_loss: 0.0014815025 val_loss: 0.0070447335
# Step = 942 train_loss: 0.0011995009 val_loss: 0.018726332
# Step = 943 train_loss: 0.0011823522 val_loss: 0.025655247
# Step = 944 train_loss: 0.0009596706 val_loss: 0.027219834
# Step = 945 train_loss: 0.0010268438 val_loss: 0.019780852
# Step = 946 train_loss: 0.0007003667 val_loss: 0.013424655
# Step = 947 train_loss: 0.0010004921 val_loss: 0.021288928
# Step = 948 train_loss: 0.0012100372 val_loss: 0.021367831
# Step = 949 train_loss: 0.0012350149 val_loss: 0.02115003
# Step = 950 train_loss: 0.0013585475 val_loss: 0.021158928
# Step = 951 train_loss: 0.00077355286 val_loss: 0.021136435
# Step = 952 train_loss: 0.0012641462 val_loss: 0.021016672
# Step = 953 train_loss: 0.0007399466 val_loss: 0.02095759
# Step = 954 train_loss: 0.001281829 val_loss: 0.020849837
# Step = 955 train_loss: 0.0012003427 val_loss: 0.020648666
# Step = 956 train_loss: 0.0013443506 val_loss: 0.020454394
# Step = 957 train_loss: 0.0007614724 val_loss: 0.020239549
# Step = 958 train_loss: 0.0008683711 val_loss: 0.019553734
# Step = 959 train_loss: 0.0036217743 val_loss: 0.019825695
# Step = 960 train_loss: 0.0013449093 val_loss: 0.019657888
# Step = 961 train_loss: 0.0015865827 val_loss: 0.019481214
# Step = 962 train_loss: 0.0012663292 val_loss: 0.019684643
# Step = 963 train_loss: 0.0024385788 val_loss: 0.019119738
# Step = 964 train_loss: 0.0021428058 val_loss: 0.009950514
# Step = 965 train_loss: 0.0030023989 val_loss: 0.48747504
# Step = 966 train_loss: 0.0022665865 val_loss: 0.48871413
# Step = 967 train_loss: 0.002658052 val_loss: 0.16528544
# Step = 968 train_loss: 0.0035492766 val_loss: 0.033019945
# Step = 969 train_loss: 0.0023156172 val_loss: 0.02504004
# Step = 970 train_loss: 0.0026360664 val_loss: 0.024625966
# Step = 971 train_loss: 0.0028150168 val_loss: 0.023856742
# Step = 972 train_loss: 0.0051759747 val_loss: 0.02811776
# Step = 973 train_loss: 0.0016230784 val_loss: 0.4897382
# Step = 974 train_loss: 0.003819982 val_loss: 0.5062101
# Step = 975 train_loss: 0.0048027285 val_loss: 0.49690646
# Step = 976 train_loss: 0.004583285 val_loss: 0.45884827
# Step = 977 train_loss: 0.00197349 val_loss: 0.0062470124
# Step = 978 train_loss: 0.0024916455 val_loss: 0.04263509
# Step = 979 train_loss: 0.0036816315 val_loss: 0.04273598
# Step = 980 train_loss: 0.002467136 val_loss: 0.03930539
# Step = 981 train_loss: 0.0037647374 val_loss: 0.027699558
# Step = 982 train_loss: 0.002349162 val_loss: 0.20749967
# Step = 983 train_loss: 0.0027730572 val_loss: 0.094948456
# Step = 984 train_loss: 0.0026371027 val_loss: 0.022855323
# Step = 985 train_loss: 0.0034261856 val_loss: 0.035334393
# Step = 986 train_loss: 0.0026351924 val_loss: 0.030024083
# Step = 987 train_loss: 0.0015873712 val_loss: 0.030707842
# Step = 988 train_loss: 0.0015447374 val_loss: 0.031421058
# Step = 989 train_loss: 0.0011896014 val_loss: 0.034311365
# Step = 990 train_loss: 0.007548216 val_loss: 0.03793279
# Step = 991 train_loss: 0.001135496 val_loss: 0.45335436
# Step = 992 train_loss: 0.0024570029 val_loss: 0.50849223
# Step = 993 train_loss: 0.004026443 val_loss: 0.5089539
# Step = 994 train_loss: 0.005769205 val_loss: 0.5092764
# Step = 995 train_loss: 0.0038143208 val_loss: 0.49587986
# Step = 996 train_loss: 0.00753736 val_loss: 0.49152756
# Step = 997 train_loss: 0.006630377 val_loss: 0.17653586
# Step = 998 train_loss: 0.0037023912 val_loss: 0.007066386
# Step = 999 train_loss: 0.0068757418 val_loss: 0.056728013
# Best model at index: 819
# Best model val_loss: 0.0021987545769661665
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_2240\2966303312.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('Best_target_model/net_parameters.pkl')

# %%
# history = np.DataFrame(columns=['index','train_loss', 'val_loss'])
#画出训练过程中的loss变化曲线
plt.plot(history['train_loss'], label='train_loss')
plt.plot(history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''Prediction using the best model'''
predict_labels_a=[]
predict_labels_b=[]
predict_labels_train=[]
predict_labels_val = []
model.eval()
with torch.no_grad():
    predict_labels_a.append(model(input_test_a).data.numpy())
    predict_labels_b.append(model(input_test_b).data.numpy())
    
    predict_labels_train.append(model(input_train).data.numpy())   
    predict_labels_val.append(model(input_val).data.numpy())      


actual_label_arr_train=np.round(np.asarray(train_labels*max_label).reshape(-1,1))  
predict_label_arr_train=np.round(np.asarray(predict_labels_train).reshape(-1,1)*max_label)


actual_label_arr_val=np.round(np.asarray(val_labels*max_label).reshape(-1,1))   
predict_label_arr_val=np.round(np.asarray(predict_labels_val).reshape(-1,1)*max_label)


actual_label_arr_a=np.round(np.asarray(test_cycle_life_a*max_label).reshape(-1,1))   
predict_label_arr_a=np.round(np.asarray(predict_labels_a).reshape(-1,1)*max_label)


actual_label_arr_b=np.round(np.asarray(test_cycle_life_b * max_label).reshape(-1,1))   
predict_label_arr_b=np.round(np.asarray(predict_labels_b).reshape(-1,1)*max_label)

# %%
'''Plot the predicted cycle lives'''
plt.scatter(actual_label_arr_train, predict_label_arr_train,s=50,c='k')
plt.scatter(actual_label_arr_val, predict_label_arr_val,s=50,c='b')
plt.scatter(actual_label_arr_a, predict_label_arr_a,s=50,c='r')
plt.scatter(actual_label_arr_b, predict_label_arr_b,s=50,c='g')
plt.plot([100,2500],[100,2500])


'''Evaluation metrics'''
mpe_a=np.mean(np.abs(predict_label_arr_a-actual_label_arr_a)/actual_label_arr_a)
mpe_b=np.mean(np.abs(predict_label_arr_b-actual_label_arr_b)/actual_label_arr_b)
mpe_train = np.mean(np.abs(predict_label_arr_train-actual_label_arr_train)/actual_label_arr_train)
mpe_val = np.mean(np.abs(predict_label_arr_val-actual_label_arr_val)/actual_label_arr_val)


rmse_a=np.sqrt(np.mean((predict_label_arr_a-actual_label_arr_a)**2))
rmse_b=np.sqrt(np.mean((predict_label_arr_b-actual_label_arr_b)**2))
rmse_train=np.sqrt(np.mean((predict_label_arr_train-actual_label_arr_train)**2))
rmse_val=np.sqrt(np.mean((predict_label_arr_val-actual_label_arr_val)**2))


print ('mpe_train:',mpe_train)
print ('mpe_val:',mpe_val)
print ('mpe_a:',mpe_a)
print ('mpe_b:',mpe_b)

print ('rmse_train:', rmse_train)
print ('rmse_val:', rmse_val)
print ('rmse_a:', rmse_a)
print ('rmse_b:', rmse_b)
# Out:
# mpe_train: 0.1124124
# mpe_val: 0.12118199
# mpe_a: 0.12748568641941438
# mpe_b: 0.15947391632212277
# rmse_train: 102.291626
# rmse_val: 104.75011
# rmse_a: 110.16530918958658
# rmse_b: 227.61552012110246

# %%
from sklearn.metrics import r2_score
r2_a = r2_score(actual_label_arr_a, predict_label_arr_a)
r2_b = r2_score(actual_label_arr_b, predict_label_arr_b)
r2_train = r2_score(actual_label_arr_train, predict_label_arr_train)
r2_val = r2_score(actual_label_arr_val, predict_label_arr_val)

print('r2_train:', r2_train)
print('r2_val:', r2_val)
print('r2_a:', r2_a)
print('r2_b:', r2_b)
# Out:
# r2_train: 0.9278562068939209
# r2_val: 0.894588828086853
# r2_a: 0.9204749834864762
# r2_b: 0.3626542944451242

# %%
plt.plot(predict_label_arr_a, label='predict_label_arr_a')
plt.plot(actual_label_arr_a, label='true_label_arr_a')
plt.plot(predict_label_arr_b, label='predict_label_arr_b')
plt.plot(actual_label_arr_b, label='true_label_arr_b')
plt.legend()
plt.show()
