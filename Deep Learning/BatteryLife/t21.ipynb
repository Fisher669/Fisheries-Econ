# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import random
from torchsummary import summary
from sklearn.model_selection import train_test_split
import shutil

'''Load data'''
temp_Qd = np.load('Data_processed/Qd_100.npy',allow_pickle=True).item()
temp_life = np.load('Data_processed/cycle_life.npy',allow_pickle=True).item()
all_capacity = np.load('Data_processed/all_capacity.npy',allow_pickle=True).item()
temp_Qd_all = []
temp_life_all = []
all_capacity_all = []

for key in temp_Qd.keys():
    temp_life_all.append(temp_life[key])
    all_capacity_all.append(all_capacity[key])
    temp_Qd_list = []
    for item in temp_Qd[key]:
        temp_Qd_list.append(item)
    temp_Qd_arr = np.asarray(temp_Qd_list)
    temp_Qd_all.append(temp_Qd_arr)
all_Qd_arr = np.asarray(temp_Qd_all)
cycle_life_arr = np.asarray(temp_life_all)    


'''Divide the dataset as the original paper stated'''
test_ind = np.hstack((np.arange(0,(41+43),2),83))
train_ind = np.arange(1,(41+43-1),2)
secondary_test_ind = np.arange(124-40,124)

all_keys = list(temp_Qd.keys())
train_keys = [all_keys[inx] for inx in train_ind]
test_keys = [all_keys[inx] for inx in test_ind]
secondary_test_keys = [all_keys[inx] for inx in secondary_test_ind]

cycle_life_arr=np.asarray(cycle_life_arr).reshape(-1,1)
max_label=np.max(cycle_life_arr)
cycle_life_arr=cycle_life_arr/max_label


train_Qds = np.asarray(all_Qd_arr)[train_ind]
train_cycle_lifes = np.asarray(cycle_life_arr)[train_ind]

test_Qd_a = np.asarray(all_Qd_arr)[test_ind]
test_cycle_life_a = np.asarray(cycle_life_arr)[test_ind]

test_Qd_b = np.asarray(all_Qd_arr)[secondary_test_ind]
test_cycle_life_b = np.asarray(cycle_life_arr)[secondary_test_ind]

train_Qd, _, train_cycle_life, _ = train_test_split(train_Qds, train_cycle_lifes, test_size=0.36, random_state=3)

# %%
# pip install einops

# %%
import torch
import torch.nn as nn
from einops import rearrange

def to_3d(x):
    return rearrange(x, 'b c h w -> b (h w) c')
def to_4d(x, h, w):
    return rearrange(x, 'b (h w) c -> b c h w', h=h, w=w)

class SELayer(nn.Module):
    def __init__(self, channel, reduction=16):
        super(SELayer, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(channel, channel // reduction, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(channel // reduction, channel, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        y = self.avg_pool(x).view(b, c)
        y = self.fc(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class SEbox(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(SEbox, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.se = SELayer(out_channel)
        self.cbam = CBAM(out_channel)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = x + self.se(x)
        x = self.dropout(x)
        x = self.cbam(x)
        return x
    
class cnn_box(nn.Module):
    def __init__(self, in_channel, out_channel, kernel_size, stride, padding):
        super(cnn_box, self).__init__()
        self.conv = nn.Conv2d(in_channel, out_channel, kernel_size, stride, padding)
        self.bn = nn.BatchNorm2d(out_channel)
        self.relu = nn.LeakyReLU(inplace=True)
        self.dropout = nn.Dropout(p=0.5)

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        x = self.dropout(x)
        return x
    
class CBAM(nn.Module):
    def __init__(self, in_channel, reduction=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.max_pool = nn.AdaptiveMaxPool2d(output_size=1)
        self.avg_pool = nn.AdaptiveAvgPool2d(output_size=1)
        self.mlp = nn.Sequential(
            nn.Linear(in_features=in_channel, out_features=in_channel // reduction, bias=False),
            nn.ReLU(),
            nn.Linear(in_features=in_channel // reduction, out_features=in_channel, bias=False)
        )
        self.sigmoid = nn.Sigmoid()
        self.conv = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=kernel_size, stride=1, padding=kernel_size // 2, bias=False)

    def forward(self, x):
        maxout = self.max_pool(x)
        avgout = self.avg_pool(x)
        channel_out = self.sigmoid(self.mlp(maxout.view(maxout.size(0), -1)) + self.mlp(avgout.view(avgout.size(0), -1)))
        channel_out = channel_out.view(x.size(0), x.size(1), 1, 1) * x
        max_out = torch.max(channel_out, dim=1, keepdim=True)[0]
        mean_out = torch.mean(channel_out, dim=1, keepdim=True)
        out = self.sigmoid(self.conv(torch.cat((max_out, mean_out), dim=1))) * channel_out
        return out

class InceptionModule(torch.nn.Module):
    def __init__(self, in_channels=64, out_channels=64):
        super(InceptionModule, self).__init__()
        
        self.inceptions = torch.nn.ModuleList([
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(3, 3), stride=1, padding=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True),
                torch.nn.Conv2d(out_channels, out_channels, kernel_size=(5, 5), stride=1, padding=2),
                torch.nn.BatchNorm2d(out_channels),
                torch.nn.LeakyReLU(inplace=True)
            ),
            torch.nn.Sequential(
                torch.nn.MaxPool2d(kernel_size=3, stride=1, padding=1),
                torch.nn.Conv2d(in_channels, out_channels, kernel_size=(1, 1), stride=1),
                torch.nn.BatchNorm2d(out_channels),
            )
        ])

    def forward(self, x):
        # 将输入传递给所有Inception模块，并将输出连接起来
        outputs = [inception(x) for inception in self.inceptions]
        return torch.cat(outputs, dim=1)  # 这里按通道维度连接输出

# 使用示例
# model = InceptionModule(in_channels=32, out_channels=64)
# output = model(input_tensor)  # input_tensor 是你的输入数据

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layers1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40)),
            nn.BatchNorm2d(8),
            nn.LeakyReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=1),
            nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(8, 16, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(16),
            torch.nn.LeakyReLU(inplace=True),
            torch.nn.Dropout(p=0.2),
            
            torch.nn.Conv2d(16, 32, kernel_size=(2, 3), stride=1),
            torch.nn.BatchNorm2d(32),
            torch.nn.LeakyReLU(inplace=True),            
            
        )
        self.go = InceptionModule()
        self.sebox1 = SEbox(64,64,kernel_size=1,stride=1,padding=1)
        
        
        self.lstm1 = nn.LSTM(32, 32, num_layers=2, bidirectional=True, batch_first=True)
        
        self.lstm2 = nn.LSTM(320, 320, num_layers=2, bidirectional=True, batch_first=True)
        self.fc1 = nn.Linear(107008, 1)
        self.dropout = nn.Dropout(p=0.2)

    def forward(self, x):
        try:
            # 网络结构部分
            x = self.layers1(x)
            x = to_3d(x)
            x, _ = self.lstm1(x)
            x = to_4d(x, 8, 19)
            
            se = self.sebox1(x)
            crop_se = se[:, :, :8, :19]
            go = self.go(x)
            
            cat1 = torch.cat((crop_se, go), dim=1)
            
            lstm2_input = to_3d(cat1)
            
            lstm2_output, _ = self.lstm2(lstm2_input)
            
            lstm2 = to_4d(lstm2_output, 8, 19)
            
            x = torch.cat((x, lstm2), dim=1)
            # # 输出部分
            # print(f"层1输出形状: {x.shape}")  # 输出层1的形状
            # print(f"转换为3D后的形状: {x.shape}")  # 输出转换后的形状
            # print(f"LSTM后输出形状: {x.shape}")  # 输出LSTM的形状
            # print(f"转换为4D后的形状: {x.shape}")  # 输出转换后的形状
            # print(f"SEbox后输出形状: {se.shape}")  # 输出SEbox的形状
            # print(f"裁剪后SEbox形状: {crop_se.shape}")  # 输出裁剪后的形状
            # print(f"InceptionModule后输出形状: {go.shape}")  # 输出InceptionModule的形状
            # print(f"拼接后输出形状(取crop_se和go): {cat1.shape}")  # 输出拼接后的形状
            # print(f"LSTM2输入形状: {lstm2_input.shape}")  # 输出LSTM2的输入形状
            # print(f"LSTM2后输出形状: {lstm2_output.shape}")  # 输出LSTM2的输出形状
            # print(f"转换为4D后LSTM2的形状: {lstm2.shape}")  # 输出转换后的LSTM2形状
            # print(f"最终拼接后输出形状: {x.shape}")  # 输出最终拼接后的形状

            return torch.sigmoid(self.fc1(x.view(x.size(0), -1)))
        except RuntimeError as e:
            print(f"运行时错误：{e}")
            return None
        except Exception as e:
            print(f"发生意外错误：{e}")
            raise  # 重新抛出异常，以便进一步处理

# %%
net = Net()     # define the network
print(net)      # net architecture
# summary(net,(1,100,1000))
# Out:
# Net(
#   (layers1): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(50, 50), stride=(5, 40))
#     (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.01, inplace=True)
#     (3): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#     (4): Dropout(p=0.2, inplace=False)
#     (5): Conv2d(8, 16, kernel_size=(2, 3), stride=(1, 1))
#     (6): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): LeakyReLU(negative_slope=0.01, inplace=True)
#     (8): Dropout(p=0.2, inplace=False)
#     (9): Conv2d(16, 32, kernel_size=(2, 3), stride=(1, 1))
#     (10): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.01, inplace=True)
#   )
#   (go): InceptionModule(
#     (inceptions): ModuleList(
#       (0): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (1): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (2): Sequential(
#         (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): LeakyReLU(negative_slope=0.01, inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): LeakyReLU(negative_slope=0.01, inplace=True)
#       )
#       (3): Sequential(
#         (0): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#         (1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#         (2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (sebox1): SEbox(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), padding=(1, 1))
#     (bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): LeakyReLU(negative_slope=0.01, inplace=True)
#     (se): SELayer(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (fc): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU(inplace=True)
#         (2): Linear(in_features=4, out_features=64, bias=False)
#         (3): Sigmoid()
#       )
#     )
#     (cbam): CBAM(
#       (max_pool): AdaptiveMaxPool2d(output_size=1)
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (mlp): Sequential(
#         (0): Linear(in_features=64, out_features=4, bias=False)
#         (1): ReLU()
#         (2): Linear(in_features=4, out_features=64, bias=False)
#       )
#       (sigmoid): Sigmoid()
#       (conv): Conv2d(2, 1, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3), bias=False)
#     )
#     (dropout): Dropout(p=0.5, inplace=False)
#   )
#   (lstm1): LSTM(32, 32, num_layers=2, batch_first=True, bidirectional=True)
#   (lstm2): LSTM(320, 320, num_layers=2, batch_first=True, bidirectional=True)
#   (fc1): Linear(in_features=107008, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
import pandas as pd
import torch.optim as optim
'''Data loader for Pytorch'''
input_train = torch.FloatTensor(train_Qd)
input_train = torch.unsqueeze(input_train, 1)
train_labels = torch.FloatTensor(train_cycle_life)

input_val = torch.FloatTensor(train_Qds)
input_val = torch.unsqueeze(input_val, 1)
val_labels = torch.FloatTensor(train_cycle_lifes)

input_test_a = torch.FloatTensor(test_Qd_a)
input_test_a = torch.unsqueeze(input_test_a, 1)
test_labels_a = torch.FloatTensor(test_cycle_life_a)

input_test_b = torch.FloatTensor(test_Qd_b)
input_test_b = torch.unsqueeze(input_test_b, 1)
test_labels_b = torch.FloatTensor(test_cycle_life_b)



seed = 17
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
torch.manual_seed(seed)    # reproducible    



optimizer = torch.optim.Adam(net.parameters(), lr=0.0001)
loss_func = torch.nn.MSELoss() 

# # 动态调整学习率
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: 0.8 ** (epoch // 40))

# # 将学习率调度器修改为指数下降
# initial_lr = 0.0001  # 初始学习率
# decay_rate = 0.96  # 每个epoch衰减的比例
# scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=lambda epoch: decay_rate ** epoch)

# 假设你已经定义了模型和优化器
# 当验证损失不下降时，减少学习率
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.8, patience=5)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=100)

# 创建历史记录DataFrame
history = pd.DataFrame(columns=['index', 'train_loss', 'val_loss'])
val_losses = []
max_models_to_keep = 10
saved_models=[]
import os

import datetime

log_file_path = 'train_log.txt'  # 请替换为实际的日志文件路径

# 初始化日志文件，并且第一行记录时间跟训练参数
with open(log_file_path, 'w') as log_file:
    log_file.write('Time: {}\n'.format(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')))
    # log_file.write('Training parameters: {}\n'.format(str(vars(args))))

for t in range(1000):
    net.train()
    train_prediction = net(input_train)
    train_loss = loss_func(train_prediction, train_labels)
   
    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()
    scheduler.step()
    # 保存模型
    model_path = 'Target_model/net_parameters'+str(t)+'.pkl'
    torch.save({
        'epoch': t,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict()}, model_path)

    net.eval()
    with torch.no_grad():
        val_prediction = net(input_val)
        val_loss = loss_func(val_prediction, val_labels)
    
    print('Step = %d' % t, 'train_loss:', train_loss.data.numpy(), 'val_loss:', val_loss.data.numpy())


# 打开文件并写入内容
    with open(log_file_path, 'a') as log_file:  # 'a'模式表示追加写入
        log_file.write('Step = %d, train_loss: %s, val_loss: %s\n' % (t, train_loss.data.numpy(), val_loss.data.numpy()))
        
    val_losses.append(val_loss.item())
    
    # 添加当前模型及其验证损失
    saved_models.append((val_loss.item(), model_path))

    # 保持模型数量不超过max_models_to_keep
    if len(saved_models) > max_models_to_keep:
        # 找到验证损失最大的一组模型并删除
        saved_models.sort(key=lambda x: x[0])  # 排序，根据损失
        os.remove(saved_models.pop()[1])  # 删除损失最大的模型
    # 加入训练历史记录
    # 创建新的一行数据
    new_entry = pd.DataFrame({'index': [t], 'train_loss': [train_loss.item()], 'val_loss': [val_loss.item()]})
    
    # 使用concat进行数据合并
    history = pd.concat([history, new_entry], ignore_index=True)

'''find the best model'''
best_index = val_losses.index(np.min(val_losses))
print(f'Best model at index: {best_index}')
print(f'Best model val_loss: {val_losses[best_index]}')

'''copy the best model from model file to the model_test file'''
shutil.copyfile(f'Target_model/net_parameters{best_index}.pkl', 'Best_target_model/net_parameters.pkl')


'''Reload the best model''' 
model = Net()
checkpoint = torch.load('Best_target_model/net_parameters.pkl')
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
# Out:
# Step = 0 train_loss: 0.059223764 val_loss: 0.04381983
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_30288\2966303312.py:111: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   history = pd.concat([history, new_entry], ignore_index=True)
# Step = 1 train_loss: 0.031209359 val_loss: 0.033708498
# Step = 2 train_loss: 0.032488972 val_loss: 0.029400691
# Step = 3 train_loss: 0.037262693 val_loss: 0.028257681
# Step = 4 train_loss: 0.037457842 val_loss: 0.028744
# Step = 5 train_loss: 0.03395714 val_loss: 0.030231258
# Step = 6 train_loss: 0.028927289 val_loss: 0.03231316
# Step = 7 train_loss: 0.027563225 val_loss: 0.03431595
# Step = 8 train_loss: 0.027552357 val_loss: 0.036024194
# Step = 9 train_loss: 0.027828563 val_loss: 0.036924593
# Step = 10 train_loss: 0.028372113 val_loss: 0.03678844
# Step = 11 train_loss: 0.029025752 val_loss: 0.035776064
# Step = 12 train_loss: 0.027999189 val_loss: 0.03425853
# Step = 13 train_loss: 0.02615075 val_loss: 0.032672238
# Step = 14 train_loss: 0.027619524 val_loss: 0.031296656
# Step = 15 train_loss: 0.025257815 val_loss: 0.030363368
# Step = 16 train_loss: 0.027333386 val_loss: 0.029955946
# Step = 17 train_loss: 0.026517322 val_loss: 0.030066164
# Step = 18 train_loss: 0.025688227 val_loss: 0.030646302
# Step = 19 train_loss: 0.023723213 val_loss: 0.031447098
# Step = 20 train_loss: 0.024725335 val_loss: 0.032413542
# Step = 21 train_loss: 0.025182333 val_loss: 0.033232138
# Step = 22 train_loss: 0.02310998 val_loss: 0.033560302
# Step = 23 train_loss: 0.021883378 val_loss: 0.033257328
# Step = 24 train_loss: 0.024458941 val_loss: 0.032118693
# Step = 25 train_loss: 0.019189171 val_loss: 0.030529188
# Step = 26 train_loss: 0.024532981 val_loss: 0.02915879
# Step = 27 train_loss: 0.016052242 val_loss: 0.027673773
# Step = 28 train_loss: 0.02046151 val_loss: 0.026454236
# Step = 29 train_loss: 0.021229919 val_loss: 0.025704684
# Step = 30 train_loss: 0.014386331 val_loss: 0.025944727
# Step = 31 train_loss: 0.011961185 val_loss: 0.02698211
# Step = 32 train_loss: 0.028013317 val_loss: 0.030735975
# Step = 33 train_loss: 0.022323446 val_loss: 0.036126144
# Step = 34 train_loss: 0.01894202 val_loss: 0.043427605
# Step = 35 train_loss: 0.019323481 val_loss: 0.040820826
# Step = 36 train_loss: 0.016747285 val_loss: 0.034250904
# Step = 37 train_loss: 0.02238684 val_loss: 0.0244998
# Step = 38 train_loss: 0.017542113 val_loss: 0.020854311
# Step = 39 train_loss: 0.020013805 val_loss: 0.020541228
# Step = 40 train_loss: 0.022353824 val_loss: 0.021518549
# Step = 41 train_loss: 0.017165657 val_loss: 0.023064774
# Step = 42 train_loss: 0.021849722 val_loss: 0.024547607
# Step = 43 train_loss: 0.020428317 val_loss: 0.025247557
# Step = 44 train_loss: 0.019785533 val_loss: 0.02423561
# Step = 45 train_loss: 0.016822226 val_loss: 0.022559224
# Step = 46 train_loss: 0.011246136 val_loss: 0.021603575
# Step = 47 train_loss: 0.025187405 val_loss: 0.020895233
# Step = 48 train_loss: 0.017611679 val_loss: 0.020346012
# Step = 49 train_loss: 0.010760118 val_loss: 0.024150196
# Step = 50 train_loss: 0.010426816 val_loss: 0.03433953
# Step = 51 train_loss: 0.015144702 val_loss: 0.056526773
# Step = 52 train_loss: 0.014352381 val_loss: 0.07201859
# Step = 53 train_loss: 0.0159806 val_loss: 0.07481383
# Step = 54 train_loss: 0.0136609115 val_loss: 0.07086781
# Step = 55 train_loss: 0.011401632 val_loss: 0.06687391
# Step = 56 train_loss: 0.015034593 val_loss: 0.06353128
# Step = 57 train_loss: 0.010027832 val_loss: 0.062002204
# Step = 58 train_loss: 0.014160289 val_loss: 0.05129976
# Step = 59 train_loss: 0.011216667 val_loss: 0.032656565
# Step = 60 train_loss: 0.008272868 val_loss: 0.020966368
# Step = 61 train_loss: 0.0115224365 val_loss: 0.019263139
# Step = 62 train_loss: 0.008306896 val_loss: 0.020055497
# Step = 63 train_loss: 0.007214688 val_loss: 0.02398149
# Step = 64 train_loss: 0.008152732 val_loss: 0.027675806
# Step = 65 train_loss: 0.009500234 val_loss: 0.03318917
# Step = 66 train_loss: 0.0101128705 val_loss: 0.038007133
# Step = 67 train_loss: 0.0063587213 val_loss: 0.04002598
# Step = 68 train_loss: 0.0077621574 val_loss: 0.041980248
# Step = 69 train_loss: 0.007505833 val_loss: 0.043987524
# Step = 70 train_loss: 0.008646185 val_loss: 0.041805033
# Step = 71 train_loss: 0.01462522 val_loss: 0.036718663
# Step = 72 train_loss: 0.0046956316 val_loss: 0.03398145
# Step = 73 train_loss: 0.0075801527 val_loss: 0.034985736
# Step = 74 train_loss: 0.006749017 val_loss: 0.03691672
# Step = 75 train_loss: 0.006877053 val_loss: 0.039997943
# Step = 76 train_loss: 0.00883453 val_loss: 0.038635902
# Step = 77 train_loss: 0.005037352 val_loss: 0.03831546
# Step = 78 train_loss: 0.010368749 val_loss: 0.038165092
# Step = 79 train_loss: 0.0070394026 val_loss: 0.03801483
# Step = 80 train_loss: 0.011314666 val_loss: 0.038524486
# Step = 81 train_loss: 0.009386506 val_loss: 0.03954519
# Step = 82 train_loss: 0.0097983135 val_loss: 0.04197248
# Step = 83 train_loss: 0.0072306744 val_loss: 0.04466239
# Step = 84 train_loss: 0.0069038495 val_loss: 0.04601453
# Step = 85 train_loss: 0.008246048 val_loss: 0.045932926
# Step = 86 train_loss: 0.008367098 val_loss: 0.044892337
# Step = 87 train_loss: 0.010087063 val_loss: 0.0428343
# Step = 88 train_loss: 0.009629254 val_loss: 0.038550988
# Step = 89 train_loss: 0.0066910707 val_loss: 0.03568732
# Step = 90 train_loss: 0.007740595 val_loss: 0.03253744
# Step = 91 train_loss: 0.0069969213 val_loss: 0.030060861
# Step = 92 train_loss: 0.0067781005 val_loss: 0.028487973
# Step = 93 train_loss: 0.0068988088 val_loss: 0.028662298
# Step = 94 train_loss: 0.009215978 val_loss: 0.029924445
# Step = 95 train_loss: 0.005103812 val_loss: 0.031935673
# Step = 96 train_loss: 0.0061819 val_loss: 0.033643994
# Step = 97 train_loss: 0.0059071756 val_loss: 0.035935786
# Step = 98 train_loss: 0.00778791 val_loss: 0.037822153
# Step = 99 train_loss: 0.005725161 val_loss: 0.039994758
# Step = 100 train_loss: 0.00786215 val_loss: 0.041647978
# Step = 101 train_loss: 0.006909489 val_loss: 0.04319311
# Step = 102 train_loss: 0.006169931 val_loss: 0.044698585
# Step = 103 train_loss: 0.0069652805 val_loss: 0.04623183
# Step = 104 train_loss: 0.006979626 val_loss: 0.048281893
# Step = 105 train_loss: 0.007015337 val_loss: 0.051134326
# Step = 106 train_loss: 0.0056658266 val_loss: 0.054621387
# Step = 107 train_loss: 0.008817886 val_loss: 0.05829543
# Step = 108 train_loss: 0.006357406 val_loss: 0.059890736
# Step = 109 train_loss: 0.0051190946 val_loss: 0.054795638
# Step = 110 train_loss: 0.009577266 val_loss: 0.04996805
# Step = 111 train_loss: 0.00420103 val_loss: 0.044183515
# Step = 112 train_loss: 0.0064835274 val_loss: 0.042158462
# Step = 113 train_loss: 0.009084625 val_loss: 0.039642777
# Step = 114 train_loss: 0.009037822 val_loss: 0.04510272
# Step = 115 train_loss: 0.0075969207 val_loss: 0.053204093
# Step = 116 train_loss: 0.006880927 val_loss: 0.03959271
# Step = 117 train_loss: 0.005546466 val_loss: 0.029309642
# Step = 118 train_loss: 0.0066535836 val_loss: 0.021425331
# Step = 119 train_loss: 0.008822105 val_loss: 0.019870415
# Step = 120 train_loss: 0.0074456832 val_loss: 0.01887261
# Step = 121 train_loss: 0.005881304 val_loss: 0.018552698
# Step = 122 train_loss: 0.0067653256 val_loss: 0.017883427
# Step = 123 train_loss: 0.0069639278 val_loss: 0.017011125
# Step = 124 train_loss: 0.009148179 val_loss: 0.017136524
# Step = 125 train_loss: 0.007301212 val_loss: 0.020889442
# Step = 126 train_loss: 0.008525467 val_loss: 0.020082636
# Step = 127 train_loss: 0.008064222 val_loss: 0.020624867
# Step = 128 train_loss: 0.0048563215 val_loss: 0.013685745
# Step = 129 train_loss: 0.00633174 val_loss: 0.08684069
# Step = 130 train_loss: 0.005986182 val_loss: 0.2948951
# Step = 131 train_loss: 0.0050953077 val_loss: 0.35748512
# Step = 132 train_loss: 0.0040196544 val_loss: 0.3912071
# Step = 133 train_loss: 0.006985512 val_loss: 0.40717575
# Step = 134 train_loss: 0.013103602 val_loss: 0.4253136
# Step = 135 train_loss: 0.0055924277 val_loss: 0.42109695
# Step = 136 train_loss: 0.011098245 val_loss: 0.40291387
# Step = 137 train_loss: 0.010794137 val_loss: 0.363594
# Step = 138 train_loss: 0.006167139 val_loss: 0.27348948
# Step = 139 train_loss: 0.014081959 val_loss: 0.12885104
# Step = 140 train_loss: 0.008032883 val_loss: 0.0047583934
# Step = 141 train_loss: 0.0048569697 val_loss: 0.017135058
# Step = 142 train_loss: 0.005147654 val_loss: 0.014943983
# Step = 143 train_loss: 0.0041745035 val_loss: 0.018188803
# Step = 144 train_loss: 0.007488017 val_loss: 0.019646788
# Step = 145 train_loss: 0.008307544 val_loss: 0.02112407
# Step = 146 train_loss: 0.0060101296 val_loss: 0.021492736
# Step = 147 train_loss: 0.0060397657 val_loss: 0.022283847
# Step = 148 train_loss: 0.003726875 val_loss: 0.023052791
# Step = 149 train_loss: 0.006840961 val_loss: 0.021052092
# Step = 150 train_loss: 0.005415547 val_loss: 0.016647005
# Step = 151 train_loss: 0.0061964025 val_loss: 0.015778044
# Step = 152 train_loss: 0.00623249 val_loss: 0.016105853
# Step = 153 train_loss: 0.006362275 val_loss: 0.017300742
# Step = 154 train_loss: 0.009649728 val_loss: 0.021168927
# Step = 155 train_loss: 0.0044396147 val_loss: 0.027126966
# Step = 156 train_loss: 0.0057836166 val_loss: 0.03026625
# Step = 157 train_loss: 0.0049426993 val_loss: 0.03192123
# Step = 158 train_loss: 0.0050797528 val_loss: 0.024394808
# Step = 159 train_loss: 0.0064978967 val_loss: 0.0064249723
# Step = 160 train_loss: 0.0050626406 val_loss: 0.025196852
# Step = 161 train_loss: 0.004647887 val_loss: 0.1054425
# Step = 162 train_loss: 0.0037680375 val_loss: 0.13370073
# Step = 163 train_loss: 0.0052288678 val_loss: 0.113302104
# Step = 164 train_loss: 0.0050115814 val_loss: 0.05158914
# Step = 165 train_loss: 0.0051241885 val_loss: 0.0092764115
# Step = 166 train_loss: 0.0066974303 val_loss: 0.010218494
# Step = 167 train_loss: 0.0054286364 val_loss: 0.05872999
# Step = 168 train_loss: 0.003771587 val_loss: 0.01875407
# Step = 169 train_loss: 0.0044738385 val_loss: 0.008746194
# Step = 170 train_loss: 0.004744548 val_loss: 0.07640453
# Step = 171 train_loss: 0.0037286724 val_loss: 0.15362415
# Step = 172 train_loss: 0.0032267221 val_loss: 0.18016611
# Step = 173 train_loss: 0.003883788 val_loss: 0.2067682
# Step = 174 train_loss: 0.0025530008 val_loss: 0.22002718
# Step = 175 train_loss: 0.0037316333 val_loss: 0.30475253
# Step = 176 train_loss: 0.0070936955 val_loss: 0.042862847
# Step = 177 train_loss: 0.004133386 val_loss: 0.035162654
# Step = 178 train_loss: 0.0035778333 val_loss: 0.05342696
# Step = 179 train_loss: 0.003557097 val_loss: 0.055556767
# Step = 180 train_loss: 0.004489416 val_loss: 0.058576666
# Step = 181 train_loss: 0.0049154586 val_loss: 0.19556218
# Step = 182 train_loss: 0.0053325864 val_loss: 0.34263584
# Step = 183 train_loss: 0.006409593 val_loss: 0.33792076
# Step = 184 train_loss: 0.0027828028 val_loss: 0.33409578
# Step = 185 train_loss: 0.0067545567 val_loss: 0.4893046
# Step = 186 train_loss: 0.0057492726 val_loss: 0.50426894
# Step = 187 train_loss: 0.005819214 val_loss: 0.5042095
# Step = 188 train_loss: 0.006548621 val_loss: 0.5053312
# Step = 189 train_loss: 0.0053370898 val_loss: 0.50516266
# Step = 190 train_loss: 0.0070649316 val_loss: 0.49664697
# Step = 191 train_loss: 0.008696855 val_loss: 0.45420837
# Step = 192 train_loss: 0.004471048 val_loss: 0.41926873
# Step = 193 train_loss: 0.0071001244 val_loss: 0.37520418
# Step = 194 train_loss: 0.020838449 val_loss: 0.27979094
# Step = 195 train_loss: 0.011206919 val_loss: 0.046976287
# Step = 196 train_loss: 0.011777476 val_loss: 0.015709605
# Step = 197 train_loss: 0.008291409 val_loss: 0.021436164
# Step = 198 train_loss: 0.019370805 val_loss: 0.0065740957
# Step = 199 train_loss: 0.010872114 val_loss: 0.5075193
# Step = 200 train_loss: 0.022088747 val_loss: 0.50651354
# Step = 201 train_loss: 0.021701219 val_loss: 0.50630754
# Step = 202 train_loss: 0.019732991 val_loss: 0.5065936
# Step = 203 train_loss: 0.013852986 val_loss: 0.5067451
# Step = 204 train_loss: 0.017888099 val_loss: 0.50606036
# Step = 205 train_loss: 0.02378591 val_loss: 0.50479156
# Step = 206 train_loss: 0.01387488 val_loss: 0.50244063
# Step = 207 train_loss: 0.0072362493 val_loss: 0.49834839
# Step = 208 train_loss: 0.006087504 val_loss: 0.49019647
# Step = 209 train_loss: 0.004541547 val_loss: 0.47833905
# Step = 210 train_loss: 0.011045597 val_loss: 0.46362957
# Step = 211 train_loss: 0.017237084 val_loss: 0.4931368
# Step = 212 train_loss: 0.014851476 val_loss: 0.5032702
# Step = 213 train_loss: 0.015920313 val_loss: 0.5064126
# Step = 214 train_loss: 0.0153134465 val_loss: 0.5070343
# Step = 215 train_loss: 0.01997877 val_loss: 0.50663996
# Step = 216 train_loss: 0.014547324 val_loss: 0.50522727
# Step = 217 train_loss: 0.013625811 val_loss: 0.50061685
# Step = 218 train_loss: 0.008620607 val_loss: 0.47914645
# Step = 219 train_loss: 0.008779734 val_loss: 0.37204784
# Step = 220 train_loss: 0.019844728 val_loss: 0.037498
# Step = 221 train_loss: 0.0058951434 val_loss: 0.016669894
# Step = 222 train_loss: 0.008373922 val_loss: 0.021674983
# Step = 223 train_loss: 0.011063935 val_loss: 0.024751646
# Step = 224 train_loss: 0.007771311 val_loss: 0.026000302
# Step = 225 train_loss: 0.0091988435 val_loss: 0.021683399
# Step = 226 train_loss: 0.010987202 val_loss: 0.023810655
# Step = 227 train_loss: 0.006874939 val_loss: 0.02614307
# Step = 228 train_loss: 0.008327969 val_loss: 0.028526872
# Step = 229 train_loss: 0.004520102 val_loss: 0.029599914
# Step = 230 train_loss: 0.0057823476 val_loss: 0.029764663
# Step = 231 train_loss: 0.009653922 val_loss: 0.02994886
# Step = 232 train_loss: 0.004873057 val_loss: 0.02634317
# Step = 233 train_loss: 0.011058726 val_loss: 0.014874756
# Step = 234 train_loss: 0.008827385 val_loss: 0.022341078
# Step = 235 train_loss: 0.0046869223 val_loss: 0.02414979
# Step = 236 train_loss: 0.00917945 val_loss: 0.02653578
# Step = 237 train_loss: 0.0052711572 val_loss: 0.027620371
# Step = 238 train_loss: 0.005423599 val_loss: 0.029743396
# Step = 239 train_loss: 0.0047467975 val_loss: 0.031203095
# Step = 240 train_loss: 0.0028241936 val_loss: 0.029368054
# Step = 241 train_loss: 0.005783664 val_loss: 0.029014768
# Step = 242 train_loss: 0.0039554136 val_loss: 0.03059226
# Step = 243 train_loss: 0.0069690216 val_loss: 0.035337158
# Step = 244 train_loss: 0.011498043 val_loss: 0.040282857
# Step = 245 train_loss: 0.0064763194 val_loss: 0.04220224
# Step = 246 train_loss: 0.0030668774 val_loss: 0.041452132
# Step = 247 train_loss: 0.0033823738 val_loss: 0.04260419
# Step = 248 train_loss: 0.0013590084 val_loss: 0.041820947
# Step = 249 train_loss: 0.0036316554 val_loss: 0.040495947
# Step = 250 train_loss: 0.006896916 val_loss: 0.039322045
# Step = 251 train_loss: 0.0026707093 val_loss: 0.038994774
# Step = 252 train_loss: 0.00650261 val_loss: 0.03557489
# Step = 253 train_loss: 0.001955993 val_loss: 0.033005998
# Step = 254 train_loss: 0.005406422 val_loss: 0.035732977
# Step = 255 train_loss: 0.0023961898 val_loss: 0.037543993
# Step = 256 train_loss: 0.0034715978 val_loss: 0.037640117
# Step = 257 train_loss: 0.0031581977 val_loss: 0.038066536
# Step = 258 train_loss: 0.005492202 val_loss: 0.038143158
# Step = 259 train_loss: 0.006555297 val_loss: 0.035130255
# Step = 260 train_loss: 0.007176298 val_loss: 0.037050027
# Step = 261 train_loss: 0.0016650705 val_loss: 0.038755275
# Step = 262 train_loss: 0.0029731232 val_loss: 0.03877737
# Step = 263 train_loss: 0.0026360813 val_loss: 0.03592978
# Step = 264 train_loss: 0.0046822596 val_loss: 0.025585547
# Step = 265 train_loss: 0.0036894109 val_loss: 0.0051312456
# Step = 266 train_loss: 0.0038279374 val_loss: 0.0029344803
# Step = 267 train_loss: 0.004451771 val_loss: 0.012664914
# Step = 268 train_loss: 0.0065347436 val_loss: 0.031106923
# Step = 269 train_loss: 0.002494873 val_loss: 0.03634921
# Step = 270 train_loss: 0.0035457262 val_loss: 0.039252277
# Step = 271 train_loss: 0.0035069475 val_loss: 0.038185693
# Step = 272 train_loss: 0.004462028 val_loss: 0.03277904
# Step = 273 train_loss: 0.0027838373 val_loss: 0.027970988
# Step = 274 train_loss: 0.0031956125 val_loss: 0.017864384
# Step = 275 train_loss: 0.0023784288 val_loss: 0.008072714
# Step = 276 train_loss: 0.0024017254 val_loss: 0.0031234163
# Step = 277 train_loss: 0.0056179385 val_loss: 0.0033269154
# Step = 278 train_loss: 0.0050464026 val_loss: 0.005054826
# Step = 279 train_loss: 0.0063753757 val_loss: 0.017614996
# Step = 280 train_loss: 0.0036195705 val_loss: 0.026417801
# Step = 281 train_loss: 0.004525502 val_loss: 0.030792754
# Step = 282 train_loss: 0.003219975 val_loss: 0.033839315
# Step = 283 train_loss: 0.0023464272 val_loss: 0.036257815
# Step = 284 train_loss: 0.003250794 val_loss: 0.03719949
# Step = 285 train_loss: 0.0033214218 val_loss: 0.03723662
# Step = 286 train_loss: 0.004018372 val_loss: 0.035812676
# Step = 287 train_loss: 0.0041981814 val_loss: 0.033987053
# Step = 288 train_loss: 0.007657937 val_loss: 0.033321716
# Step = 289 train_loss: 0.0045621307 val_loss: 0.032463703
# Step = 290 train_loss: 0.0036831412 val_loss: 0.031212034
# Step = 291 train_loss: 0.0031728302 val_loss: 0.029878
# Step = 292 train_loss: 0.0047568586 val_loss: 0.028100302
# Step = 293 train_loss: 0.005512986 val_loss: 0.026246041
# Step = 294 train_loss: 0.0041212277 val_loss: 0.024593867
# Step = 295 train_loss: 0.0030914333 val_loss: 0.023146555
# Step = 296 train_loss: 0.0035481225 val_loss: 0.021991918
# Step = 297 train_loss: 0.006059431 val_loss: 0.021314198
# Step = 298 train_loss: 0.0035597524 val_loss: 0.020927068
# Step = 299 train_loss: 0.0042347866 val_loss: 0.02057238
# Step = 300 train_loss: 0.0039803246 val_loss: 0.020361207
# Step = 301 train_loss: 0.0049342066 val_loss: 0.020082125
# Step = 302 train_loss: 0.003280877 val_loss: 0.019657172
# Step = 303 train_loss: 0.004005692 val_loss: 0.018945966
# Step = 304 train_loss: 0.0034918485 val_loss: 0.017773692
# Step = 305 train_loss: 0.002696877 val_loss: 0.016292118
# Step = 306 train_loss: 0.0036453628 val_loss: 0.014597131
# Step = 307 train_loss: 0.0023790563 val_loss: 0.011988645
# Step = 308 train_loss: 0.0037591236 val_loss: 0.0098272385
# Step = 309 train_loss: 0.0034644953 val_loss: 0.008019024
# Step = 310 train_loss: 0.00516215 val_loss: 0.008199521
# Step = 311 train_loss: 0.0095713595 val_loss: 0.011065208
# Step = 312 train_loss: 0.004540314 val_loss: 0.014731067
# Step = 313 train_loss: 0.004603975 val_loss: 0.013649572
# Step = 314 train_loss: 0.0046694377 val_loss: 0.015516623
# Step = 315 train_loss: 0.0032800408 val_loss: 0.019970348
# Step = 316 train_loss: 0.0025428508 val_loss: 0.021366559
# Step = 317 train_loss: 0.0076865405 val_loss: 0.024197826
# Step = 318 train_loss: 0.0050844024 val_loss: 0.021773905
# Step = 319 train_loss: 0.0021864756 val_loss: 0.01749194
# Step = 320 train_loss: 0.004700969 val_loss: 0.00842621
# Step = 321 train_loss: 0.0053297547 val_loss: 0.008201634
# Step = 322 train_loss: 0.003242109 val_loss: 0.016473241
# Step = 323 train_loss: 0.0026105505 val_loss: 0.024944238
# Step = 324 train_loss: 0.003637033 val_loss: 0.029690208
# Step = 325 train_loss: 0.006072375 val_loss: 0.028674085
# Step = 326 train_loss: 0.0032825286 val_loss: 0.025481204
# Step = 327 train_loss: 0.0027446137 val_loss: 0.028936537
# Step = 328 train_loss: 0.004443774 val_loss: 0.03224079
# Step = 329 train_loss: 0.00491404 val_loss: 0.032279097
# Step = 330 train_loss: 0.004990361 val_loss: 0.029969096
# Step = 331 train_loss: 0.0018856993 val_loss: 0.020050202
# Step = 332 train_loss: 0.003613395 val_loss: 0.010243252
# Step = 333 train_loss: 0.0036618721 val_loss: 0.011473787
# Step = 334 train_loss: 0.003614087 val_loss: 0.02926938
# Step = 335 train_loss: 0.002661275 val_loss: 0.037997082
# Step = 336 train_loss: 0.004840814 val_loss: 0.035770282
# Step = 337 train_loss: 0.0025194888 val_loss: 0.024792396
# Step = 338 train_loss: 0.0023612955 val_loss: 0.03268991
# Step = 339 train_loss: 0.005768696 val_loss: 0.025140166
# Step = 340 train_loss: 0.0028598441 val_loss: 0.028151445
# Step = 341 train_loss: 0.002333976 val_loss: 0.0050014006
# Step = 342 train_loss: 0.004817508 val_loss: 0.032301262
# Step = 343 train_loss: 0.0037491035 val_loss: 0.035068996
# Step = 344 train_loss: 0.003613842 val_loss: 0.027343305
# Step = 345 train_loss: 0.0029295455 val_loss: 0.17367874
# Step = 346 train_loss: 0.006570528 val_loss: 0.35425833
# Step = 347 train_loss: 0.0026908861 val_loss: 0.1909102
# Step = 348 train_loss: 0.0027509886 val_loss: 0.019075457
# Step = 349 train_loss: 0.004397232 val_loss: 0.023377277
# Step = 350 train_loss: 0.0033174364 val_loss: 0.032801993
# Step = 351 train_loss: 0.0041496614 val_loss: 0.04367658
# Step = 352 train_loss: 0.0061196354 val_loss: 0.027616723
# Step = 353 train_loss: 0.0024074027 val_loss: 0.016932623
# Step = 354 train_loss: 0.0049430355 val_loss: 0.38989508
# Step = 355 train_loss: 0.006867441 val_loss: 0.067057595
# Step = 356 train_loss: 0.004210797 val_loss: 0.034898773
# Step = 357 train_loss: 0.0027880522 val_loss: 0.04201915
# Step = 358 train_loss: 0.0035099972 val_loss: 0.029928284
# Step = 359 train_loss: 0.0016992292 val_loss: 0.0050495835
# Step = 360 train_loss: 0.0033834649 val_loss: 0.010665368
# Step = 361 train_loss: 0.005419401 val_loss: 0.028398374
# Step = 362 train_loss: 0.003987112 val_loss: 0.046301764
# Step = 363 train_loss: 0.0077007012 val_loss: 0.007751694
# Step = 364 train_loss: 0.003678856 val_loss: 0.39655098
# Step = 365 train_loss: 0.0043458724 val_loss: 0.3571647
# Step = 366 train_loss: 0.0057721827 val_loss: 0.032477014
# Step = 367 train_loss: 0.003490715 val_loss: 0.04897809
# Step = 368 train_loss: 0.0039428747 val_loss: 0.04243969
# Step = 369 train_loss: 0.004116536 val_loss: 0.0047024675
# Step = 370 train_loss: 0.004002057 val_loss: 0.026633184
# Step = 371 train_loss: 0.0053045545 val_loss: 0.05093592
# Step = 372 train_loss: 0.005077936 val_loss: 0.034817163
# Step = 373 train_loss: 0.005461341 val_loss: 0.4285349
# Step = 374 train_loss: 0.0026691158 val_loss: 0.503745
# Step = 375 train_loss: 0.013217678 val_loss: 0.50349945
# Step = 376 train_loss: 0.004337862 val_loss: 0.4841063
# Step = 377 train_loss: 0.0060532563 val_loss: 0.010345696
# Step = 378 train_loss: 0.005213238 val_loss: 0.05241589
# Step = 379 train_loss: 0.0069592437 val_loss: 0.05300998
# Step = 380 train_loss: 0.0070113936 val_loss: 0.11627795
# Step = 381 train_loss: 0.007463088 val_loss: 0.41501898
# Step = 382 train_loss: 0.0040676156 val_loss: 0.12988524
# Step = 383 train_loss: 0.0042682607 val_loss: 0.023976244
# Step = 384 train_loss: 0.0051983614 val_loss: 0.024076976
# Step = 385 train_loss: 0.0025769142 val_loss: 0.029375311
# Step = 386 train_loss: 0.0021392878 val_loss: 0.04002479
# Step = 387 train_loss: 0.0044642 val_loss: 0.04995482
# Step = 388 train_loss: 0.004992257 val_loss: 0.044940528
# Step = 389 train_loss: 0.0031655 val_loss: 0.035799634
# Step = 390 train_loss: 0.0034027088 val_loss: 0.027909672
# Step = 391 train_loss: 0.0017760227 val_loss: 0.024054777
# Step = 392 train_loss: 0.0032727076 val_loss: 0.033295065
# Step = 393 train_loss: 0.0033832917 val_loss: 0.033585213
# Step = 394 train_loss: 0.0030430418 val_loss: 0.037415907
# Step = 395 train_loss: 0.0032436629 val_loss: 0.037126243
# Step = 396 train_loss: 0.0037049626 val_loss: 0.036828537
# Step = 397 train_loss: 0.0051088934 val_loss: 0.03703986
# Step = 398 train_loss: 0.003483191 val_loss: 0.037361678
# Step = 399 train_loss: 0.0040846705 val_loss: 0.039149433
# Step = 400 train_loss: 0.0035403376 val_loss: 0.042096794
# Step = 401 train_loss: 0.0032669492 val_loss: 0.04515079
# Step = 402 train_loss: 0.0036116191 val_loss: 0.010920822
# Step = 403 train_loss: 0.0029655872 val_loss: 0.4941455
# Step = 404 train_loss: 0.0049306485 val_loss: 0.50120527
# Step = 405 train_loss: 0.0064533344 val_loss: 0.5047325
# Step = 406 train_loss: 0.0059284293 val_loss: 0.49083543
# Step = 407 train_loss: 0.0070716343 val_loss: 0.0023849702
# Step = 408 train_loss: 0.0070971204 val_loss: 0.05963027
# Step = 409 train_loss: 0.007133915 val_loss: 0.012010378
# Step = 410 train_loss: 0.006151724 val_loss: 0.4880215
# Step = 411 train_loss: 0.0063142153 val_loss: 0.50545704
# Step = 412 train_loss: 0.00392321 val_loss: 0.5057455
# Step = 413 train_loss: 0.0030838302 val_loss: 0.4992331
# Step = 414 train_loss: 0.006053937 val_loss: 0.46592623
# Step = 415 train_loss: 0.006557733 val_loss: 0.020904588
# Step = 416 train_loss: 0.0029079157 val_loss: 0.049003914
# Step = 417 train_loss: 0.0031402456 val_loss: 0.04615615
# Step = 418 train_loss: 0.0036726992 val_loss: 0.04263779
# Step = 419 train_loss: 0.002920824 val_loss: 0.039072596
# Step = 420 train_loss: 0.00426316 val_loss: 0.036324833
# Step = 421 train_loss: 0.008480881 val_loss: 0.027311802
# Step = 422 train_loss: 0.0021325948 val_loss: 0.4772883
# Step = 423 train_loss: 0.0074799955 val_loss: 0.5014295
# Step = 424 train_loss: 0.009035348 val_loss: 0.50407207
# Step = 425 train_loss: 0.005474681 val_loss: 0.50311065
# Step = 426 train_loss: 0.0034499122 val_loss: 0.48761177
# Step = 427 train_loss: 0.00593467 val_loss: 0.20860472
# Step = 428 train_loss: 0.0024042816 val_loss: 0.014429566
# Step = 429 train_loss: 0.00660302 val_loss: 0.030907942
# Step = 430 train_loss: 0.008796128 val_loss: 0.040707197
# Step = 431 train_loss: 0.0034256189 val_loss: 0.041639194
# Step = 432 train_loss: 0.005621788 val_loss: 0.02830398
# Step = 433 train_loss: 0.0013107029 val_loss: 0.009323139
# Step = 434 train_loss: 0.0031322083 val_loss: 0.029473586
# Step = 435 train_loss: 0.0025856933 val_loss: 0.04261705
# Step = 436 train_loss: 0.0032502252 val_loss: 0.05276192
# Step = 437 train_loss: 0.0030239564 val_loss: 0.03862384
# Step = 438 train_loss: 0.0035268527 val_loss: 0.0038183453
# Step = 439 train_loss: 0.0030343002 val_loss: 0.027772488
# Step = 440 train_loss: 0.0052071223 val_loss: 0.031416453
# Step = 441 train_loss: 0.002289033 val_loss: 0.034379426
# Step = 442 train_loss: 0.0032786676 val_loss: 0.035986856
# Step = 443 train_loss: 0.0019043061 val_loss: 0.03839277
# Step = 444 train_loss: 0.006064169 val_loss: 0.04051632
# Step = 445 train_loss: 0.0034258089 val_loss: 0.041868493
# Step = 446 train_loss: 0.004241799 val_loss: 0.042765617
# Step = 447 train_loss: 0.0029066487 val_loss: 0.030522585
# Step = 448 train_loss: 0.0022346345 val_loss: 0.011436168
# Step = 449 train_loss: 0.0060875462 val_loss: 0.014141806
# Step = 450 train_loss: 0.0018490503 val_loss: 0.018749744
# Step = 451 train_loss: 0.0031605538 val_loss: 0.018927148
# Step = 452 train_loss: 0.0028719907 val_loss: 0.020090472
# Step = 453 train_loss: 0.0019352676 val_loss: 0.025701072
# Step = 454 train_loss: 0.0021379457 val_loss: 0.026605947
# Step = 455 train_loss: 0.0021394147 val_loss: 0.03168525
# Step = 456 train_loss: 0.0028440058 val_loss: 0.031566508
# Step = 457 train_loss: 0.0028302385 val_loss: 0.037924267
# Step = 458 train_loss: 0.0017218012 val_loss: 0.04244613
# Step = 459 train_loss: 0.0035911088 val_loss: 0.04139423
# Step = 460 train_loss: 0.0022175985 val_loss: 0.04217836
# Step = 461 train_loss: 0.0020657217 val_loss: 0.04173211
# Step = 462 train_loss: 0.0037239268 val_loss: 0.036802046
# Step = 463 train_loss: 0.0017138402 val_loss: 0.029533217
# Step = 464 train_loss: 0.0019129886 val_loss: 0.021592876
# Step = 465 train_loss: 0.0031678053 val_loss: 0.022359753
# Step = 466 train_loss: 0.0026783077 val_loss: 0.019663729
# Step = 467 train_loss: 0.0014624805 val_loss: 0.017927298
# Step = 468 train_loss: 0.0019662788 val_loss: 0.017539034
# Step = 469 train_loss: 0.0028227845 val_loss: 0.020526133
# Step = 470 train_loss: 0.004408288 val_loss: 0.028293734
# Step = 471 train_loss: 0.0015660924 val_loss: 0.03590147
# Step = 472 train_loss: 0.0020591991 val_loss: 0.040362395
# Step = 473 train_loss: 0.0022675577 val_loss: 0.042750377
# Step = 474 train_loss: 0.0026041216 val_loss: 0.042637978
# Step = 475 train_loss: 0.0036971648 val_loss: 0.042418912
# Step = 476 train_loss: 0.0018256889 val_loss: 0.041936267
# Step = 477 train_loss: 0.0021958468 val_loss: 0.041365508
# Step = 478 train_loss: 0.0022587376 val_loss: 0.040529206
# Step = 479 train_loss: 0.002264486 val_loss: 0.039379735
# Step = 480 train_loss: 0.0019018928 val_loss: 0.03814825
# Step = 481 train_loss: 0.0016207519 val_loss: 0.037415918
# Step = 482 train_loss: 0.0026146842 val_loss: 0.036315296
# Step = 483 train_loss: 0.0026905292 val_loss: 0.035000265
# Step = 484 train_loss: 0.0014492994 val_loss: 0.03346443
# Step = 485 train_loss: 0.001955003 val_loss: 0.03183375
# Step = 486 train_loss: 0.001985269 val_loss: 0.029883929
# Step = 487 train_loss: 0.0013516851 val_loss: 0.028191784
# Step = 488 train_loss: 0.0019335032 val_loss: 0.026619766
# Step = 489 train_loss: 0.0026107314 val_loss: 0.025085371
# Step = 490 train_loss: 0.0013120379 val_loss: 0.023545964
# Step = 491 train_loss: 0.0023713252 val_loss: 0.021801516
# Step = 492 train_loss: 0.0020721154 val_loss: 0.020166766
# Step = 493 train_loss: 0.0017976636 val_loss: 0.0187214
# Step = 494 train_loss: 0.0020578986 val_loss: 0.017573569
# Step = 495 train_loss: 0.0018069658 val_loss: 0.016493684
# Step = 496 train_loss: 0.0022297604 val_loss: 0.01556908
# Step = 497 train_loss: 0.0030754209 val_loss: 0.014886672
# Step = 498 train_loss: 0.0017553924 val_loss: 0.014229021
# Step = 499 train_loss: 0.002071986 val_loss: 0.013685599
# Step = 500 train_loss: 0.002846063 val_loss: 0.013196383
# Step = 501 train_loss: 0.0024998335 val_loss: 0.01258557
# Step = 502 train_loss: 0.001909297 val_loss: 0.012105544
# Step = 503 train_loss: 0.0033044813 val_loss: 0.011728083
# Step = 504 train_loss: 0.002011918 val_loss: 0.011469167
# Step = 505 train_loss: 0.0021789952 val_loss: 0.011226255
# Step = 506 train_loss: 0.0027074849 val_loss: 0.011058337
# Step = 507 train_loss: 0.0036904453 val_loss: 0.011388936
# Step = 508 train_loss: 0.0018898637 val_loss: 0.011549047
# Step = 509 train_loss: 0.0040240497 val_loss: 0.0116796475
# Step = 510 train_loss: 0.002017029 val_loss: 0.011732614
# Step = 511 train_loss: 0.0025523019 val_loss: 0.011895783
# Step = 512 train_loss: 0.0020140389 val_loss: 0.01193969
# Step = 513 train_loss: 0.0028706393 val_loss: 0.012482259
# Step = 514 train_loss: 0.0020644232 val_loss: 0.013236378
# Step = 515 train_loss: 0.002450706 val_loss: 0.013503334
# Step = 516 train_loss: 0.0019245434 val_loss: 0.0118005825
# Step = 517 train_loss: 0.0018233968 val_loss: 0.010165926
# Step = 518 train_loss: 0.0016646937 val_loss: 0.008058314
# Step = 519 train_loss: 0.0020939454 val_loss: 0.0044873506
# Step = 520 train_loss: 0.00161069 val_loss: 0.003071673
# Step = 521 train_loss: 0.0018511981 val_loss: 0.0037618817
# Step = 522 train_loss: 0.0017846526 val_loss: 0.0071617234
# Step = 523 train_loss: 0.0021810997 val_loss: 0.014713531
# Step = 524 train_loss: 0.0031040856 val_loss: 0.018603355
# Step = 525 train_loss: 0.0020828308 val_loss: 0.021283874
# Step = 526 train_loss: 0.0017529833 val_loss: 0.032267816
# Step = 527 train_loss: 0.0023635987 val_loss: 0.041922797
# Step = 528 train_loss: 0.0016651278 val_loss: 0.070720784
# Step = 529 train_loss: 0.0023159867 val_loss: 0.06128648
# Step = 530 train_loss: 0.0028229316 val_loss: 0.029573616
# Step = 531 train_loss: 0.0015342025 val_loss: 0.020673407
# Step = 532 train_loss: 0.0027896278 val_loss: 0.0032796802
# Step = 533 train_loss: 0.0015878975 val_loss: 0.0041956324
# Step = 534 train_loss: 0.001475629 val_loss: 0.014295306
# Step = 535 train_loss: 0.0024725709 val_loss: 0.025664626
# Step = 536 train_loss: 0.0014056729 val_loss: 0.035417225
# Step = 537 train_loss: 0.002013294 val_loss: 0.039529346
# Step = 538 train_loss: 0.0024798699 val_loss: 0.040661536
# Step = 539 train_loss: 0.0016740045 val_loss: 0.040950675
# Step = 540 train_loss: 0.0021381585 val_loss: 0.041040827
# Step = 541 train_loss: 0.0025510932 val_loss: 0.03965292
# Step = 542 train_loss: 0.0018067905 val_loss: 0.030311057
# Step = 543 train_loss: 0.0024037277 val_loss: 0.026946664
# Step = 544 train_loss: 0.002532009 val_loss: 0.024519749
# Step = 545 train_loss: 0.0017901819 val_loss: 0.025302995
# Step = 546 train_loss: 0.0027401003 val_loss: 0.0276067
# Step = 547 train_loss: 0.0018998568 val_loss: 0.029877378
# Step = 548 train_loss: 0.0024723113 val_loss: 0.034539927
# Step = 549 train_loss: 0.0021545338 val_loss: 0.030435154
# Step = 550 train_loss: 0.0025142012 val_loss: 0.009809277
# Step = 551 train_loss: 0.0022448169 val_loss: 0.31951678
# Step = 552 train_loss: 0.0019930115 val_loss: 0.46556556
# Step = 553 train_loss: 0.0048150737 val_loss: 0.038123496
# Step = 554 train_loss: 0.0015125775 val_loss: 0.019012244
# Step = 555 train_loss: 0.0014227882 val_loss: 0.034225166
# Step = 556 train_loss: 0.002204468 val_loss: 0.03619629
# Step = 557 train_loss: 0.005166308 val_loss: 0.48961094
# Step = 558 train_loss: 0.0025462476 val_loss: 0.49736238
# Step = 559 train_loss: 0.0053722886 val_loss: 0.50016403
# Step = 560 train_loss: 0.0028205337 val_loss: 0.5050127
# Step = 561 train_loss: 0.0096470285 val_loss: 0.50810343
# Step = 562 train_loss: 0.0048201904 val_loss: 0.508773
# Step = 563 train_loss: 0.007921961 val_loss: 0.5084653
# Step = 564 train_loss: 0.008868351 val_loss: 0.49425808
# Step = 565 train_loss: 0.0076020164 val_loss: 0.38323784
# Step = 566 train_loss: 0.013784165 val_loss: 0.044618417
# Step = 567 train_loss: 0.003166138 val_loss: 0.013285725
# Step = 568 train_loss: 0.006491633 val_loss: 0.041960377
# Step = 569 train_loss: 0.005521603 val_loss: 0.04736298
# Step = 570 train_loss: 0.0072235283 val_loss: 0.048068892
# Step = 571 train_loss: 0.01925555 val_loss: 0.04163552
# Step = 572 train_loss: 0.014248958 val_loss: 0.022422543
# Step = 573 train_loss: 0.005400576 val_loss: 0.025762636
# Step = 574 train_loss: 0.005799838 val_loss: 0.02065847
# Step = 575 train_loss: 0.010397559 val_loss: 0.019810103
# Step = 576 train_loss: 0.008647179 val_loss: 0.020911412
# Step = 577 train_loss: 0.008734228 val_loss: 0.022416042
# Step = 578 train_loss: 0.0063608447 val_loss: 0.02495773
# Step = 579 train_loss: 0.003863711 val_loss: 0.026309729
# Step = 580 train_loss: 0.004333984 val_loss: 0.026041575
# Step = 581 train_loss: 0.013991392 val_loss: 0.026504584
# Step = 582 train_loss: 0.007016913 val_loss: 0.025080143
# Step = 583 train_loss: 0.0039567384 val_loss: 0.022356378
# Step = 584 train_loss: 0.0051186625 val_loss: 0.020878686
# Step = 585 train_loss: 0.004553538 val_loss: 0.019237773
# Step = 586 train_loss: 0.0059279925 val_loss: 0.016962523
# Step = 587 train_loss: 0.006391955 val_loss: 0.0162336
# Step = 588 train_loss: 0.0057969233 val_loss: 0.01857189
# Step = 589 train_loss: 0.003306969 val_loss: 0.018801609
# Step = 590 train_loss: 0.005086619 val_loss: 0.018113272
# Step = 591 train_loss: 0.0042557237 val_loss: 0.01748019
# Step = 592 train_loss: 0.0037939283 val_loss: 0.01628842
# Step = 593 train_loss: 0.003385129 val_loss: 0.012660579
# Step = 594 train_loss: 0.004478377 val_loss: 0.013210971
# Step = 595 train_loss: 0.0076643387 val_loss: 0.017030941
# Step = 596 train_loss: 0.0036946929 val_loss: 0.017236233
# Step = 597 train_loss: 0.0048701297 val_loss: 0.016509874
# Step = 598 train_loss: 0.002387285 val_loss: 0.014958469
# Step = 599 train_loss: 0.0028584625 val_loss: 0.015222332
# Step = 600 train_loss: 0.0020439764 val_loss: 0.016366975
# Step = 601 train_loss: 0.0032174645 val_loss: 0.016318928
# Step = 602 train_loss: 0.0027341088 val_loss: 0.01607958
# Step = 603 train_loss: 0.0046964213 val_loss: 0.016980909
# Step = 604 train_loss: 0.0050281757 val_loss: 0.017051343
# Step = 605 train_loss: 0.0025158064 val_loss: 0.015819466
# Step = 606 train_loss: 0.004152193 val_loss: 0.014891163
# Step = 607 train_loss: 0.001882717 val_loss: 0.012805981
# Step = 608 train_loss: 0.0016939039 val_loss: 0.013316103
# Step = 609 train_loss: 0.0024608558 val_loss: 0.015782038
# Step = 610 train_loss: 0.0024301948 val_loss: 0.01934403
# Step = 611 train_loss: 0.0019395644 val_loss: 0.022987377
# Step = 612 train_loss: 0.0021607885 val_loss: 0.024372578
# Step = 613 train_loss: 0.0037974168 val_loss: 0.024998644
# Step = 614 train_loss: 0.0026274973 val_loss: 0.024898363
# Step = 615 train_loss: 0.0024765518 val_loss: 0.024163965
# Step = 616 train_loss: 0.0035825819 val_loss: 0.015965147
# Step = 617 train_loss: 0.0028561407 val_loss: 0.0086160395
# Step = 618 train_loss: 0.0029082422 val_loss: 0.01163675
# Step = 619 train_loss: 0.0020877258 val_loss: 0.022740245
# Step = 620 train_loss: 0.0025898854 val_loss: 0.024664424
# Step = 621 train_loss: 0.0013037093 val_loss: 0.02424247
# Step = 622 train_loss: 0.002041956 val_loss: 0.018301928
# Step = 623 train_loss: 0.0020381212 val_loss: 0.0028378298
# Step = 624 train_loss: 0.0017512869 val_loss: 0.17076367
# Step = 625 train_loss: 0.0021148752 val_loss: 0.23674448
# Step = 626 train_loss: 0.001836449 val_loss: 0.10492202
# Step = 627 train_loss: 0.0021404834 val_loss: 0.00482249
# Step = 628 train_loss: 0.0017587495 val_loss: 0.015975267
# Step = 629 train_loss: 0.0018847903 val_loss: 0.032324575
# Step = 630 train_loss: 0.0030230347 val_loss: 0.03367508
# Step = 631 train_loss: 0.0016884685 val_loss: 0.033064846
# Step = 632 train_loss: 0.001929285 val_loss: 0.032223597
# Step = 633 train_loss: 0.0016513169 val_loss: 0.029370701
# Step = 634 train_loss: 0.0017358306 val_loss: 0.018145796
# Step = 635 train_loss: 0.002649726 val_loss: 0.010568906
# Step = 636 train_loss: 0.0012958274 val_loss: 0.008351329
# Step = 637 train_loss: 0.0016581486 val_loss: 0.013716785
# Step = 638 train_loss: 0.0016162654 val_loss: 0.0151440995
# Step = 639 train_loss: 0.0017938762 val_loss: 0.016004592
# Step = 640 train_loss: 0.001509017 val_loss: 0.015217571
# Step = 641 train_loss: 0.0011989147 val_loss: 0.015939645
# Step = 642 train_loss: 0.0017159664 val_loss: 0.015632672
# Step = 643 train_loss: 0.00094206264 val_loss: 0.015227447
# Step = 644 train_loss: 0.0023065873 val_loss: 0.022108588
# Step = 645 train_loss: 0.0020119904 val_loss: 0.025421364
# Step = 646 train_loss: 0.002068636 val_loss: 0.030401982
# Step = 647 train_loss: 0.001957097 val_loss: 0.033110306
# Step = 648 train_loss: 0.0030101957 val_loss: 0.40034658
# Step = 649 train_loss: 0.0021592777 val_loss: 0.50766957
# Step = 650 train_loss: 0.0038495657 val_loss: 0.50882155
# Step = 651 train_loss: 0.004749235 val_loss: 0.50913256
# Step = 652 train_loss: 0.0018755674 val_loss: 0.509277
# Step = 653 train_loss: 0.0019734444 val_loss: 0.50875694
# Step = 654 train_loss: 0.005276695 val_loss: 0.4953148
# Step = 655 train_loss: 0.005261831 val_loss: 0.49008384
# Step = 656 train_loss: 0.0026226153 val_loss: 0.25607514
# Step = 657 train_loss: 0.0027495222 val_loss: 0.0018280159
# Step = 658 train_loss: 0.0022678801 val_loss: 0.019995378
# Step = 659 train_loss: 0.003846517 val_loss: 0.032760255
# Step = 660 train_loss: 0.0058109337 val_loss: 0.026082184
# Step = 661 train_loss: 0.005651665 val_loss: 0.017070178
# Step = 662 train_loss: 0.002857561 val_loss: 0.0018568004
# Step = 663 train_loss: 0.002880434 val_loss: 0.063612
# Step = 664 train_loss: 0.0029158944 val_loss: 0.14488347
# Step = 665 train_loss: 0.0016953421 val_loss: 0.16392782
# Step = 666 train_loss: 0.0037757154 val_loss: 0.14760248
# Step = 667 train_loss: 0.0049250787 val_loss: 0.084077924
# Step = 668 train_loss: 0.003753096 val_loss: 0.0065354626
# Step = 669 train_loss: 0.0020440856 val_loss: 0.003961979
# Step = 670 train_loss: 0.002405051 val_loss: 0.016746292
# Step = 671 train_loss: 0.0013290688 val_loss: 0.022526095
# Step = 672 train_loss: 0.0028857752 val_loss: 0.02921924
# Step = 673 train_loss: 0.0025419 val_loss: 0.032643788
# Step = 674 train_loss: 0.0045656753 val_loss: 0.035397764
# Step = 675 train_loss: 0.0013859398 val_loss: 0.036195487
# Step = 676 train_loss: 0.0012174915 val_loss: 0.036175672
# Step = 677 train_loss: 0.0018406869 val_loss: 0.036052782
# Step = 678 train_loss: 0.0024534354 val_loss: 0.03471562
# Step = 679 train_loss: 0.0020414894 val_loss: 0.033412404
# Step = 680 train_loss: 0.0012846664 val_loss: 0.03127213
# Step = 681 train_loss: 0.003149636 val_loss: 0.028084423
# Step = 682 train_loss: 0.0019526911 val_loss: 0.024765337
# Step = 683 train_loss: 0.0012938585 val_loss: 0.02173409
# Step = 684 train_loss: 0.0016009882 val_loss: 0.019397367
# Step = 685 train_loss: 0.0015124716 val_loss: 0.018208714
# Step = 686 train_loss: 0.0012370765 val_loss: 0.017336046
# Step = 687 train_loss: 0.0025435053 val_loss: 0.017560795
# Step = 688 train_loss: 0.002210842 val_loss: 0.018266343
# Step = 689 train_loss: 0.0019504146 val_loss: 0.018946817
# Step = 690 train_loss: 0.0020022916 val_loss: 0.019061971
# Step = 691 train_loss: 0.003798798 val_loss: 0.019574841
# Step = 692 train_loss: 0.001144265 val_loss: 0.019681092
# Step = 693 train_loss: 0.0014802164 val_loss: 0.019634334
# Step = 694 train_loss: 0.0017813172 val_loss: 0.019340504
# Step = 695 train_loss: 0.0018814506 val_loss: 0.019029554
# Step = 696 train_loss: 0.002425359 val_loss: 0.018758884
# Step = 697 train_loss: 0.0016656845 val_loss: 0.018348293
# Step = 698 train_loss: 0.0019003793 val_loss: 0.017910754
# Step = 699 train_loss: 0.0017035867 val_loss: 0.01743395
# Step = 700 train_loss: 0.0012499186 val_loss: 0.016923014
# Step = 701 train_loss: 0.0029812627 val_loss: 0.016481955
# Step = 702 train_loss: 0.0019028293 val_loss: 0.016117632
# Step = 703 train_loss: 0.0039230743 val_loss: 0.015803523
# Step = 704 train_loss: 0.001705238 val_loss: 0.0153472135
# Step = 705 train_loss: 0.0023208933 val_loss: 0.01490608
# Step = 706 train_loss: 0.0029759216 val_loss: 0.014111073
# Step = 707 train_loss: 0.0019155041 val_loss: 0.013481211
# Step = 708 train_loss: 0.002014441 val_loss: 0.012740234
# Step = 709 train_loss: 0.001934648 val_loss: 0.012492989
# Step = 710 train_loss: 0.0033001688 val_loss: 0.011604149
# Step = 711 train_loss: 0.0014246018 val_loss: 0.0108022
# Step = 712 train_loss: 0.0041817394 val_loss: 0.010476838
# Step = 713 train_loss: 0.0024300602 val_loss: 0.010605174
# Step = 714 train_loss: 0.004111013 val_loss: 0.011901872
# Step = 715 train_loss: 0.0027248615 val_loss: 0.011921212
# Step = 716 train_loss: 0.004017546 val_loss: 0.013871657
# Step = 717 train_loss: 0.0028905498 val_loss: 0.015434345
# Step = 718 train_loss: 0.0024773558 val_loss: 0.016977532
# Step = 719 train_loss: 0.0018616399 val_loss: 0.017825974
# Step = 720 train_loss: 0.0008396569 val_loss: 0.01848173
# Step = 721 train_loss: 0.0016190634 val_loss: 0.018477045
# Step = 722 train_loss: 0.0027498526 val_loss: 0.017547825
# Step = 723 train_loss: 0.0020040649 val_loss: 0.016672233
# Step = 724 train_loss: 0.0017422927 val_loss: 0.016408095
# Step = 725 train_loss: 0.0016093361 val_loss: 0.015758913
# Step = 726 train_loss: 0.0017134313 val_loss: 0.01789243
# Step = 727 train_loss: 0.0014743723 val_loss: 0.018770704
# Step = 728 train_loss: 0.0021673082 val_loss: 0.017013978
# Step = 729 train_loss: 0.0016166861 val_loss: 0.016278569
# Step = 730 train_loss: 0.0020381457 val_loss: 0.01163476
# Step = 731 train_loss: 0.0025945045 val_loss: 0.014439624
# Step = 732 train_loss: 0.0009886109 val_loss: 0.016417325
# Step = 733 train_loss: 0.0018378237 val_loss: 0.021520568
# Step = 734 train_loss: 0.0012693349 val_loss: 0.027140073
# Step = 735 train_loss: 0.0014954756 val_loss: 0.03312636
# Step = 736 train_loss: 0.0019250682 val_loss: 0.033674616
# Step = 737 train_loss: 0.0044802926 val_loss: 0.03274284
# Step = 738 train_loss: 0.0011180099 val_loss: 0.03196894
# Step = 739 train_loss: 0.0036402033 val_loss: 0.029564748
# Step = 740 train_loss: 0.0012877651 val_loss: 0.0272824
# Step = 741 train_loss: 0.0013589495 val_loss: 0.02502002
# Step = 742 train_loss: 0.0012973839 val_loss: 0.024763368
# Step = 743 train_loss: 0.0010439089 val_loss: 0.02386242
# Step = 744 train_loss: 0.0014226212 val_loss: 0.020941837
# Step = 745 train_loss: 0.0025323501 val_loss: 0.026818007
# Step = 746 train_loss: 0.001993915 val_loss: 0.029185126
# Step = 747 train_loss: 0.0008717297 val_loss: 0.031708255
# Step = 748 train_loss: 0.0018559562 val_loss: 0.031443775
# Step = 749 train_loss: 0.0012513755 val_loss: 0.026806904
# Step = 750 train_loss: 0.0018262726 val_loss: 0.015972601
# Step = 751 train_loss: 0.0025233207 val_loss: 0.0025428843
# Step = 752 train_loss: 0.0027889332 val_loss: 0.009773976
# Step = 753 train_loss: 0.0012850644 val_loss: 0.015834944
# Step = 754 train_loss: 0.0024783465 val_loss: 0.0022436695
# Step = 755 train_loss: 0.0011543925 val_loss: 0.004950487
# Step = 756 train_loss: 0.001959751 val_loss: 0.058621082
# Step = 757 train_loss: 0.0020228357 val_loss: 0.026893433
# Step = 758 train_loss: 0.0016350986 val_loss: 0.0021283224
# Step = 759 train_loss: 0.0031383461 val_loss: 0.022726646
# Step = 760 train_loss: 0.0013077133 val_loss: 0.034646276
# Step = 761 train_loss: 0.0016889174 val_loss: 0.03429155
# Step = 762 train_loss: 0.0023534256 val_loss: 0.021002907
# Step = 763 train_loss: 0.0020686905 val_loss: 0.015457446
# Step = 764 train_loss: 0.0019884624 val_loss: 0.4450488
# Step = 765 train_loss: 0.0022861934 val_loss: 0.49053463
# Step = 766 train_loss: 0.0014734485 val_loss: 0.4911582
# Step = 767 train_loss: 0.0036236083 val_loss: 0.49092615
# Step = 768 train_loss: 0.0030044378 val_loss: 0.34758765
# Step = 769 train_loss: 0.003263062 val_loss: 0.018238412
# Step = 770 train_loss: 0.0021170913 val_loss: 0.033453815
# Step = 771 train_loss: 0.002786459 val_loss: 0.02819325
# Step = 772 train_loss: 0.0013536507 val_loss: 0.018070016
# Step = 773 train_loss: 0.0016726756 val_loss: 0.0024086675
# Step = 774 train_loss: 0.0018421111 val_loss: 0.07662384
# Step = 775 train_loss: 0.0039893915 val_loss: 0.015760163
# Step = 776 train_loss: 0.0014508584 val_loss: 0.03203595
# Step = 777 train_loss: 0.0024662863 val_loss: 0.033356264
# Step = 778 train_loss: 0.006123613 val_loss: 0.5091278
# Step = 779 train_loss: 0.0036974165 val_loss: 0.5022421
# Step = 780 train_loss: 0.00456693 val_loss: 0.5052788
# Step = 781 train_loss: 0.011044123 val_loss: 0.5083753
# Step = 782 train_loss: 0.017064855 val_loss: 0.50940835
# Step = 783 train_loss: 0.017577661 val_loss: 0.5095477
# Step = 784 train_loss: 0.010928595 val_loss: 0.5095769
# Step = 785 train_loss: 0.003373543 val_loss: 0.5095859
# Step = 786 train_loss: 0.008419581 val_loss: 0.5095896
# Step = 787 train_loss: 0.0073635313 val_loss: 0.5095912
# Step = 788 train_loss: 0.006937364 val_loss: 0.5095918
# Step = 789 train_loss: 0.017616408 val_loss: 0.5095921
# Step = 790 train_loss: 0.013928741 val_loss: 0.50959224
# Step = 791 train_loss: 0.018070577 val_loss: 0.50959224
# Step = 792 train_loss: 0.013912641 val_loss: 0.5095922
# Step = 793 train_loss: 0.009452086 val_loss: 0.5095918
# Step = 794 train_loss: 0.016642805 val_loss: 0.509569
# Step = 795 train_loss: 0.0057634315 val_loss: 0.5044775
# Step = 796 train_loss: 0.008033197 val_loss: 0.49303156
# Step = 797 train_loss: 0.013561064 val_loss: 0.48717472
# Step = 798 train_loss: 0.008021363 val_loss: 0.47195658
# Step = 799 train_loss: 0.00713457 val_loss: 0.42511418
# Step = 800 train_loss: 0.0036552162 val_loss: 0.09941346
# Step = 801 train_loss: 0.0068030613 val_loss: 0.10372767
# Step = 802 train_loss: 0.004501816 val_loss: 0.19562219
# Step = 803 train_loss: 0.0033737659 val_loss: 0.4538954
# Step = 804 train_loss: 0.0071266005 val_loss: 0.3977081
# Step = 805 train_loss: 0.012253145 val_loss: 0.049250185
# Step = 806 train_loss: 0.02793325 val_loss: 0.04027072
# Step = 807 train_loss: 0.015219808 val_loss: 0.04856132
# Step = 808 train_loss: 0.0153337605 val_loss: 0.06768515
# Step = 809 train_loss: 0.0132745495 val_loss: 0.08279889
# Step = 810 train_loss: 0.019685 val_loss: 0.083696716
# Step = 811 train_loss: 0.016215136 val_loss: 0.07072667
# Step = 812 train_loss: 0.009581954 val_loss: 0.054253694
# Step = 813 train_loss: 0.0070433016 val_loss: 0.044353765
# Step = 814 train_loss: 0.009835265 val_loss: 0.03634233
# Step = 815 train_loss: 0.010889646 val_loss: 0.027836105
# Step = 816 train_loss: 0.01001648 val_loss: 0.022292253
# Step = 817 train_loss: 0.010769823 val_loss: 0.018395213
# Step = 818 train_loss: 0.009435851 val_loss: 0.016251424
# Step = 819 train_loss: 0.0037919427 val_loss: 0.015274488
# Step = 820 train_loss: 0.011970038 val_loss: 0.014871029
# Step = 821 train_loss: 0.0076316977 val_loss: 0.014908068
# Step = 822 train_loss: 0.0029088869 val_loss: 0.015266789
# Step = 823 train_loss: 0.006115474 val_loss: 0.0149799455
# Step = 824 train_loss: 0.0021301007 val_loss: 0.014444978
# Step = 825 train_loss: 0.004660755 val_loss: 0.014512101
# Step = 826 train_loss: 0.005518978 val_loss: 0.016825786
# Step = 827 train_loss: 0.004590229 val_loss: 0.021036267
# Step = 828 train_loss: 0.0032031026 val_loss: 0.025954377
# Step = 829 train_loss: 0.0034519073 val_loss: 0.032051336
# Step = 830 train_loss: 0.0031188033 val_loss: 0.03584531
# Step = 831 train_loss: 0.0071854126 val_loss: 0.04182248
# Step = 832 train_loss: 0.002332003 val_loss: 0.043137558
# Step = 833 train_loss: 0.0021854246 val_loss: 0.017899364
# Step = 834 train_loss: 0.008598849 val_loss: 0.021682756
# Step = 835 train_loss: 0.0029539792 val_loss: 0.024562774
# Step = 836 train_loss: 0.0040906067 val_loss: 0.026112283
# Step = 837 train_loss: 0.0020203644 val_loss: 0.027467724
# Step = 838 train_loss: 0.0019503449 val_loss: 0.028503694
# Step = 839 train_loss: 0.0021466424 val_loss: 0.029602632
# Step = 840 train_loss: 0.0065790094 val_loss: 0.030447213
# Step = 841 train_loss: 0.0049812165 val_loss: 0.031206897
# Step = 842 train_loss: 0.0020889896 val_loss: 0.027008696
# Step = 843 train_loss: 0.0034889388 val_loss: 0.019530034
# Step = 844 train_loss: 0.0012130924 val_loss: 0.012203952
# Step = 845 train_loss: 0.0061991024 val_loss: 0.014321698
# Step = 846 train_loss: 0.0038200545 val_loss: 0.01731436
# Step = 847 train_loss: 0.002427823 val_loss: 0.022461077
# Step = 848 train_loss: 0.0016966332 val_loss: 0.026897576
# Step = 849 train_loss: 0.0013452435 val_loss: 0.031115424
# Step = 850 train_loss: 0.0010277631 val_loss: 0.033520818
# Step = 851 train_loss: 0.0034544123 val_loss: 0.034400858
# Step = 852 train_loss: 0.0027200703 val_loss: 0.03604916
# Step = 853 train_loss: 0.004512443 val_loss: 0.037713915
# Step = 854 train_loss: 0.0015458653 val_loss: 0.038239375
# Step = 855 train_loss: 0.0018243155 val_loss: 0.03844997
# Step = 856 train_loss: 0.003838483 val_loss: 0.03847487
# Step = 857 train_loss: 0.0024737483 val_loss: 0.03809613
# Step = 858 train_loss: 0.0031129753 val_loss: 0.03687116
# Step = 859 train_loss: 0.003941005 val_loss: 0.033542328
# Step = 860 train_loss: 0.0031857868 val_loss: 0.03172188
# Step = 861 train_loss: 0.003907557 val_loss: 0.032760914
# Step = 862 train_loss: 0.0017765127 val_loss: 0.033475302
# Step = 863 train_loss: 0.0026105116 val_loss: 0.03414596
# Step = 864 train_loss: 0.0012314541 val_loss: 0.033968955
# Step = 865 train_loss: 0.0028084116 val_loss: 0.03351568
# Step = 866 train_loss: 0.0019902054 val_loss: 0.03268752
# Step = 867 train_loss: 0.0023265157 val_loss: 0.031151664
# Step = 868 train_loss: 0.0019114974 val_loss: 0.028358428
# Step = 869 train_loss: 0.0035215335 val_loss: 0.028627796
# Step = 870 train_loss: 0.0025249044 val_loss: 0.029890148
# Step = 871 train_loss: 0.0029219065 val_loss: 0.029875118
# Step = 872 train_loss: 0.0030231434 val_loss: 0.029269679
# Step = 873 train_loss: 0.0018415477 val_loss: 0.028035266
# Step = 874 train_loss: 0.0017100733 val_loss: 0.02678783
# Step = 875 train_loss: 0.0037613001 val_loss: 0.025719196
# Step = 876 train_loss: 0.002656028 val_loss: 0.02548867
# Step = 877 train_loss: 0.0018895784 val_loss: 0.025367793
# Step = 878 train_loss: 0.0035511097 val_loss: 0.024436925
# Step = 879 train_loss: 0.0013722604 val_loss: 0.02325528
# Step = 880 train_loss: 0.0019897257 val_loss: 0.021421546
# Step = 881 train_loss: 0.0016279427 val_loss: 0.020077577
# Step = 882 train_loss: 0.0017634892 val_loss: 0.018813249
# Step = 883 train_loss: 0.0019462024 val_loss: 0.01727793
# Step = 884 train_loss: 0.0020795292 val_loss: 0.015311195
# Step = 885 train_loss: 0.0034807513 val_loss: 0.011816241
# Step = 886 train_loss: 0.002935482 val_loss: 0.010017944
# Step = 887 train_loss: 0.0027974958 val_loss: 0.009365326
# Step = 888 train_loss: 0.001640273 val_loss: 0.0090033375
# Step = 889 train_loss: 0.0022235343 val_loss: 0.008655751
# Step = 890 train_loss: 0.0021294146 val_loss: 0.008236027
# Step = 891 train_loss: 0.0020883982 val_loss: 0.008273904
# Step = 892 train_loss: 0.0022073975 val_loss: 0.008346845
# Step = 893 train_loss: 0.0027073422 val_loss: 0.008669315
# Step = 894 train_loss: 0.0017069802 val_loss: 0.009077607
# Step = 895 train_loss: 0.0026319197 val_loss: 0.009435249
# Step = 896 train_loss: 0.0015966514 val_loss: 0.0096085705
# Step = 897 train_loss: 0.0025142888 val_loss: 0.009868925
# Step = 898 train_loss: 0.002139114 val_loss: 0.010027198
# Step = 899 train_loss: 0.001517252 val_loss: 0.010065155
# Step = 900 train_loss: 0.00232013 val_loss: 0.010031117
# Step = 901 train_loss: 0.001775716 val_loss: 0.009946209
# Step = 902 train_loss: 0.002742879 val_loss: 0.009988575
# Step = 903 train_loss: 0.0034157638 val_loss: 0.010055646
# Step = 904 train_loss: 0.0013164307 val_loss: 0.010375313
# Step = 905 train_loss: 0.0028924108 val_loss: 0.010815047
# Step = 906 train_loss: 0.002697695 val_loss: 0.011300364
# Step = 907 train_loss: 0.0015655379 val_loss: 0.0117497705
# Step = 908 train_loss: 0.0018086309 val_loss: 0.012359296
# Step = 909 train_loss: 0.00283408 val_loss: 0.012624495
# Step = 910 train_loss: 0.002153123 val_loss: 0.013113314
# Step = 911 train_loss: 0.0024469418 val_loss: 0.014127548
# Step = 912 train_loss: 0.0019857204 val_loss: 0.015224044
# Step = 913 train_loss: 0.0019545653 val_loss: 0.016099162
# Step = 914 train_loss: 0.0017251436 val_loss: 0.016479002
# Step = 915 train_loss: 0.002136792 val_loss: 0.01713577
# Step = 916 train_loss: 0.0016158742 val_loss: 0.018061569
# Step = 917 train_loss: 0.001997089 val_loss: 0.018541966
# Step = 918 train_loss: 0.0020003081 val_loss: 0.018227614
# Step = 919 train_loss: 0.0013533073 val_loss: 0.017723046
# Step = 920 train_loss: 0.0017148991 val_loss: 0.017165862
# Step = 921 train_loss: 0.0020099955 val_loss: 0.015264519
# Step = 922 train_loss: 0.0017382716 val_loss: 0.011951877
# Step = 923 train_loss: 0.0031658409 val_loss: 0.008426006
# Step = 924 train_loss: 0.00212877 val_loss: 0.0037465252
# Step = 925 train_loss: 0.001492884 val_loss: 0.0025636484
# Step = 926 train_loss: 0.0022121414 val_loss: 0.0030579555
# Step = 927 train_loss: 0.0014457852 val_loss: 0.0033783098
# Step = 928 train_loss: 0.0037552947 val_loss: 0.005021508
# Step = 929 train_loss: 0.0018492093 val_loss: 0.0117907515
# Step = 930 train_loss: 0.0020080318 val_loss: 0.014853727
# Step = 931 train_loss: 0.0019450308 val_loss: 0.015551909
# Step = 932 train_loss: 0.0020975873 val_loss: 0.013495163
# Step = 933 train_loss: 0.0019195795 val_loss: 0.0059690583
# Step = 934 train_loss: 0.0022580146 val_loss: 0.0025534742
# Step = 935 train_loss: 0.0018958106 val_loss: 0.0025774585
# Step = 936 train_loss: 0.001999838 val_loss: 0.0026582484
# Step = 937 train_loss: 0.0019016619 val_loss: 0.0030827725
# Step = 938 train_loss: 0.0015223593 val_loss: 0.0035804142
# Step = 939 train_loss: 0.0017255738 val_loss: 0.0026015793
# Step = 940 train_loss: 0.0018467256 val_loss: 0.0025110662
# Step = 941 train_loss: 0.0019621141 val_loss: 0.0024777981
# Step = 942 train_loss: 0.0013050941 val_loss: 0.0069252774
# Step = 943 train_loss: 0.0026570517 val_loss: 0.007483481
# Step = 944 train_loss: 0.0026446718 val_loss: 0.007839244
# Step = 945 train_loss: 0.0026637232 val_loss: 0.008972774
# Step = 946 train_loss: 0.0025287005 val_loss: 0.004091261
# Step = 947 train_loss: 0.0021834972 val_loss: 0.010975502
# Step = 948 train_loss: 0.0017927686 val_loss: 0.01889194
# Step = 949 train_loss: 0.002803644 val_loss: 0.022553474
# Step = 950 train_loss: 0.002852179 val_loss: 0.023247736
# Step = 951 train_loss: 0.0016091156 val_loss: 0.02211473
# Step = 952 train_loss: 0.0018852736 val_loss: 0.021493576
# Step = 953 train_loss: 0.002740364 val_loss: 0.031013675
# Step = 954 train_loss: 0.0018360601 val_loss: 0.032272637
# Step = 955 train_loss: 0.0027066758 val_loss: 0.031671643
# Step = 956 train_loss: 0.0018177591 val_loss: 0.030832253
# Step = 957 train_loss: 0.0012783007 val_loss: 0.02975784
# Step = 958 train_loss: 0.0017203935 val_loss: 0.029562809
# Step = 959 train_loss: 0.001647594 val_loss: 0.029685056
# Step = 960 train_loss: 0.0014770383 val_loss: 0.02878852
# Step = 961 train_loss: 0.0017139992 val_loss: 0.021583175
# Step = 962 train_loss: 0.002295839 val_loss: 0.019793307
# Step = 963 train_loss: 0.0015220671 val_loss: 0.020415697
# Step = 964 train_loss: 0.0017773926 val_loss: 0.023825064
# Step = 965 train_loss: 0.0017317993 val_loss: 0.029587144
# Step = 966 train_loss: 0.0021387872 val_loss: 0.028377233
# Step = 967 train_loss: 0.0018641655 val_loss: 0.0024660276
# Step = 968 train_loss: 0.0013856671 val_loss: 0.33809492
# Step = 969 train_loss: 0.0023321654 val_loss: 0.43560755
# Step = 970 train_loss: 0.0019313667 val_loss: 0.448416
# Step = 971 train_loss: 0.0016156918 val_loss: 0.33693933
# Step = 972 train_loss: 0.0017664015 val_loss: 0.075660855
# Step = 973 train_loss: 0.0021808287 val_loss: 0.01575004
# Step = 974 train_loss: 0.0029459319 val_loss: 0.0032082568
# Step = 975 train_loss: 0.0018349062 val_loss: 0.0025241047
# Step = 976 train_loss: 0.0014825977 val_loss: 0.008015893
# Step = 977 train_loss: 0.0016554986 val_loss: 0.024524543
# Step = 978 train_loss: 0.0010247855 val_loss: 0.032149374
# Step = 979 train_loss: 0.0009949133 val_loss: 0.03175121
# Step = 980 train_loss: 0.00092654733 val_loss: 0.029863445
# Step = 981 train_loss: 0.0013006731 val_loss: 0.01479421
# Step = 982 train_loss: 0.000979972 val_loss: 0.016961822
# Step = 983 train_loss: 0.001475484 val_loss: 0.08426465
# Step = 984 train_loss: 0.0015122523 val_loss: 0.07126946
# Step = 985 train_loss: 0.0013669346 val_loss: 0.009044954
# Step = 986 train_loss: 0.001768573 val_loss: 0.01443828
# Step = 987 train_loss: 0.0015167766 val_loss: 0.030673547
# Step = 988 train_loss: 0.0018164404 val_loss: 0.032479085
# Step = 989 train_loss: 0.0018013672 val_loss: 0.015997496
# Step = 990 train_loss: 0.0013732926 val_loss: 0.27202874
# Step = 991 train_loss: 0.0013244306 val_loss: 0.49110386
# Step = 992 train_loss: 0.00321364 val_loss: 0.49075884
# Step = 993 train_loss: 0.0020327466 val_loss: 0.27730247
# Step = 994 train_loss: 0.002270129 val_loss: 0.01130847
# Step = 995 train_loss: 0.0027850023 val_loss: 0.021686569
# Step = 996 train_loss: 0.0034765597 val_loss: 0.01229547
# Step = 997 train_loss: 0.0014584436 val_loss: 0.0598755
# Step = 998 train_loss: 0.0029763724 val_loss: 0.49084753
# Step = 999 train_loss: 0.004351347 val_loss: 0.4404092
# Best model at index: 657
# Best model val_loss: 0.0018280158983543515
# C:\Users\Fisher Man\AppData\Local\Temp\ipykernel_30288\2966303312.py:124: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('Best_target_model/net_parameters.pkl')

# %%
# history = np.DataFrame(columns=['index','train_loss', 'val_loss'])
#画出训练过程中的loss变化曲线
plt.plot(history['train_loss'], label='train_loss')
plt.plot(history['val_loss'], label='val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
'''Prediction using the best model'''
predict_labels_a=[]
predict_labels_b=[]
predict_labels_train=[]
predict_labels_val = []
model.eval()
with torch.no_grad():
    predict_labels_a.append(model(input_test_a).data.numpy())
    predict_labels_b.append(model(input_test_b).data.numpy())
    
    predict_labels_train.append(model(input_train).data.numpy())   
    predict_labels_val.append(model(input_val).data.numpy())      


actual_label_arr_train=np.round(np.asarray(train_labels*max_label).reshape(-1,1))  
predict_label_arr_train=np.round(np.asarray(predict_labels_train).reshape(-1,1)*max_label)


actual_label_arr_val=np.round(np.asarray(val_labels*max_label).reshape(-1,1))   
predict_label_arr_val=np.round(np.asarray(predict_labels_val).reshape(-1,1)*max_label)


actual_label_arr_a=np.round(np.asarray(test_cycle_life_a*max_label).reshape(-1,1))   
predict_label_arr_a=np.round(np.asarray(predict_labels_a).reshape(-1,1)*max_label)


actual_label_arr_b=np.round(np.asarray(test_cycle_life_b * max_label).reshape(-1,1))   
predict_label_arr_b=np.round(np.asarray(predict_labels_b).reshape(-1,1)*max_label)

# %%
'''Plot the predicted cycle lives'''
plt.scatter(actual_label_arr_train, predict_label_arr_train,s=50,c='k')
plt.scatter(actual_label_arr_val, predict_label_arr_val,s=50,c='b')
plt.scatter(actual_label_arr_a, predict_label_arr_a,s=50,c='r')
plt.scatter(actual_label_arr_b, predict_label_arr_b,s=50,c='g')
plt.plot([100,2500],[100,2500])


'''Evaluation metrics'''
mpe_a=np.mean(np.abs(predict_label_arr_a-actual_label_arr_a)/actual_label_arr_a)
mpe_b=np.mean(np.abs(predict_label_arr_b-actual_label_arr_b)/actual_label_arr_b)
mpe_train = np.mean(np.abs(predict_label_arr_train-actual_label_arr_train)/actual_label_arr_train)
mpe_val = np.mean(np.abs(predict_label_arr_val-actual_label_arr_val)/actual_label_arr_val)


rmse_a=np.sqrt(np.mean((predict_label_arr_a-actual_label_arr_a)**2))
rmse_b=np.sqrt(np.mean((predict_label_arr_b-actual_label_arr_b)**2))
rmse_train=np.sqrt(np.mean((predict_label_arr_train-actual_label_arr_train)**2))
rmse_val=np.sqrt(np.mean((predict_label_arr_val-actual_label_arr_val)**2))


print ('mpe_train:',mpe_train)
print ('mpe_val:',mpe_val)
print ('mpe_a:',mpe_a)
print ('mpe_b:',mpe_b)

print ('rmse_train:', rmse_train)
print ('rmse_val:', rmse_val)
print ('rmse_a:', rmse_a)
print ('rmse_b:', rmse_b)
# Out:
# mpe_train: 0.13316502
# mpe_val: 0.13587104
# mpe_a: 0.11759044113780115
# mpe_b: 0.13669155489874965
# rmse_train: 93.804825
# rmse_val: 95.58166
# rmse_a: 94.20030612698987
# rmse_b: 237.59161390924555

# %%
from sklearn.metrics import r2_score
r2_a = r2_score(actual_label_arr_a, predict_label_arr_a)
r2_b = r2_score(actual_label_arr_b, predict_label_arr_b)
r2_train = r2_score(actual_label_arr_train, predict_label_arr_train)
r2_val = r2_score(actual_label_arr_val, predict_label_arr_val)

print('r2_train:', r2_train)
print('r2_val:', r2_val)
print('r2_a:', r2_a)
print('r2_b:', r2_b)
# Out:
# r2_train: 0.9393306374549866
# r2_val: 0.9122338891029358
# r2_a: 0.9418541557183394
# r2_b: 0.3055619061851145
